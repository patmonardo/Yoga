# %% [markdown]
# # CHAPTER 3

# %% [markdown]
# # C. INFINITY

# %% [markdown]
#     The infinite
#
#     (a) in simple determination,
#     is the affirmative as negation of the finite;
#     (b) but is thereby in alternating
#     determination with the infinite,
#     and is abstract, one-sided infinite;
#     (c) is the self-sublation of this infinite
#     and of the finite in one process.
#     This is the true infinite.

# %% [markdown]
# 1. **Introduction to Infinity:**
#    - The concept of infinity is introduced and is characterized in different ways.
#
# 2. **(a) Infinity in Simple Determination:**
#    - **Affirmative as Negation of the Finite:**
#      - Infinity is defined as the negation of the finite.
#      - This negation is affirmative, implying that infinity exists as the opposite or negation of finiteness.
#
# 3. **(b) Infinity in Alternating Determination:**
#    - **Abstract, One-Sided Infinite:**
#      - Infinity is described as being in a state of alternating determination with the finite.
#      - This version of infinity is abstract and one-sided, indicating that it is not fully realized or comprehensive.
#
# 4. **(c) The Self-Sublation of Infinity and the Finite:**
#    - **Self-Sublation in One Process:**
#      - This section introduces the concept of self-sublation, where both the finite and the one-sided infinite negate themselves.
#      - This process of self-sublation leads to the true infinite.
#    - **True Infinite:**
#      - The true infinite is presented as the result of the self-sublation of both the finite and the abstract infinite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "A class representing the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# ex:SimpleDetermination a owl:Class ;
#     rdfs:label "Simple Determination" ;
#     rdfs:comment "A class representing the simple determination, the initial affirmative negation of the finite." .
#
# ex:AlternatingDetermination a owl:Class ;
#     rdfs:label "Alternating Determination" ;
#     rdfs:comment "A class representing the alternating determination, where the infinite is abstract and one-sided." .
#
# ex:SelfSublation a owl:Class ;
#     rdfs:label "Self-Sublation" ;
#     rdfs:comment "A class representing the self-sublation process, where the infinite and finite negate each other in one process." .
#
# # Properties
# ex:hasSimpleDetermination a owl:ObjectProperty ;
#     rdfs:label "has simple determination" ;
#     rdfs:comment "Indicates that the infinite has a simple determination." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:SimpleDetermination .
#
# ex:hasNegation a owl:ObjectProperty ;
#     rdfs:label "has negation" ;
#     rdfs:comment "Indicates that the simple determination negates the finite." ;
#     rdfs:domain ex:SimpleDetermination ;
#     rdfs:range ex:Finite .
#
# ex:hasAlternatingDetermination a owl:ObjectProperty ;
#     rdfs:label "has alternating determination" ;
#     rdfs:comment "Indicates that the infinite has an alternating determination, making it abstract and one-sided." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:AlternatingDetermination .
#
# ex:hasSelfSublation a owl:ObjectProperty ;
#     rdfs:label "has self-sublation" ;
#     rdfs:comment "Indicates that the infinite achieves true infinity through the self-sublation process." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:TrueInfinite .
#
# ex:of a owl:ObjectProperty ;
#     rdfs:label "of" ;
#     rdfs:comment "Indicates the elements involved in the self-sublation process." ;
#     rdfs:domain ex:SelfSublation ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# # Individuals
# ex:simpleDetermination a ex:SimpleDetermination ;
#     rdfs:label "Simple Determination" ;
#     rdfs:comment "An individual representing the simple determination within the infinite." ;
#     ex:hasNegation ex:finite .
#
# ex:alternatingDetermination a ex:AlternatingDetermination ;
#     rdfs:label "Alternating Determination" ;
#     rdfs:comment "An individual representing the alternating determination, which is abstract and one-sided." ;
#     ex:isAbstract "true"^^xsd:boolean ;
#     ex:isOneSidedInfinite "true"^^xsd:boolean .
#
# ex:selfSublation a ex:SelfSublation ;
#     rdfs:label "Self-Sublation" ;
#     rdfs:comment "An individual representing the self-sublation process, combining the infinite and the finite." ;
#     ex:of ex:Infinite, ex:Finite .
#
# # Relationships
# ex:Infinite ex:hasSimpleDetermination ex:simpleDetermination ;
#     ex:hasAlternatingDetermination ex:alternatingDetermination ;
#     ex:hasSelfSublation ex:selfSublation .
#
# ex:TrueInfinite ex:hasSelfSublation ex:selfSublation .
# ```

# %% [markdown]
# ## a. The infinite in general

# %% [markdown]
#     The infinite is the negation of negation, the affirmative,
#     being that has reinstated itself out of restrictedness.
#     The infinite is, in a more intense sense
#     than the first immediate being;
#     it is the true being;
#     the elevation above restriction.
#     At the mention of the infinite, soul and spirit light up,
#     for in the infinite the spirit is at home,
#     and not only abstractly;
#     rather, it rises to itself, to the light of its thinking,
#     its universality, its freedom.

# %% [markdown]
# 1. **Infinite as Affirmative Being**: The transcreation emphasizes that the infinite is an affirmative state, a result of overcoming negation.
#
# 2. **Profound Existence of the Infinite**: It underlines that the infinite represents a deeper, truer form of being than mere initial existence.
#
# 3. **Spiritual Resonance of the Infinite**: The translation captures the uplifting effect of the concept of the infinite on the soul and spirit.
#
# 4. **Elevation and Enlightenment**: The text portrays the infinite as a state where the spirit rises to a higher level of awareness, universality, and freedom.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:AffirmativeBeing a owl:Class ;
#     rdfs:label "Affirmative Being" ;
#     rdfs:comment "A class representing the affirmative being, the true being elevated above restriction." .
#
# ex:Restrictedness a owl:Class ;
#     rdfs:label "Restrictedness" ;
#     rdfs:comment "A class representing the state of restriction that the infinite overcomes." .
#
# ex:Spirit a owl:Class ;
#     rdfs:label "Spirit" ;
#     rdfs:comment "A class representing the spirit, which finds its home and universality in the infinite." .
#
# ex:Soul a owl:Class ;
#     rdfs:label "Soul" ;
#     rdfs:comment "A class representing the soul, which lights up at the mention of the infinite." .
#
# # Properties
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the infinite involves the negation of negation." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:AffirmativeBeing .
#
# ex:overcomesRestrictedness a owl:ObjectProperty ;
#     rdfs:label "overcomes restrictedness" ;
#     rdfs:comment "Indicates that the infinite overcomes restrictedness." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Restrictedness .
#
# ex:isHomeTo a owl:ObjectProperty ;
#     rdfs:label "is home to" ;
#     rdfs:comment "Indicates that the infinite is the home of the spirit." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Spirit .
#
# ex:lightsUpSoul a owl:ObjectProperty ;
#     rdfs:label "lights up soul" ;
#     rdfs:comment "Indicates that the infinite lights up the soul." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Soul .
#
# # Individuals
# ex:affirmativeBeing a ex:AffirmativeBeing ;
#     rdfs:label "Affirmative Being" ;
#     rdfs:comment "An individual representing the affirmative being, the true being elevated above restriction." .
#
# ex:restrictedness a ex:Restrictedness ;
#     rdfs:label "Restrictedness" ;
#     rdfs:comment "An individual representing the state of restriction that the infinite overcomes." .
#
# ex:spirit a ex:Spirit ;
#     rdfs:label "Spirit" ;
#     rdfs:comment "An individual representing the spirit, which finds its home and universality in the infinite." .
#
# ex:soul a ex:Soul ;
#     rdfs:label "Soul" ;
#     rdfs:comment "An individual representing the soul, which lights up at the mention of the infinite." .
#
# # Relationships
# ex:Infinite ex:negationOfNegation ex:affirmativeBeing ;
#     ex:overcomesRestrictedness ex:restrictedness ;
#     ex:isHomeTo ex:spirit ;
#     ex:lightsUpSoul ex:soul .
# ```

# %% [markdown]
#     What is first given with the concept of the infinite is this,
#     that in its being-in-itself existence is determined
#     as finite and transcends restriction.
#     It is the very nature of the finite
#     that it transcend itself,
#     that it negate its negation
#     and become infinite.

# %% [markdown]
# 1. **Intrinsic Transcendence of the Finite**: The transcreation highlights the idea that the finite is intrinsically defined yet surpasses its own finite nature.
#
# 2. **Self-Negation Leading to Infinity**: It emphasizes the process where the finite negates its own negation, resulting in its transformation into the infinite.
#
# 3. **Fundamental Nature of the Finite**: The translation underscores that it is the essential nature of the finite to transcend itself, to evolve beyond its initial state.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the state of restriction that the finite transcends." .
#
# # Properties
# ex:transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that the finite transcends restriction and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the finite negates its negation to become infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# # Individuals
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the state of restriction." .
#
# # Relationships
# ex:Finite ex:transcends ex:restriction ;
#     ex:negationOfNegation ex:Infinite .
# ```

# %% [markdown]
#     Consequently, the infinite does not stand
#     above the finite as something ready-made by itself,
#     as if the finite stood fixed outside or below it.
#     Nor is it we only, as a subjective reason,
#     who transcend the finite into the infinite,
#     as if, in saying that the infinite is a concept of reason
#     and that through reason we elevate ourselves above things temporal,
#     we did this without prejudice to the finite,
#     without this elevation (which remains external to the finite)
#     affecting it.

# %% [markdown]
# 1. **Inseparable Connection of Finite and Infinite**: The transcreation emphasizes that the infinite is not a separate entity aloof from the finite.
#
# 2. **Role of Human Reason**: It underlines that transcending the finite to reach the infinite is not solely an act of subjective reasoning.
#
# 3. **Transformation Beyond Intellectual Exercise**: The translation suggests that the journey from the finite to the infinite involves a fundamental transformation of the finite itself.
#
# 4. **Interlinked Existential Process**: The text portrays the process as an existential one, where the finite and infinite are integrally connected.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the state of restriction that the finite transcends." .
#
# ex:SubjectiveReason a owl:Class ;
#     rdfs:label "Subjective Reason" ;
#     rdfs:comment "A class representing the subjective reason that transcends the finite into the infinite." .
#
# # Properties
# ex:transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that the finite transcends restriction and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the finite negates its negation to become infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:integrates a owl:ObjectProperty ;
#     rdfs:label "integrates" ;
#     rdfs:comment "Indicates that the infinite integrates the finite, showing they are not separate entities." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:transcendedBy a owl:ObjectProperty ;
#     rdfs:label "transcended by" ;
#     rdfs:comment "Indicates that the finite is transcended by subjective reason into the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SubjectiveReason .
#
# # Individuals
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the state of restriction." .
#
# ex:subjectiveReason a ex:SubjectiveReason ;
#     rdfs:label "Subjective Reason" ;
#     rdfs:comment "An individual representing the subjective reason that transcends the finite into the infinite." .
#
# # Relationships
# ex:Finite ex:transcends ex:restriction ;
#     ex:negationOfNegation ex:Infinite ;
#     ex:transcendedBy ex:subjectiveReason .
#
# ex:Infinite ex:integrates ex:Finite .
# ```

# %% [markdown]
#     In so far as the finite itself is being elevated to infinity,
#     it is not at all an alien force that does this for it;
#     it is rather its nature to refer itself to itself as restriction
#     (both restriction as such and as ought)
#     and to transcend this restriction,
#     or rather, in this self-reference,
#     to have negated the restriction
#     and gone above and beyond it.

# %% [markdown]
# 1. **Inherent Nature of the Finite**: The transcreation emphasizes that the finite naturally possesses the capacity to elevate itself to the infinite.
#
# 2. **Self-Referential Transcendence**: It highlights that the finite's transcendence of its limitations is a process of self-reference and self-negation.
#
# 3. **Role of Restriction and Ought**: The translation elucidates that the finite's interaction with its own limitations (both as restriction and as the 'ought') is crucial in this process.
#
# 4. **Natural Ascendance to the Infinite**: The text underscores that the finite's movement to the infinite is a natural progression, not influenced by external forces.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the state of restriction that the finite transcends." .
#
# ex:Ought a owl:Class ;
#     rdfs:label "Ought" ;
#     rdfs:comment "A class representing the concept of 'ought,' a form of restriction." .
#
# ex:SelfReference a owl:Class ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "A class representing the self-reference of the finite to its own restriction." .
#
# # Properties
# ex:transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that the finite transcends restriction and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the finite negates its negation to become infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:integrates a owl:ObjectProperty ;
#     rdfs:label "integrates" ;
#     rdfs:comment "Indicates that the infinite integrates the finite, showing they are not separate entities." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:transcendedBy a owl:ObjectProperty ;
#     rdfs:label "transcended by" ;
#     rdfs:comment "Indicates that the finite is transcended by subjective reason into the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SubjectiveReason .
#
# ex:refersToSelfAs a owl:ObjectProperty ;
#     rdfs:label "refers to self as" ;
#     rdfs:comment "Indicates that the finite refers to itself as restriction." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SelfReference .
#
# ex:hasOught a owl:ObjectProperty ;
#     rdfs:label "has ought" ;
#     rdfs:comment "Indicates that the self-reference of the finite includes the concept of 'ought'." ;
#     rdfs:domain ex:SelfReference ;
#     rdfs:range ex:Ought .
#
# # Individuals
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the state of restriction." .
#
# ex:subjectiveReason a ex:SubjectiveReason ;
#     rdfs:label "Subjective Reason" ;
#     rdfs:comment "An individual representing the subjective reason that transcends the finite into the infinite." .
#
# ex:selfReference a ex:SelfReference ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "An individual representing the self-reference of the finite to its own restriction." .
#
# ex:ought a ex:Ought ;
#     rdfs:label "Ought" ;
#     rdfs:comment "An individual representing the concept of 'ought,' a form of restriction." .
#
# # Relationships
# ex:Finite ex:transcends ex:restriction ;
#     ex:negationOfNegation ex:Infinite ;
#     ex:transcendedBy ex:subjectiveReason ;
#     ex:refersToSelfAs ex:selfReference .
#
# ex:Infinite ex:integrates ex:Finite .
#
# ex:SelfReference ex:hasOught ex:ought .

# %% [markdown]
#     It is not in the sublation of the finite in general
#     that infinity in general comes to be,
#     but the finite is rather just this,
#     that through its nature it comes to be itself the infinite.
#     Infinity is its affirmative determination,
#     its vocation, what it truly is in itself.

# %% [markdown]
# 1. **Finite’s Evolution into the Infinite**: The transcreation underlines that the finite naturally becomes the infinite, rather than the infinite being a mere negation of the finite.
#
# 2. **Infinite as Affirmative Determination**: It emphasizes that the infinite is the positive realization and true essence of the finite.
#
# 3. **Innate Nature of the Finite**: The translation points out that it is in the inherent nature or 'vocation' of the finite to transform into the infinite.
#
# 4. **Unity of Finite and Infinite**: The text highlights the concept that infinity is not an external state but is integrally connected to the nature of the finite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the state of restriction that the finite transcends." .
#
# ex:Ought a owl:Class ;
#     rdfs:label "Ought" ;
#     rdfs:comment "A class representing the concept of 'ought,' a form of restriction." .
#
# ex:SelfReference a owl:Class ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "A class representing the self-reference of the finite to its own restriction." .
#
# ex:AffirmativeDetermination a owl:Class ;
#     rdfs:label "Affirmative Determination" ;
#     rdfs:comment "A class representing the affirmative determination of the finite to become the infinite." .
#
# # Properties
# ex:transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that the finite transcends restriction and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the finite negates its negation to become infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:integrates a owl:ObjectProperty ;
#     rdfs:label "integrates" ;
#     rdfs:comment "Indicates that the infinite integrates the finite, showing they are not separate entities." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:transcendedBy a owl:ObjectProperty ;
#     rdfs:label "transcended by" ;
#     rdfs:comment "Indicates that the finite is transcended by subjective reason into the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SubjectiveReason .
#
# ex:refersToSelfAs a owl:ObjectProperty ;
#     rdfs:label "refers to self as" ;
#     rdfs:comment "Indicates that the finite refers to itself as restriction." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SelfReference .
#
# ex:hasOught a owl:ObjectProperty ;
#     rdfs:label "has ought" ;
#     rdfs:comment "Indicates that the self-reference of the finite includes the concept of 'ought'." ;
#     rdfs:domain ex:SelfReference ;
#     rdfs:range ex:Ought .
#
# ex:becomesInfiniteThroughNature a owl:ObjectProperty ;
#     rdfs:label "becomes infinite through nature" ;
#     rdfs:comment "Indicates that the finite, through its nature, becomes the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:hasAffirmativeDetermination a owl:ObjectProperty ;
#     rdfs:label "has affirmative determination" ;
#     rdfs:comment "Indicates that the infinite is the affirmative determination of the finite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:AffirmativeDetermination .
#
# # Individuals
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the state of restriction." .
#
# ex:subjectiveReason a ex:SubjectiveReason ;
#     rdfs:label "Subjective Reason" ;
#     rdfs:comment "An individual representing the subjective reason that transcends the finite into the infinite." .
#
# ex:selfReference a ex:SelfReference ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "An individual representing the self-reference of the finite to its own restriction." .
#
# ex:ought a ex:Ought ;
#     rdfs:label "Ought" ;
#     rdfs:comment "An individual representing the concept of 'ought,' a form of restriction." .
#
# ex:affirmativeDetermination a ex:AffirmativeDetermination ;
#     rdfs:label "Affirmative Determination" ;
#     rdfs:comment "An individual representing the affirmative determination of the finite to become the infinite." .
#
# # Relationships
# ex:Finite ex:transcends ex:restriction ;
#     ex:negationOfNegation ex:Infinite ;
#     ex:transcendedBy ex:subjectiveReason ;
#     ex:refersToSelfAs ex:selfReference ;
#     ex:hasOught ex:ought ;
#     ex:becomesInfiniteThroughNature ex:Infinite ;
#     ex:hasAffirmativeDetermination ex:affirmativeDetermination .
#
# ex:Infinite ex:integrates ex:Finite .

# %% [markdown]
#     The finite has thus vanished into the infinite
#     and what is, is only the infinite.

# %% [markdown]
# 1. **Dissolution of the Finite**: The transcreation emphasizes the idea that the finite has entirely merged into the infinite.
#
# 2. **Infinite as the Sole Reality**: It highlights that, according to Hegel, the only true existence or reality that remains is the infinite.
#
# 3. **Transcendence of Finite Existence**: The translation underscores the concept that the essence of being transcends finite limitations to embody an infinite nature.
#
# 4. **Ultimate Manifestation of Existence**: The text portrays the infinite as the final and true manifestation of existence, where the finite no longer exists as an independent entity.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the state of restriction that the finite transcends." .
#
# ex:Ought a owl:Class ;
#     rdfs:label "Ought" ;
#     rdfs:comment "A class representing the concept of 'ought,' a form of restriction." .
#
# ex:SelfReference a owl:Class ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "A class representing the self-reference of the finite to its own restriction." .
#
# ex:AffirmativeDetermination a owl:Class ;
#     rdfs:label "Affirmative Determination" ;
#     rdfs:comment "A class representing the affirmative determination of the finite to become the infinite." .
#
# ex:SubjectiveReason a owl:Class ;
#     rdfs:label "Subjective Reason" ;
#     rdfs:comment "A class representing the subjective reason that transcends the finite into the infinite." .
#
# # Properties
# ex:transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that the finite transcends restriction and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the finite negates its negation to become infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:integrates a owl:ObjectProperty ;
#     rdfs:label "integrates" ;
#     rdfs:comment "Indicates that the infinite integrates the finite, showing they are not separate entities." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:transcendedBy a owl:ObjectProperty ;
#     rdfs:label "transcended by" ;
#     rdfs:comment "Indicates that the finite is transcended by subjective reason into the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SubjectiveReason .
#
# ex:refersToSelfAs a owl:ObjectProperty ;
#     rdfs:label "refers to self as" ;
#     rdfs:comment "Indicates that the finite refers to itself as restriction." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SelfReference .
#
# ex:hasOught a owl:ObjectProperty ;
#     rdfs:label "has ought" ;
#     rdfs:comment "Indicates that the self-reference of the finite includes the concept of 'ought'." ;
#     rdfs:domain ex:SelfReference ;
#     rdfs:range ex:Ought .
#
# ex:becomesInfiniteThroughNature a owl:ObjectProperty ;
#     rdfs:label "becomes infinite through nature" ;
#     rdfs:comment "Indicates that the finite, through its nature, becomes the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:hasAffirmativeDetermination a owl:ObjectProperty ;
#     rdfs:label "has affirmative determination" ;
#     rdfs:comment "Indicates that the infinite is the affirmative determination of the finite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:AffirmativeDetermination .
#
# ex:vanishesInto a owl:ObjectProperty ;
#     rdfs:label "vanishes into" ;
#     rdfs:comment "Indicates that the finite vanishes into the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# # Individuals
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the state of restriction." .
#
# ex:subjectiveReason a ex:SubjectiveReason ;
#     rdfs:label "Subjective Reason" ;
#     rdfs:comment "An individual representing the subjective reason that transcends the finite into the infinite." .
#
# ex:selfReference a ex:SelfReference ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "An individual representing the self-reference of the finite to its own restriction." .
#
# ex:ought a ex:Ought ;
#     rdfs:label "Ought" ;
#     rdfs:comment "An individual representing the concept of 'ought,' a form of restriction." .
#
# ex:affirmativeDetermination a ex:AffirmativeDetermination ;
#     rdfs:label "Affirmative Determination" ;
#     rdfs:comment "An individual representing the affirmative determination of the finite to become the infinite." .
#
# # Relationships
# ex:Finite ex:transcends ex:restriction ;
#     ex:negationOfNegation ex:Infinite ;
#     ex:transcendedBy ex:subjectiveReason ;
#     ex:refersToSelfAs ex:selfReference ;
#     ex:hasOught ex:ought ;
#     ex:becomesInfiniteThroughNature ex:Infinite ;
#     ex:hasAffirmativeDetermination ex:affirmativeDetermination ;
#     ex:vanishesInto ex:Infinite .
#
# ex:Infinite ex:integrates ex:Finite .

# %% [markdown]
# ## b. Alternating determination of finite and infinite

# %% [markdown]
#     The infinite is;
#     in this immediacy it is at the same time
#     the negation of an other, of the finite.
#     And so, as existent and at the same time as the
#     non-being of an other,
#     it has fallen back into the category of the something,
#     of something determinate in general.

# %% [markdown]
# 1. **Immediate Existence of the Infinite**: The transcreation emphasizes the immediate existence of the infinite in Hegel's philosophy.
#
# 2. **Negation of the Finite**: It highlights that this immediate existence involves the negation of the finite, defining the infinite in relation to it.
#
# 3. **Infinite as Something Determinate**: The translation suggests that through this process, the infinite, while being existent, also falls back into being a specific, determinate entity.
#
# 4. **Dialectical Interpretation**: The text reflects Hegel's dialectical method, portraying the infinite as both an abstract concept and a concrete entity defined through its relationship with the finite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Something a owl:Class ;
#     rdfs:label "Something" ;
#     rdfs:comment "A class representing something determinate in general." .
#
# # Properties
# ex:negationOfOther a owl:ObjectProperty ;
#     rdfs:label "negation of other" ;
#     rdfs:comment "Indicates that the infinite is the negation of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:existentAndNonBeingOfOther a owl:ObjectProperty ;
#     rdfs:label "existent and non-being of other" ;
#     rdfs:comment "Indicates that the infinite exists and is at the same time the non-being of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:fallsIntoCategoryOfSomething a owl:ObjectProperty ;
#     rdfs:label "falls into category of something" ;
#     rdfs:comment "Indicates that the infinite, as existent and as non-being of an other, falls back into the category of something determinate." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Something .
#
# # Individuals
# ex:somethingDeterminate a ex:Something ;
#     rdfs:label "Something Determinate" ;
#     rdfs:comment "An individual representing something determinate in general." .
#
# # Relationships
# ex:Infinite ex:negationOfOther ex:Finite ;
#     ex:existentAndNonBeingOfOther ex:Finite ;
#     ex:fallsIntoCategoryOfSomething ex:somethingDeterminate .

# %% [markdown]
#     More precisely: the infinite is
#     the existence reflected into itself
#     which results from the mediating sublation
#     of determinateness in general
#     and is consequently posited as existence
#     distinct from its determinateness;
#     therefore, it has fallen back into
#     the category of something with a limit.

# %% [markdown]
# 1. **Self-Reflective Nature of the Infinite**: The transcreation emphasizes the concept of the infinite as an existence that reflects into itself.
#
# 2. **Sublation of Determinateness**: It highlights the process where the infinite emerges from transcending general determinateness.
#
# 3. **Distinction from Determinateness**: The translation underlines that the infinite is positioned as distinct from its specific characteristics.
#
# 4. **Re-entry into Limitation**: The text illustrates the paradox where, in becoming distinct, the infinite falls back into the category of something with a limit.

# %% [markdown]
# I understand, let's focus strictly on the current text segment and ensure the ontology is concise and directly aligned with the provided information.
#
# ### Revised OWL Ontology for "b. Alternating Determination of Finite and Infinite"
#
# ```turtle
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# # Properties
# ex:standsOverAgainst a owl:ObjectProperty ;
#     rdfs:label "stands over against" ;
#     rdfs:comment "Indicates that the finite stands over against the infinite as real existence." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:mutualReference a owl:ObjectProperty ;
#     rdfs:label "mutual reference" ;
#     rdfs:comment "Indicates the qualitative mutual reference between the finite and infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:resurrectsBeingOf a owl:ObjectProperty ;
#     rdfs:label "resurrects being of" ;
#     rdfs:comment "Indicates that the immediate being of the infinite resurrects the being of its negation, the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# # Relationships
# ex:Finite ex:standsOverAgainst ex:Infinite ;
#     ex:mutualReference ex:Infinite .
#
# ex:Infinite ex:resurrectsBeingOf ex:Finite .
# ```
#
# This ontology strictly includes the concepts and relationships from the provided text segment:
#
# - **Classes**: Infinite, Finite
# - **Properties**: stands over against, mutual reference, resurrects being of
# - **Relationships**:
#   - The finite stands over against the infinite.
#   - The finite and infinite have a mutual reference.
#   - The infinite resurrects the being of the finite.
#
# This concise ontology reflects the alternating determination of finite and infinite, focusing on their mutual reference and the resurrection of the finite's being by the infinite.
#
# Would you like to proceed with the next part of the chapter or make further adjustments to this segment?

# %% [markdown]
#     In accordance with this determinateness,
#     the finite stands over against
#     the infinite as real existence;
#     they thus remain outside each other,
#     standing in qualitative mutual reference;
#     the immediate being of the infinite
#     resurrects the being of its negation,
#     of the finite again, which seemed at first
#     to have vanished into the infinite.

# %% [markdown]
# 1. **Mutual Opposition of Finite and Infinite**: The transcreation highlights the oppositional relationship between the finite and the infinite, each standing as a distinct reality.
#
# 2. **Qualitative Mutual Reference**: It emphasizes the qualitative relationship between the two, where each refers to and is defined in relation to the other.
#
# 3. **Resurrection of the Finite**: The translation captures the idea that the immediate being of the infinite paradoxically reasserts the existence of the finite.
#
# 4. **Dialectical Interplay**: The text reflects Hegel's dialectical method, showing the interconnected yet distinct nature of the finite and infinite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:RealExistence a owl:Class ;
#     rdfs:label "Real Existence" ;
#     rdfs:comment "A class representing real existence, indicating the finite's standing over against the infinite." .
#
# # Properties
# ex:standsOverAgainst a owl:ObjectProperty ;
#     rdfs:label "stands over against" ;
#     rdfs:comment "Indicates that the finite stands over against the infinite as real existence." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:RealExistence .
#
# ex:mutualReference a owl:ObjectProperty ;
#     rdfs:label "mutual reference" ;
#     rdfs:comment "Indicates the qualitative mutual reference between the finite and infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:resurrectsBeingOf a owl:ObjectProperty ;
#     rdfs:label "resurrects being of" ;
#     rdfs:comment "Indicates that the immediate being of the infinite resurrects the being of its negation, the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# # Relationships
# ex:Finite ex:standsOverAgainst ex:RealExistence ;
#     ex:mutualReference ex:Infinite .
#
# ex:Infinite ex:resurrectsBeingOf ex:Finite .

# %% [markdown]
#     But the infinite and the finite are not
#     in these referential categories only;
#     the two sides are further determined in addition
#     to being as mere others to each other.
#     Namely, the finite is restriction posited as restriction;
#     it is existence posited with the determination
#     that it passes over into what is its in-itself
#     and becomes infinite.

# %% [markdown]
# 1. **Beyond Mere Opposition**: The transcreation emphasizes that the finite and the infinite are not just opposites; they possess deeper, intrinsic qualities.
#
# 2. **Finite as Self-Aware Restriction**: It highlights that the finite is not only a limitation but is also self-aware of this nature and its implications.
#
# 3. **Intrinsic Orientation Towards Infinity**: The translation underscores the finite's inherent tendency to transcend its own limitations and become infinite.
#
# 4. **Evolution of Finite into Infinite**: The text portrays the finite's transition into the infinite as a natural evolution towards its true essence.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:RealExistence a owl:Class ;
#     rdfs:label "Real Existence" ;
#     rdfs:comment "A class representing real existence, indicating the finite's standing over against the infinite." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the finite as restriction posited as restriction." .
#
# # Properties
# ex:standsOverAgainst a owl:ObjectProperty ;
#     rdfs:label "stands over against" ;
#     rdfs:comment "Indicates that the finite stands over against the infinite as real existence." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:RealExistence .
#
# ex:mutualReference a owl:ObjectProperty ;
#     rdfs:label "mutual reference" ;
#     rdfs:comment "Indicates the qualitative mutual reference between the finite and infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:resurrectsBeingOf a owl:ObjectProperty ;
#     rdfs:label "resurrects being of" ;
#     rdfs:comment "Indicates that the immediate being of the infinite resurrects the being of its negation, the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:positedAsRestriction a owl:ObjectProperty ;
#     rdfs:label "posited as restriction" ;
#     rdfs:comment "Indicates that the finite is restriction posited as restriction." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:passesOverInto a owl:ObjectProperty ;
#     rdfs:label "passes over into" ;
#     rdfs:comment "Indicates that the finite passes over into its in-itself and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# # Individuals
# ex:realExistence a ex:RealExistence ;
#     rdfs:label "Real Existence" ;
#     rdfs:comment "An individual representing real existence, indicating the finite's standing over against the infinite." .
#
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the finite as restriction posited as restriction." .
#
# # Relationships
# ex:Finite ex:standsOverAgainst ex:realExistence ;
#     ex:mutualReference ex:Infinite ;
#     ex:positedAsRestriction ex:restriction ;
#     ex:passesOverInto ex:Infinite .
#
# ex:Infinite ex:resurrectsBeingOf ex:Finite .

# %% [markdown]
#     Infinity is the nothing of the finite,
#     the in-itself that the latter ought to be,
#     but it is this at the same time
#     as reflected within itself,
#     as realized ought, as only
#     affirmative self-referring being.
#     In infinity we have the satisfaction
#     that all determinateness, alteration, all restriction
#     and the ought itself together with it,
#     have vanished, are sublated,
#     and the nothing of the finite is posited.

# %% [markdown]
# 1. **Infinity as Negation of the Finite**: The transcreation underscores that infinity represents the negation or absence of the finite.
#
# 2. **Realized Potential of the Infinite**: It highlights that infinity is not just a negation but a reflection and realization of what the finite 'ought' to be.
#
# 3. **Affirmative Self-Referring Being**: The translation illustrates that infinity is a self-contained, affirmative state, transcending the finite.
#
# 4. **Satisfaction in Infinity**: The text conveys a sense of fulfillment in infinity, where limitations, changes, and the 'ought' of the finite are transcended.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:RealExistence a owl:Class ;
#     rdfs:label "Real Existence" ;
#     rdfs:comment "A class representing real existence, indicating the finite's standing over against the infinite." .
#
# ex:Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "A class representing the finite as restriction posited as restriction." .
#
# ex:Ought a owl:Class ;
#     rdfs:label "Ought" ;
#     rdfs:comment "A class representing the concept of 'ought,' a form of restriction." .
#
# ex:NothingOfFinite a owl:Class ;
#     rdfs:label "Nothing of Finite" ;
#     rdfs:comment "A class representing the nothing of the finite, the in-itself that the finite ought to be." .
#
# # Properties
# ex:standsOverAgainst a owl:ObjectProperty ;
#     rdfs:label "stands over against" ;
#     rdfs:comment "Indicates that the finite stands over against the infinite as real existence." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:RealExistence .
#
# ex:mutualReference a owl:ObjectProperty ;
#     rdfs:label "mutual reference" ;
#     rdfs:comment "Indicates the qualitative mutual reference between the finite and infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:resurrectsBeingOf a owl:ObjectProperty ;
#     rdfs:label "resurrects being of" ;
#     rdfs:comment "Indicates that the immediate being of the infinite resurrects the being of its negation, the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:positedAsRestriction a owl:ObjectProperty ;
#     rdfs:label "posited as restriction" ;
#     rdfs:comment "Indicates that the finite is restriction posited as restriction." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Restriction .
#
# ex:passesOverInto a owl:ObjectProperty ;
#     rdfs:label "passes over into" ;
#     rdfs:comment "Indicates that the finite passes over into its in-itself and becomes infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:nothingOfFinite a owl:ObjectProperty ;
#     rdfs:label "nothing of finite" ;
#     rdfs:comment "Indicates that the infinite is the nothing of the finite, the in-itself that the finite ought to be." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:NothingOfFinite .
#
# ex:realizedOught a owl:ObjectProperty ;
#     rdfs:label "realized ought" ;
#     rdfs:comment "Indicates that the infinite is the realized ought, the affirmative self-referring being." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Ought .
#
# # Individuals
# ex:realExistence a ex:RealExistence ;
#     rdfs:label "Real Existence" ;
#     rdfs:comment "An individual representing real existence, indicating the finite's standing over against the infinite." .
#
# ex:restriction a ex:Restriction ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "An individual representing the finite as restriction posited as restriction." .
#
# ex:ought a ex:Ought ;
#     rdfs:label "Ought" ;
#     rdfs:comment "An individual representing the concept of 'ought,' a form of restriction." .
#
# ex:nothingOfFinite a ex:NothingOfFinite ;
#     rdfs:label "Nothing of Finite" ;
#     rdfs:comment "An individual representing the nothing of the finite, the in-itself that the finite ought to be." .
#
# # Relationships
# ex:Finite ex:standsOverAgainst ex:realExistence ;
#     ex:mutualReference ex:Infinite ;
#     ex:positedAsRestriction ex:restriction ;
#     ex:passesOverInto ex:Infinite .
#
# ex:Infinite ex:resurrectsBeingOf ex:Finite ;
#     ex:nothingOfFinite ex:nothingOfFinite ;
#     ex:realizedOught ex:ought .

# %% [markdown]
#     As this negation of the finite is
#     the being-in-itself determined which,
#     as negation of negation, is in itself affirmative.
#     Yet this affirmation is qualitatively
#     immediate self-reference, being;
#     and, because of this, the affirmative is led back
#     to the category of being that has
#     the finite confronting it as an other;
#     its negative nature is posited as existent negation,
#     and hence as first and immediate negation.

# %% [markdown]
# 1. **Affirmative Nature of Finite Negation**: The transcreation emphasizes that the negation of the finite is, in essence, an affirmative being-in-itself.
#
# 2. **Immediate Self-Reference**: It highlights the immediate and qualitative nature of this affirmation as a form of self-referential being.
#
# 3. **Reconnection to Finite Being**: The translation illustrates that this affirmative state leads back to a category of being where the finite is still recognized as an 'other.'
#
# 4. **Existent Negation of the Infinite**: The text points out that the negative aspect of the infinite is posited as an existent, primary form of negation.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing negation in Hegelian philosophy." .
#
# ex:BeingInItself a owl:Class ;
#     rdfs:label "Being in Itself" ;
#     rdfs:comment "A class representing the being-in-itself determined as negation of negation and affirmative." .
#
# ex:Affirmation a owl:Class ;
#     rdfs:label "Affirmation" ;
#     rdfs:comment "A class representing the affirmation as immediate self-reference." .
#
# ex:ExistentNegation a owl:Class ;
#     rdfs:label "Existent Negation" ;
#     rdfs:comment "A class representing the existent negation, the first and immediate negation." .
#
# # Properties
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the being-in-itself is determined as negation of negation and is affirmative." ;
#     rdfs:domain ex:BeingInItself ;
#     rdfs:range ex:Negation .
#
# ex:immediateSelfReference a owl:ObjectProperty ;
#     rdfs:label "immediate self-reference" ;
#     rdfs:comment "Indicates that the affirmation is immediate self-reference, being." ;
#     rdfs:domain ex:Affirmation ;
#     rdfs:range ex:BeingInItself .
#
# ex:positedAsExistentNegation a owl:ObjectProperty ;
#     rdfs:label "posited as existent negation" ;
#     rdfs:comment "Indicates that the negative nature is posited as existent negation." ;
#     rdfs:domain ex:Negation ;
#     rdfs:range ex:ExistentNegation .
#
# # Individuals
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing negation in Hegelian philosophy." .
#
# ex:beingInItself a ex:BeingInItself ;
#     rdfs:label "Being in Itself" ;
#     rdfs:comment "An individual representing the being-in-itself determined as negation of negation and affirmative." .
#
# ex:affirmation a ex:Affirmation ;
#     rdfs:label "Affirmation" ;
#     rdfs:comment "An individual representing the affirmation as immediate self-reference." .
#
# ex:existentNegation a ex:ExistentNegation ;
#     rdfs:label "Existent Negation" ;
#     rdfs:comment "An individual representing the existent negation, the first and immediate negation." .
#
# # Relationships
# ex:BeingInItself ex:negationOfNegation ex:negation .
#
# ex:Affirmation ex:immediateSelfReference ex:beingInItself .
#
# ex:Negation ex:positedAsExistentNegation ex:existentNegation .

# %% [markdown]
#     The infinite is in this way burdened
#     with the opposition to the finite,
#     and this finite, as an other, remains a real existence
#     even though in its being-in-itself, in the infinite,
#     it is at the same time posited as sublated;
#     this infinite is that which is not finite:
#     a being in the determinateness of negation.

# %% [markdown]
# 1. **Oppositional Burden of the Infinite**: The transcreation underscores that the infinite inherently bears the opposition to the finite.
#
# 2. **Finite's Continued Real Existence**: It highlights that despite being transcended within the infinite, the finite continues to exist as a distinct reality.
#
# 3. **Infinite as Non-Finite**: The translation focuses on defining the infinite as essentially what is not finite, emphasizing its existence in negation.
#
# 4. **Determinateness of Negation**: The text illustrates that the infinite's essence is defined by its determined negation of the finite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:BeingInItself a owl:Class ;
#     rdfs:label "Being in Itself" ;
#     rdfs:comment "A class representing the being-in-itself determined as negation of negation and affirmative." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing negation in Hegelian philosophy." .
#
# # Properties
# ex:burdenedWithOppositionTo a owl:ObjectProperty ;
#     rdfs:label "burdened with opposition to" ;
#     rdfs:comment "Indicates that the infinite is burdened with opposition to the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:remainsRealExistence a owl:ObjectProperty ;
#     rdfs:label "remains real existence" ;
#     rdfs:comment "Indicates that the finite remains a real existence even though it is posited as sublated in the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:positedAsSublatedIn a owl:ObjectProperty ;
#     rdfs:label "posited as sublated in" ;
#     rdfs:comment "Indicates that the finite is posited as sublated in the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:beingInDeterminatenessOf a owl:ObjectProperty ;
#     rdfs:label "being in the determinateness of" ;
#     rdfs:comment "Indicates that the infinite is a being in the determinateness of negation." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Negation .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:beingInItself a ex:BeingInItself ;
#     rdfs:label "Being in Itself" ;
#     rdfs:comment "An individual representing the being-in-itself determined as negation of negation and affirmative." .
#
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing negation in Hegelian philosophy." .
#
# # Relationships
# ex:Infinite ex:burdenedWithOppositionTo ex:Finite ;
#     ex:beingInDeterminatenessOf ex:negation .
#
# ex:Finite ex:remainsRealExistence ex:Infinite ;
#     ex:positedAsSublatedIn ex:Infinite .

# %% [markdown]
#     Contrasted with the finite,
#     with the series of existent determinacies,
#     of realities,
#     the infinite is indeterminate emptiness,
#     the beyond of the finite,
#     whose being-in-itself is not in its existence
#     (which is something determinate).

# %% [markdown]
# 1. **Infinite as Indeterminate Emptiness**: The transcreation emphasizes the infinite's nature as an undefined, boundless emptiness in contrast to the finite's specific realities.
#
# 2. **Infinite as Beyond of the Finite**: It highlights the concept of the infinite as a transcendent realm beyond the finite's series of realities.
#
# 3. **Non-Determinate Nature of Infinite**: The translation points out that the infinite's essence does not reside in determinate existence, unlike the finite.
#
# 4. **Transcendence Over Finite Determinacies**: The text illustrates that the infinite surpasses the finite's specific, determinate characteristics.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Determinacy a owl:Class ;
#     rdfs:label "Determinacy" ;
#     rdfs:comment "A class representing a series of existent determinacies." .
#
# ex:Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "A class representing realities." .
#
# ex:IndeterminateEmptiness a owl:Class ;
#     rdfs:label "Indeterminate Emptiness" ;
#     rdfs:comment "A class representing the indeterminate emptiness contrasted with the finite." .
#
# ex:Beyond a owl:Class ;
#     rdfs:label "Beyond" ;
#     rdfs:comment "A class representing the beyond of the finite." .
#
# # Properties
# ex:contrastedWith a owl:ObjectProperty ;
#     rdfs:label "contrasted with" ;
#     rdfs:comment "Indicates that the infinite is contrasted with the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:seriesOf a owl:ObjectProperty ;
#     rdfs:label "series of" ;
#     rdfs:comment "Indicates that the finite is a series of existent determinacies and realities." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Determinacy, ex:Reality .
#
# ex:isIndeterminateEmptiness a owl:ObjectProperty ;
#     rdfs:label "is indeterminate emptiness" ;
#     rdfs:comment "Indicates that the infinite is indeterminate emptiness." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:IndeterminateEmptiness .
#
# ex:isBeyondOf a owl:ObjectProperty ;
#     rdfs:label "is beyond of" ;
#     rdfs:comment "Indicates that the infinite is the beyond of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Beyond .
#
# ex:beingInItselfNotInExistence a owl:ObjectProperty ;
#     rdfs:label "being-in-itself not in existence" ;
#     rdfs:comment "Indicates that the infinite's being-in-itself is not in its existence, which is something determinate." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:determinacy a ex:Determinacy ;
#     rdfs:label "Determinacy" ;
#     rdfs:comment "An individual representing a series of existent determinacies." .
#
# ex:reality a ex:Reality ;
#     rdfs:label "Reality" ;
#     rdfs:comment "An individual representing realities." .
#
# ex:indeterminateEmptiness a ex:IndeterminateEmptiness ;
#     rdfs:label "Indeterminate Emptiness" ;
#     rdfs:comment "An individual representing the indeterminate emptiness contrasted with the finite." .
#
# ex:beyond a ex:Beyond ;
#     rdfs:label "Beyond" ;
#     rdfs:comment "An individual representing the beyond of the finite." .
#
# # Relationships
# ex:Infinite ex:contrastedWith ex:Finite ;
#     ex:isIndeterminateEmptiness ex:indeterminateEmptiness ;
#     ex:isBeyondOf ex:beyond ;
#     ex:beingInItselfNotInExistence ex:Finite .
#
# ex:Finite ex:seriesOf ex:determinacy, ex:reality .

# %% [markdown]
#     As thus posited over against the finite,
#     the two connected by the qualitative mutual reference of others,
#     the infinite is to be called the bad infinite,
#     the infinite of the understanding,
#     for which it counts as the highest,
#     the absolute truth.

# %% [markdown]
# 1. **Oppositional Infinite as 'Bad Infinite'**: The transcreation clarifies that Hegel refers to the infinite, as simply opposed to the finite, as the 'bad infinite.'
#
# 2. **Understanding's Perspective**: It emphasizes that this concept of the infinite is the perspective of the 'understanding,' which sees it as the highest truth.
#
# 3. **Limitation of the 'Bad Infinite'**: The translation points out the limitations in this view of the infinite, as it fails to capture its fuller, more dynamic essence.
#
# 4. **Simplistic View of Infinity**: The text underscores that the 'bad infinite' represents a linear, simplistic understanding of infinity, not acknowledging its deeper interconnectedness with the finite.

# %% [markdown]
# Let's incorporate the new concepts and relationships from this text segment into the ontology.
#
# ### Focused OWL Ontology for the Latest Text Segment
#
# ```turtle
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "A class representing the bad infinite, the infinite of the understanding." .
#
# ex:Understanding a owl:Class ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "A class representing the understanding." .
#
# ex:AbsoluteTruth a owl:Class ;
#     rdfs:label "Absolute Truth" ;
#     rdfs:comment "A class representing the absolute truth." .
#
# # Properties
# ex:positedOverAgainst a owl:ObjectProperty ;
#     rdfs:label "posited over against" ;
#     rdfs:comment "Indicates that the infinite is posited over against the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:connectedBy a owl:ObjectProperty ;
#     rdfs:label "connected by" ;
#     rdfs:comment "Indicates that the infinite and finite are connected by the qualitative mutual reference of others." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:called a owl:ObjectProperty ;
#     rdfs:label "called" ;
#     rdfs:comment "Indicates that the infinite is called the bad infinite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:BadInfinite .
#
# ex:countsAs a owl:ObjectProperty ;
#     rdfs:label "counts as" ;
#     rdfs:comment "Indicates that the bad infinite counts as the highest, the absolute truth for the understanding." ;
#     rdfs:domain ex:BadInfinite ;
#     rdfs:range ex:AbsoluteTruth .
#
# ex:ofUnderstanding a owl:ObjectProperty ;
#     rdfs:label "of understanding" ;
#     rdfs:comment "Indicates that the bad infinite is of the understanding." ;
#     rdfs:domain ex:BadInfinite ;
#     rdfs:range ex:Understanding .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:badInfinite a ex:BadInfinite ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "An individual representing the bad infinite, the infinite of the understanding." .
#
# ex:understanding a ex:Understanding ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "An individual representing the understanding." .
#
# ex:absoluteTruth a ex:AbsoluteTruth ;
#     rdfs:label "Absolute Truth" ;
#     rdfs:comment "An individual representing the absolute truth." .
#
# # Relationships
# ex:Infinite ex:positedOverAgainst ex:Finite ;
#     ex:connectedBy ex:Finite ;
#     ex:called ex:badInfinite .
#
# ex:BadInfinite ex:countsAs ex:absoluteTruth ;
#     ex:ofUnderstanding ex:understanding .
# ```
#
# This ontology strictly includes the concepts and relationships from the provided text segment:
#
# - **Classes**: Infinite, Finite, Bad Infinite, Understanding, Absolute Truth
# - **Properties**: posited over against, connected by, called, counts as, of understanding
# - **Individuals**: infinite, finite, badInfinite, understanding, absoluteTruth
#
# This concise ontology reflects the specific concepts and relationships described in your latest text segment.
#
# Please provide the next text segment, and we'll continue building the ontology step by step.

# %% [markdown]
#     The understanding believes that
#     it has attained satisfaction
#     in the reconciliation of truth
#     while it is in fact entangled in
#     unreconciled, unresolved, absolute contradictions.
#     And it is these contradictions,
#     into which it falls on every side whenever
#     it embarks on the application and explication
#     of these categories that belong to it,
#     that must make it conscious of the fact.

# %% [markdown]
# 1. **Understanding's False Satisfaction**: The transcreation emphasizes the understanding's mistaken belief in having reconciled with truth.
#
# 2. **Entanglement in Contradictions**: It highlights the deep contradictions the understanding faces in its pursuit of truth.
#
# 3. **Exposure Through Application**: The translation points out that these contradictions become apparent when the understanding tries to apply its categories.
#
# 4. **Consciousness of Limitations**: The text suggests that these contradictions should lead the understanding to become aware of its own limitations.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Understanding a owl:Class ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "A class representing the understanding in Hegelian philosophy." .
#
# ex:Truth a owl:Class ;
#     rdfs:label "Truth" ;
#     rdfs:comment "A class representing the concept of truth." .
#
# ex:Contradiction a owl:Class ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "A class representing the concept of contradiction." .
#
# ex:Category a owl:Class ;
#     rdfs:label "Category" ;
#     rdfs:comment "A class representing the categories of the understanding." .
#
# # Properties
# ex:believesAttainedSatisfaction a owl:ObjectProperty ;
#     rdfs:label "believes attained satisfaction" ;
#     rdfs:comment "Indicates that the understanding believes it has attained satisfaction in the reconciliation of truth." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Truth .
#
# ex:entangledIn a owl:ObjectProperty ;
#     rdfs:label "entangled in" ;
#     rdfs:comment "Indicates that the understanding is entangled in unreconciled, unresolved, absolute contradictions." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Contradiction .
#
# ex:fallsInto a owl:ObjectProperty ;
#     rdfs:label "falls into" ;
#     rdfs:comment "Indicates that the understanding falls into contradictions whenever it applies and explicates its categories." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Contradiction .
#
# ex:appliesAndExplicates a owl:ObjectProperty ;
#     rdfs:label "applies and explicates" ;
#     rdfs:comment "Indicates that the understanding applies and explicates its categories." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Category .
#
# ex:mustBecomeConsciousOf a owl:ObjectProperty ;
#     rdfs:label "must become conscious of" ;
#     rdfs:comment "Indicates that the understanding must become conscious of the contradictions into which it falls." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Contradiction .
#
# # Individuals
# ex:understanding a ex:Understanding ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "An individual representing the understanding in Hegelian philosophy." .
#
# ex:truth a ex:Truth ;
#     rdfs:label "Truth" ;
#     rdfs:comment "An individual representing the concept of truth." .
#
# ex:contradiction a ex:Contradiction ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "An individual representing the concept of contradiction." .
#
# ex:category a ex:Category ;
#     rdfs:label "Category" ;
#     rdfs:comment "An individual representing the categories of the understanding." .
#
# # Relationships
# ex:Understanding ex:believesAttainedSatisfaction ex:truth ;
#     ex:entangledIn ex:contradiction ;
#     ex:fallsInto ex:contradiction ;
#     ex:appliesAndExplicates ex:category ;
#     ex:mustBecomeConsciousOf ex:contradiction .

# %% [markdown]
#     This contradiction is present in the very fact
#     that the infinite remains over against the finite,
#     with the result that there are two determinacies.
#     There are two worlds, one infinite and one finite,
#     and in their connection the infinite is only
#     the limit of the finite and thus only a determinate,
#     itself finite infinite.

# %% [markdown]
# 1. **Inherent Contradiction in Infinite-Finite Relation**: The transcreation underscores the contradiction of the infinite being opposed to the finite.
#
# 2. **Coexistence of Two Realms**: It emphasizes the existence of two separate 'worlds' – the infinite and the finite.
#
# 3. **Infinite as Finite Limit**: The translation points out the paradox where the infinite, in relation to the finite, becomes just another finite limit.
#
# 4. **Conceptual Problem of 'Finite Infinite'**: The text highlights the conceptual issue in treating the infinite as a bounded entity, a 'finite infinite.'

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Contradiction a owl:Class ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "A class representing the concept of contradiction." .
#
# ex:Determinacy a owl:Class ;
#     rdfs:label "Determinacy" ;
#     rdfs:comment "A class representing a determinate quality or characteristic." .
#
# ex:World a owl:Class ;
#     rdfs:label "World" ;
#     rdfs:comment "A class representing a world, either infinite or finite." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing a limit, the boundary of the finite." .
#
# # Properties
# ex:remainsOverAgainst a owl:ObjectProperty ;
#     rdfs:label "remains over against" ;
#     rdfs:comment "Indicates that the infinite remains over against the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:resultsIn a owl:ObjectProperty ;
#     rdfs:label "results in" ;
#     rdfs:comment "Indicates that the contradiction results in two determinacies." ;
#     rdfs:domain ex:Contradiction ;
#     rdfs:range ex:Determinacy .
#
# ex:twoWorlds a owl:ObjectProperty ;
#     rdfs:label "two worlds" ;
#     rdfs:comment "Indicates that there are two worlds, one infinite and one finite." ;
#     rdfs:domain ex:World ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# ex:connectionOf a owl:ObjectProperty ;
#     rdfs:label "connection of" ;
#     rdfs:comment "Indicates the connection between the infinite and the finite." ;
#     rdfs:domain ex:World ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# ex:limitOf a owl:ObjectProperty ;
#     rdfs:label "limit of" ;
#     rdfs:comment "Indicates that the infinite is the limit of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:finiteInfinite a owl:ObjectProperty ;
#     rdfs:label "finite infinite" ;
#     rdfs:comment "Indicates that the infinite, as a determinate, is itself finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:contradiction a ex:Contradiction ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "An individual representing the concept of contradiction." .
#
# ex:determinacy a ex:Determinacy ;
#     rdfs:label "Determinacy" ;
#     rdfs:comment "An individual representing a determinate quality or characteristic." .
#
# ex:world a ex:World ;
#     rdfs:label "World" ;
#     rdfs:comment "An individual representing a world, either infinite or finite." .
#
# ex:limit a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing a limit, the boundary of the finite." .
#
# # Relationships
# ex:Infinite ex:remainsOverAgainst ex:Finite ;
#     ex:limitOf ex:Finite ;
#     ex:finiteInfinite ex:Finite .
#
# ex:Contradiction ex:resultsIn ex:determinacy .
#
# ex:World ex:twoWorlds ex:infinite, ex:finite ;
#     ex:connectionOf ex:infinite, ex:finite .

# %% [markdown]
#     This contradiction develops its content into more explicit forms.
#     The finite is the real existence which persists as such
#     even when it has gone over into its non-being, the infinite.
#     As we have seen, this infinite has for its determinateness,
#     over against the finite,
#     only the first, immediate negation,
#     just as the finite, as negated,
#     has over against this negation
#     only the meaning of an other
#     and is, therefore, still a something.

# %% [markdown]
# 1. **Development of Contradiction**: The transcreation emphasizes how the contradiction between the finite and infinite becomes more explicitly defined.
#
# 2. **Persistence of the Finite**: It highlights that the finite continues to exist, even as it transitions into the infinite.
#
# 3. **Infinite as Immediate Negation**: The translation illustrates that the infinite's primary characteristic in relation to the finite is immediate negation.
#
# 4. **Finite as a Distinct 'Other'**: The text underscores that the finite, even when negated, maintains its identity as an 'other' against the infinite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Contradiction a owl:Class ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "A class representing the concept of contradiction." .
#
# ex:NonBeing a owl:Class ;
#     rdfs:label "Non-Being" ;
#     rdfs:comment "A class representing the non-being of the finite." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing the concept of negation." .
#
# ex:Other a owl:Class ;
#     rdfs:label "Other" ;
#     rdfs:comment "A class representing the meaning of an other." .
#
# ex:Something a owl:Class ;
#     rdfs:label "Something" ;
#     rdfs:comment "A class representing something determinate." .
#
# # Properties
# ex:developsContentInto a owl:ObjectProperty ;
#     rdfs:label "develops content into" ;
#     rdfs:comment "Indicates that the contradiction develops its content into more explicit forms." ;
#     rdfs:domain ex:Contradiction ;
#     rdfs:range ex:Content .
#
# ex:persistAs a owl:ObjectProperty ;
#     rdfs:label "persists as" ;
#     rdfs:comment "Indicates that the finite persists as real existence even when it has gone over into its non-being, the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:RealExistence .
#
# ex:goneOverInto a owl:ObjectProperty ;
#     rdfs:label "gone over into" ;
#     rdfs:comment "Indicates that the finite goes over into its non-being, the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:NonBeing .
#
# ex:hasDeterminatenessOverAgainst a owl:ObjectProperty ;
#     rdfs:label "has determinateness over against" ;
#     rdfs:comment "Indicates that the infinite has for its determinateness the first, immediate negation over against the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:negatedHasMeaningOf a owl:ObjectProperty ;
#     rdfs:label "negated has meaning of" ;
#     rdfs:comment "Indicates that the finite, as negated, has the meaning of an other over against this negation." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Other .
#
# ex:stillASomething a owl:ObjectProperty ;
#     rdfs:label "still a something" ;
#     rdfs:comment "Indicates that the finite is still a something." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Something .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:contradiction a ex:Contradiction ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "An individual representing the concept of contradiction." .
#
# ex:nonBeing a ex:NonBeing ;
#     rdfs:label "Non-Being" ;
#     rdfs:comment "An individual representing the non-being of the finite." .
#
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the concept of negation." .
#
# ex:other a ex:Other ;
#     rdfs:label "Other" ;
#     rdfs:comment "An individual representing the meaning of an other." .
#
# ex:something a ex:Something ;
#     rdfs:label "Something" ;
#     rdfs:comment "An individual representing something determinate." .
#
# # Relationships
# ex:Contradiction ex:developsContentInto ex:Content .
#
# ex:Finite ex:persistAs ex:RealExistence ;
#     ex:goneOverInto ex:NonBeing ;
#     ex:negatedHasMeaningOf ex:Other ;
#     ex:stillASomething ex:Something .
#
# ex:Infinite ex:hasDeterminatenessOverAgainst ex:Finite .
#
# ex:Negation ex:negatedHasMeaningOf ex:Other .

# %% [markdown]
#     When, therefore, the understanding,
#     elevating itself above this finite world,
#     rises to what is the highest for it,
#     to the infinite,
#     the finite world remains for it
#     as something on this side here,
#     and, thus posited only above the finite,
#     the infinite is separated from the finite
#     and, for the same reason,
#     the finite from the infinite:
#     each is placed in a different location,
#     the finite as existence here,
#     and the infinite, although the being-in-itself of the finite,
#     there as a beyond, at a nebulous, inaccessible distance
#     outside which there stands, enduring, the finite.

# %% [markdown]
# 1. **Understanding's Elevation to the Infinite**: The transcreation emphasizes the understanding's attempt to transcend the finite and reach the infinite.
#
# 2. **Separation of Finite and Infinite**: It highlights the resultant separation, placing the finite and infinite in distinct realms.
#
# 3. **Finite as Immediate Existence**: The translation points out that the finite is seen as existing in the immediate, tangible world.
#
# 4. **Infinite as Distant Beyond**: The text describes the infinite as being perceived as a distant, nebulous realm, despite its intrinsic connection to the finite.
#
# 5. **Critique of Dualistic View**: The aim is to present Hegel's critique of the understanding's dualistic separation of the finite and infinite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Understanding a owl:Class ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "A class representing the understanding in Hegelian philosophy." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Highest a owl:Class ;
#     rdfs:label "Highest" ;
#     rdfs:comment "A class representing the highest concept for the understanding." .
#
# ex:Beyond a owl:Class ;
#     rdfs:label "Beyond" ;
#     rdfs:comment "A class representing the infinite as a nebulous, inaccessible distance." .
#
# # Properties
# ex:elevatesAbove a owl:ObjectProperty ;
#     rdfs:label "elevates above" ;
#     rdfs:comment "Indicates that the understanding elevates itself above the finite world." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Finite .
#
# ex:risesTo a owl:ObjectProperty ;
#     rdfs:label "rises to" ;
#     rdfs:comment "Indicates that the understanding rises to the infinite, the highest for it." ;
#     rdfs:domain ex:Understanding ;
#     rdfs:range ex:Highest .
#
# ex:separatedFrom a owl:ObjectProperty ;
#     rdfs:label "separated from" ;
#     rdfs:comment "Indicates that the infinite is separated from the finite and vice versa." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:placedInDifferentLocation a owl:ObjectProperty ;
#     rdfs:label "placed in different location" ;
#     rdfs:comment "Indicates that the finite and infinite are placed in different locations." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:existsHere a owl:ObjectProperty ;
#     rdfs:label "exists here" ;
#     rdfs:comment "Indicates that the finite exists here as existence." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Location .
#
# ex:inaccessibleDistance a owl:ObjectProperty ;
#     rdfs:label "inaccessible distance" ;
#     rdfs:comment "Indicates that the infinite is at a nebulous, inaccessible distance." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Beyond .
#
# ex:beingInItselfOf a owl:ObjectProperty ;
#     rdfs:label "being-in-itself of" ;
#     rdfs:comment "Indicates that the infinite is the being-in-itself of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# # Individuals
# ex:understanding a ex:Understanding ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "An individual representing the understanding in Hegelian philosophy." .
#
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:highest a ex:Highest ;
#     rdfs:label "Highest" ;
#     rdfs:comment "An individual representing the highest concept for the understanding." .
#
# ex:beyond a ex:Beyond ;
#     rdfs:label "Beyond" ;
#     rdfs:comment "An individual representing the infinite as a nebulous, inaccessible distance." .
#
# # Relationships
# ex:Understanding ex:elevatesAbove ex:Finite ;
#     ex:risesTo ex:highest .
#
# ex:Infinite ex:separatedFrom ex:Finite ;
#     ex:beingInItselfOf ex:Finite ;
#     ex:inaccessibleDistance ex:beyond .
#
# ex:Finite ex:placedInDifferentLocation ex:Infinite ;
#     ex:existsHere ex:Location .

# %% [markdown]
#     As thus separated, they are just as much
#     essentially connected with each other,
#     through the very negation that divides them.
#     This negation connecting them
#     (these somethings reflected into themselves)
#     is the common limit of each over against the other;
#     and that, too, in such a way that each
#     does not merely have this limit in it over against the other,
#     but the negation is rather the in-itselfness of each;
#     each thus has for itself, in its separation
#     from the other, the limit in it.

# %% [markdown]
# 1. **Essential Connection Despite Separation**: The transcreation emphasizes the deep, essential connection between the finite and the infinite, even in their separation.
#
# 2. **Negation as Common Limit**: It highlights that the negation which divides them also serves as a common boundary, linking them together.
#
# 3. **Intrinsic Nature of Negation**: The translation points out that this negation is not merely an external boundary but an intrinsic part of each entity's essence.
#
# 4. **Internalization of the Limit**: The text shows that in their separation, both the finite and the infinite internalize this limit or negation.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing the concept of negation." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing the common limit between the infinite and the finite." .
#
# # Properties
# ex:connectedWith a owl:ObjectProperty ;
#     rdfs:label "connected with" ;
#     rdfs:comment "Indicates that the infinite and finite are essentially connected through negation." ;
#     rdfs:domain ex:Infinite, ex:Finite ;
#     rdfs:range ex:Negation .
#
# ex:negationDividesAndConnects a owl:ObjectProperty ;
#     rdfs:label "negation divides and connects" ;
#     rdfs:comment "Indicates that the negation both divides and connects the infinite and finite." ;
#     rdfs:domain ex:Negation ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# ex:commonLimitOf a owl:ObjectProperty ;
#     rdfs:label "common limit of" ;
#     rdfs:comment "Indicates that the limit is the common boundary of the infinite and finite." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# ex:inItselfnessOf a owl:ObjectProperty ;
#     rdfs:label "in-itselfness of" ;
#     rdfs:comment "Indicates that the negation is the in-itselfness of both the infinite and finite." ;
#     rdfs:domain ex:Negation ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# ex:hasLimitInSeparationFrom a owl:ObjectProperty ;
#     rdfs:label "has limit in separation from" ;
#     rdfs:comment "Indicates that each has the limit within itself in its separation from the other." ;
#     rdfs:domain ex:Infinite, ex:Finite ;
#     rdfs:range ex:Limit .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the concept of negation." .
#
# ex:limit a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the common limit between the infinite and the finite." .
#
# # Relationships
# ex:Infinite ex:connectedWith ex:negation ;
#     ex:hasLimitInSeparationFrom ex:limit .
#
# ex:Finite ex:connectedWith ex:negation ;
#     ex:hasLimitInSeparationFrom ex:limit .
#
# ex:Negation ex:negationDividesAndConnects ex:infinite, ex:finite ;
#     ex:inItselfnessOf ex:infinite, ex:finite .
#
# ex:Limit ex:commonLimitOf ex:infinite, ex:finite .

# %% [markdown]
#     But the limit is the first negation;
#     both are thus limited, finite, in themselves.
#     Yet, as each affirmatively refers itself to itself,
#     each is also the negation of its limit;
#     each thus immediately repels
#     the negation from itself as its non-being,
#     and, qualitatively severed from it,
#     posits it as an other being outside it:
#     the finite posits its non-being as this infinite,
#     and the infinite likewise the finite.

# %% [markdown]
# 1. **Limit as First Negation**: The transcreation emphasizes that the limit acts as the first negation, making both entities inherently finite.
#
# 2. **Self-Affirmation and Negation of Limit**: It highlights that by affirmatively referring to themselves, both the finite and infinite negate their own limits.
#
# 3. **Repulsion of Non-Being**: The translation illustrates that each entity repels this negation, viewing it as its non-being, and separates itself from it.
#
# 4. **Projection as 'Other'**: The text shows that this repulsion leads to the projection of the negation as an 'other' outside each entity.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Something a owl:Class ;
#     rdfs:label "Something" ;
#     rdfs:comment "A class representing something determinate." .
#
# ex:Other a owl:Class ;
#     rdfs:label "Other" ;
#     rdfs:comment "A class representing the meaning of an other." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing the concept of negation." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing the common limit between the infinite and the finite." .
#
# # Properties
# ex:connectedWith a owl:ObjectProperty ;
#     rdfs:label "connected with" ;
#     rdfs:comment "Indicates that the infinite and finite are essentially connected through negation." ;
#     rdfs:domain ex:Infinite, ex:Finite ;
#     rdfs:range ex:Negation .
#
# ex:negationDividesAndConnects a owl:ObjectProperty ;
#     rdfs:label "negation divides and connects" ;
#     rdfs:comment "Indicates that the negation both divides and connects the infinite and finite." ;
#     rdfs:domain ex:Negation ;
#     rdfs:range ex:Infinite, ex:Finite .
#
# ex:commonLimitOf a owl:ObjectProperty ;
#     rdfs:label "common limit of" ;
#     rdfs:comment "Indicates that the limit is the common boundary of something and other." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Something, ex:Other .
#
# ex:sublatedInto a owl:ObjectProperty ;
#     rdfs:label "sublated into" ;
#     rdfs:comment "Indicates that something and other are sublated into infinity." ;
#     rdfs:domain ex:Something, ex:Other ;
#     rdfs:range ex:Infinite .
#
# ex:hasLimitInSeparationFrom a owl:ObjectProperty ;
#     rdfs:label "has limit in separation from" ;
#     rdfs:comment "Indicates that each has the limit within itself in its separation from the other." ;
#     rdfs:domain ex:Infinite, ex:Finite ;
#     rdfs:range ex:Limit .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:something a ex:Something ;
#     rdfs:label "Something" ;
#     rdfs:comment "An individual representing something determinate." .
#
# ex:other a ex:Other ;
#     rdfs:label "Other" ;
#     rdfs:comment "An individual representing the meaning of an other." .
#
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the concept of negation." .
#
# ex:limit a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the common limit between something and other." .
#
# # Relationships
# ex:Infinite ex:connectedWith ex:negation ;
#     ex:hasLimitInSeparationFrom ex:limit .
#
# ex:Finite ex:connectedWith ex:negation ;
#     ex:hasLimitInSeparationFrom ex:limit .
#
# ex:Negation ex:negationDividesAndConnects ex:infinite, ex:finite .
#
# ex:Limit ex:commonLimitOf ex:something, ex:other .
#
# ex:Something ex:sublatedInto ex:infinite .
#
# ex:Other ex:sublatedInto ex:infinite .

# %% [markdown]
#     It is readily conceded that the
#     finite passes over into the infinite necessarily
#     (that is, through its determination)
#     and is thereby elevated to what is its in-itself,
#     for while the finite is indeed determined as subsistent existence,
#     it is at the same time also a null in itself
#     and therefore destined to self-dissolution;
#     whereas the infinite, although burdened with negation and limit,
#     is equally also determined as the existent in-itself,
#     so that this abstraction of self-referring affirmation is
#     what constitutes its determination,
#     and hence finite existence is not present in it.

# %% [markdown]
# 1. **Inevitable Transition of Finite to Infinite**: The transcreation emphasizes the widely accepted view of the finite's necessary transition into the infinite.
#
# 2. **Finite's Dual Nature**: It highlights that the finite is both a subsisting existence and a nullity destined for self-dissolution.
#
# 3. **Infinite as Existent 'In-Itself'**: The translation underlines that the infinite is defined as the existent 'in-itself,' distinguished by self-affirmation.
#
# 4. **Self-Referring Affirmation of the Infinite**: The text points out that the infinite's identity is constituted by its self-referential affirmation.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing the concept of negation." .
#
# ex:Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "A class representing existence." .
#
# ex:SelfDissolution a owl:Class ;
#     rdfs:label "Self-Dissolution" ;
#     rdfs:comment "A class representing the self-dissolution of the finite." .
#
# # Properties
# ex:passesOverInto a owl:ObjectProperty ;
#     rdfs:label "passes over into" ;
#     rdfs:comment "Indicates that the finite necessarily passes over into the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:elevatedTo a owl:ObjectProperty ;
#     rdfs:label "elevated to" ;
#     rdfs:comment "Indicates that the finite is elevated to its in-itself." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Existence .
#
# ex:determinedAs a owl:ObjectProperty ;
#     rdfs:label "determined as" ;
#     rdfs:comment "Indicates the determination of the finite and infinite." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Existence .
#
# ex:nullInItself a owl:ObjectProperty ;
#     rdfs:label "null in itself" ;
#     rdfs:comment "Indicates that the finite is a null in itself and destined to self-dissolution." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:SelfDissolution .
#
# ex:burdenedWith a owl:ObjectProperty ;
#     rdfs:label "burdened with" ;
#     rdfs:comment "Indicates that the infinite is burdened with negation and limit." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Negation, ex:Limit .
#
# ex:existentInItself a owl:ObjectProperty ;
#     rdfs:label "existent in-itself" ;
#     rdfs:comment "Indicates that the infinite is determined as the existent in-itself." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Existence .
#
# ex:selfReferringAffirmation a owl:ObjectProperty ;
#     rdfs:label "self-referring affirmation" ;
#     rdfs:comment "Indicates that the infinite is determined by self-referring affirmation." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Existence .
#
# ex:finiteExistenceNotPresent a owl:ObjectProperty ;
#     rdfs:label "finite existence not present" ;
#     rdfs:comment "Indicates that finite existence is not present in the infinite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the concept of negation." .
#
# ex:existence a ex:Existence ;
#     rdfs:label "Existence" ;
#     rdfs:comment "An individual representing existence." .
#
# ex:selfDissolution a ex:SelfDissolution ;
#     rdfs:label "Self-Dissolution" ;
#     rdfs:comment "An individual representing the self-dissolution of the finite." .
#
# # Relationships
# ex:Finite ex:passesOverInto ex:Infinite ;
#     ex:elevatedTo ex:existence ;
#     ex:determinedAs ex:existence ;
#     ex:nullInItself ex:selfDissolution .
#
# ex:Infinite ex:burdenedWith ex:negation ;
#     ex:existentInItself ex:existence ;
#     ex:selfReferringAffirmation ex:existence ;
#     ex:finiteExistenceNotPresent ex:finite .

# %% [markdown]
#     But it has been shown that the infinite itself
#     attains affirmative being only by the mediation of negation,
#     as negation of negation,
#     and that when its affirmation thus attained is
#     taken as just simple, qualitative being,
#     the negation contained in it is demoted
#     to simple immediate negation
#     and, therefore, to determinateness and limit;
#     and these, then, are excluded from the infinite
#     as contradicting its in-itself;
#     they are posited as not belonging to it
#     but rather as opposed to its in-itself,
#     as the finite.

# %% [markdown]
# 1. **Infinite's Affirmation via Negation**: The transcreation emphasizes that the infinite achieves its affirmative state through negating negation.
#
# 2. **Reduction of Negation to Determinateness**: It highlights that in its simplest form, the negation within the infinite is demoted to immediate negation, seen as determinateness and limit.
#
# 3. **Exclusion of Limits from the Infinite**: The translation points out that these limiting aspects are viewed as contradictory to the infinite's true essence.
#
# 4. **Finite as Opposed to Infinite's In-Itself**: The text illustrates that the finite is positioned in contrast to the infinite, embodying the limitations and determinacies that the infinite surpasses.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing the infinite in Hegelian philosophy." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing the finite in Hegelian philosophy." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "A class representing the concept of negation." .
#
# ex:AffirmativeBeing a owl:Class ;
#     rdfs:label "Affirmative Being" ;
#     rdfs:comment "A class representing the affirmative being attained by the mediation of negation." .
#
# ex:DeterminateNegation a owl:Class ;
#     rdfs:label "Determinate Negation" ;
#     rdfs:comment "A class representing the negation contained in the infinite, demoted to simple immediate negation." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing the limit excluded from the infinite." .
#
# # Properties
# ex:attainsAffirmativeBeingThrough a owl:ObjectProperty ;
#     rdfs:label "attains affirmative being through" ;
#     rdfs:comment "Indicates that the infinite attains affirmative being through the mediation of negation." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Negation .
#
# ex:negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that the infinite's affirmative being is attained as the negation of negation." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Negation .
#
# ex:containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that the infinite contains negation within its affirmation." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:DeterminateNegation .
#
# ex:demotedTo a owl:ObjectProperty ;
#     rdfs:label "demoted to" ;
#     rdfs:comment "Indicates that the negation is demoted to simple immediate negation." ;
#     rdfs:domain ex:Negation ;
#     rdfs:range ex:DeterminateNegation .
#
# ex:excludedFrom a owl:ObjectProperty ;
#     rdfs:label "excluded from" ;
#     rdfs:comment "Indicates that determinateness and limit are excluded from the infinite." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Infinite .
#
# ex:opposedToInItself a owl:ObjectProperty ;
#     rdfs:label "opposed to in-itself" ;
#     rdfs:comment "Indicates that determinateness and limit are opposed to the in-itself of the infinite." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Infinite .
#
# ex:positedAsFinite a owl:ObjectProperty ;
#     rdfs:label "posited as finite" ;
#     rdfs:comment "Indicates that determinateness and limit are posited as the finite." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Finite .
#
# # Individuals
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite in Hegelian philosophy." .
#
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite in Hegelian philosophy." .
#
# ex:negation a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the concept of negation." .
#
# ex:affirmativeBeing a ex:AffirmativeBeing ;
#     rdfs:label "Affirmative Being" ;
#     rdfs:comment "An individual representing the affirmative being attained by the mediation of negation." .
#
# ex:determinateNegation a ex:DeterminateNegation ;
#     rdfs:label "Determinate Negation" ;
#     rdfs:comment "An individual representing the negation contained in the infinite, demoted to simple immediate negation." .
#
# ex:limit a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the limit excluded from the infinite." .
#
# # Relationships
# ex:Infinite ex:attainsAffirmativeBeingThrough ex:negation ;
#     ex:negationOfNegation ex:negation ;
#     ex:containsNegation ex:determinateNegation .
#
# ex:Negation ex:demotedTo ex:determinateNegation .
#
# ex:Limit ex:excludedFrom ex:infinite ;
#     ex:opposedToInItself ex:infinite ;
#     ex:positedAsFinite ex:finite .

# %% [markdown]
#     Since each is in it and through its determination
#     the positing of its other, the two are inseparable.
#     But this unity rests hidden in their qualitative otherness;
#     it is their inner unity, one that lies only at their base.

# %% [markdown]
# 1. **Inseparable Link through Determination**: The transcreation emphasizes that the finite and infinite are inseparably interconnected through their mutual determinations.
#
# 2. **Hidden Unity Amidst Qualitative Otherness**: It highlights the concealed unity that underlies their qualitative differences.
#
# 3. **Inner Unity at the Base**: The translation points out that this unity is an inner, foundational aspect of their relationship, not immediately apparent.
#
# 4. **Contrast with Apparent Distinctness**: The text contrasts this hidden unity with the visible distinctness and opposition of the finite and infinite.

# %% [markdown]
#     The manner of the appearance of this unity has thereby been defined.
#     The unity is posited in existence as a turning over
#     or transition of the finite into the infinite, and vice-versa;
#     so that the infinite only emerges in the finite,
#     and the finite in the infinite,
#     the other in the other;
#     that is to say, each arises in the other
#     independently and immediately,
#     and their connection is only an external one.

# %% [markdown]
# 1. **Transformation and Transition**: The transcreation emphasizes the ongoing process of the finite turning into the infinite and vice versa.
#
# 2. **Mutual Emergence**: It highlights how the infinite and finite emerge within each other, each manifesting in the other.
#
# 3. **Independence and Immediacy**: The translation illustrates the spontaneous and independent nature of their mutual emergence.
#
# 4. **Perceived External Connection**: The text points out that despite their intertwined relationship, their connection is often seen as external rather than intrinsic.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing Finitude or the finite." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing Infinity or the infinite." .
#
# ex:Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "A class representing the unity of the finite and the infinite." .
#
# # Properties
# ex:transitionsTo a owl:ObjectProperty ;
#     rdfs:label "transitions to" ;
#     rdfs:comment "Indicates the transition of the finite into the infinite, and vice-versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:emergesIn a owl:ObjectProperty ;
#     rdfs:label "emerges in" ;
#     rdfs:comment "Indicates that the infinite emerges in the finite, and vice-versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:externalConnectionWith a owl:ObjectProperty ;
#     rdfs:label "external connection with" ;
#     rdfs:comment "Indicates the external connection between the finite and the infinite." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:hasUnity a owl:ObjectProperty ;
#     rdfs:label "has unity" ;
#     rdfs:comment "Indicates that the finite and the infinite have an underlying unity." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Unity .
#
# # Individuals
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:unity1 a ex:Unity ;
#     rdfs:label "Unity" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." .
#
# # Relationships
# ex:finite ex:transitionsTo ex:infinite ;
#     ex:emergesIn ex:infinite ;
#     ex:externalConnectionWith ex:infinite ;
#     ex:hasUnity ex:unity1 .
#
# ex:infinite ex:transitionsTo ex:finite ;
#     ex:emergesIn ex:finite ;
#     ex:externalConnectionWith ex:finite ;
#     ex:hasUnity ex:unity1 .

# %% [markdown]
#     The process of their transition
#     has the following, detailed shape.
#     We have the finite passing over into the infinite.
#     This passing over appears as an external doing.
#     In this emptiness beyond the finite, what arises?
#     What is there of positive in it?
#     On account of the inseparability of the infinite and the finite
#     (or because this infinite, which stands apart, is itself restricted),
#     the limit arises.

# %% [markdown]
# 1. **Finite's Transition to Infinite**: The transcreation focuses on the process of the finite passing over into the infinite, appearing as an external action.
#
# 2. **Emergence of the Limit**: It highlights the emergence of the limit within the infinite, due to the inseparability of the infinite and finite.
#
# 3. **Infinite's Inherent Restriction**: The translation underscores that even the infinite, perceived as limitless, inherently contains a form of limitation.
#
# 4. **Redefinition of the Limit**: The text illustrates that the concept of the limit is not abolished but transformed in the transition from finite to infinite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing Finitude or the finite." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing Infinity or the infinite." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing the limit that arises from the transition between the finite and the infinite." .
#
# ex:Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "A class representing the unity of the finite and the infinite." .
#
# # Properties
# ex:transitionsTo a owl:ObjectProperty ;
#     rdfs:label "transitions to" ;
#     rdfs:comment "Indicates the transition of the finite into the infinite, and vice-versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:emergesIn a owl:ObjectProperty ;
#     rdfs:label "emerges in" ;
#     rdfs:comment "Indicates that the infinite emerges in the finite, and vice-versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:externalConnectionWith a owl:ObjectProperty ;
#     rdfs:label "external connection with" ;
#     rdfs:comment "Indicates the external connection between the finite and the infinite." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:hasUnity a owl:ObjectProperty ;
#     rdfs:label "has unity" ;
#     rdfs:comment "Indicates that the finite and the infinite have an underlying unity." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Unity .
#
# ex:arisesFrom a owl:ObjectProperty ;
#     rdfs:label "arises from" ;
#     rdfs:comment "Indicates that the limit arises from the inseparability of the finite and the infinite." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Unity .
#
# # Individuals
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:limit1 a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the limit." .
#
# ex:unity1 a ex:Unity ;
#     rdfs:label "Unity" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." .
#
# # Relationships
# ex:finite ex:transitionsTo ex:infinite ;
#     ex:emergesIn ex:infinite ;
#     ex:externalConnectionWith ex:infinite ;
#     ex:hasUnity ex:unity1 .
#
# ex:infinite ex:transitionsTo ex:finite ;
#     ex:emergesIn ex:finite ;
#     ex:externalConnectionWith ex:finite ;
#     ex:hasUnity ex:unity1 .
#
# ex:limit1 ex:arisesFrom ex:unity1 .

# %% [markdown]
#     The infinite has vanished and the other,
#     the finite, has stepped in.
#     But this stepping in of the finite appears
#     as an event external to the infinite,
#     and the new limit as something that does not arise
#     out of the infinite itself but is likewise found given.

# %% [markdown]
# 1. **Vanishing of the Infinite**: The transcreation emphasizes the concept of the infinite disappearing and being replaced by the finite.
#
# 2. **Finite's External Emergence**: It highlights the perception that the finite's emergence is an external event, separate from the infinite.
#
# 3. **Externally Imposed New Limit**: The translation points out that the new limit arising with the finite is seen as externally given, not derived from the infinite.
#
# 4. **Dichotomy in Perception**: The text illustrates the dichotomous view that separates the processes of the infinite and finite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "A class representing Finitude or the finite." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "A class representing Infinity or the infinite." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing the limit that arises from the transition between the finite and the infinite." .
#
# ex:Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "A class representing the unity of the finite and the infinite." .
#
# # Properties
# ex:transitionsTo a owl:ObjectProperty ;
#     rdfs:label "transitions to" ;
#     rdfs:comment "Indicates the transition of the finite into the infinite, and vice-versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:emergesIn a owl:ObjectProperty ;
#     rdfs:label "emerges in" ;
#     rdfs:comment "Indicates that the infinite emerges in the finite, and vice-versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:externalConnectionWith a owl:ObjectProperty ;
#     rdfs:label "external connection with" ;
#     rdfs:comment "Indicates the external connection between the finite and the infinite." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:hasUnity a owl:ObjectProperty ;
#     rdfs:label "has unity" ;
#     rdfs:comment "Indicates that the finite and the infinite have an underlying unity." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Unity .
#
# ex:arisesExternally a owl:ObjectProperty ;
#     rdfs:label "arises externally" ;
#     rdfs:comment "Indicates that the limit arises externally, not from the infinite itself." ;
#     rdfs:domain ex:Limit ;
#     rdfs:range ex:Infinite .
#
# ex:stepsIn a owl:ObjectProperty ;
#     rdfs:label "steps in" ;
#     rdfs:comment "Indicates that the finite steps in when the infinite vanishes." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# # Individuals
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:limit1 a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the limit." .
#
# ex:unity1 a ex:Unity ;
#     rdfs:label "Unity" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." .
#
# # Relationships
# ex:finite ex:transitionsTo ex:infinite ;
#     ex:emergesIn ex:infinite ;
#     ex:externalConnectionWith ex:infinite ;
#     ex:hasUnity ex:unity1 ;
#     ex:stepsIn ex:infinite .
#
# ex:infinite ex:transitionsTo ex:finite ;
#     ex:emergesIn ex:finite ;
#     ex:externalConnectionWith ex:finite ;
#     ex:hasUnity ex:unity1 .
#
# ex:limit1 ex:arisesExternally ex:infinite ;

# %% [markdown]
#     And with this we are back at the previous determination,
#     which has been sublated in vain.
#     This new limit, however, is itself only
#     something to be sublated or transcended.
#     And so there arises again the emptiness, the nothing,
#     in which we find again the said determination,
#     and so forth to infinity.

# %% [markdown]
# 1. **Cyclical Return to Previous Determination**: The transcreation emphasizes the recurring return to a previously sublated determination.
#
# 2. **New Limit as Transitory**: It highlights that each new limit is itself destined to be transcended or sublated.
#
# 3. **Recurring Emergence of Emptiness**: The translation points out the repeated emergence of 'nothingness' or emptiness with each cycle.
#
# 4. **Endless Progression to Infinity**: The text illustrates the infinite progression that results from this continuous cycle of transcending and returning.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Determination a owl:Class ;
#     rdfs:label "Determination" ;
#     rdfs:comment "A class representing a specific determination." .
#
# ex:Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "A class representing the process of sublation or transcendence." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "A class representing the limit that arises from the transition between the finite and the infinite." .
#
# ex:Emptiness a owl:Class ;
#     rdfs:label "Emptiness" ;
#     rdfs:comment "A class representing the emptiness or nothingness that arises." .
#
# ex:Infinity a owl:Class ;
#     rdfs:label "Infinity" ;
#     rdfs:comment "A class representing Infinity or the infinite." .
#
# # Properties
# ex:transitionsTo a owl:ObjectProperty ;
#     rdfs:label "transitions to" ;
#     rdfs:comment "Indicates the transition of determination to sublation." ;
#     rdfs:domain ex:Determination ;
#     rdfs:range ex:Sublation .
#
# ex:sublates a owl:ObjectProperty ;
#     rdfs:label "sublates" ;
#     rdfs:comment "Indicates that a limit is sublated or transcended." ;
#     rdfs:domain ex:Sublation ;
#     rdfs:range ex:Limit .
#
# ex:resultsIn a owl:ObjectProperty ;
#     rdfs:label "results in" ;
#     rdfs:comment "Indicates that sublation results in emptiness." ;
#     rdfs:domain ex:Sublation ;
#     rdfs:range ex:Emptiness .
#
# ex:containsDetermination a owl:ObjectProperty ;
#     rdfs:label "contains determination" ;
#     rdfs:comment "Indicates that emptiness contains the said determination." ;
#     rdfs:domain ex:Emptiness ;
#     rdfs:range ex:Determination .
#
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that the process leads to infinity." ;
#     rdfs:domain ex:Emptiness ;
#     rdfs:range ex:Infinity .
#
# # Individuals
# ex:determination1 a ex:Determination ;
#     rdfs:label "Determination" ;
#     rdfs:comment "An individual representing a specific determination." .
#
# ex:sublation1 a ex:Sublation ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "An individual representing the process of sublation." ;
#     ex:sublates ex:limit1 ;
#     ex:resultsIn ex:emptiness1 .
#
# ex:limit1 a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the limit." .
#
# ex:emptiness1 a ex:Emptiness ;
#     rdfs:label "Emptiness" ;
#     rdfs:comment "An individual representing the emptiness." ;
#     ex:containsDetermination ex:determination1 ;
#     ex:leadsTo ex:infinity1 .
#
# ex:infinity1 a ex:Infinity ;
#     rdfs:label "Infinity" ;
#     rdfs:comment "An individual representing infinity." .
#
# # Relationships
# ex:determination1 ex:transitionsTo ex:sublation1 .
# ex:sublation1 ex:sublates ex:limit1 .
# ex:sublation1 ex:resultsIn ex:emptiness1 .
# ex:emptiness1 ex:containsDetermination ex:determination1 .
# ex:emptiness1 ex:leadsTo ex:infinity1 .

# %% [markdown]
#     We have before us the alternating determination
#     of the finite and the infinite;
#     the finite is finite only with reference
#     to the ought or the infinite,
#     and the infinite is only infinite with reference to the finite.
#     The two are inseparable and at the same time
#     absolutely other with respect to each other;
#     each has in it the other of itself;
#     each is thus the unity of itself and its other,
#     and, in its determinateness not to be
#     what itself and what its other is:
#     it is existence.

# %% [markdown]
# 1. **Mutual Dependence of Finite and Infinite**: The transcreation underscores the interdependent relationship between the finite and the infinite.
#
# 2. **Inseparability Yet Distinctness**: It highlights that while they are inseparable, they are also absolutely distinct from each other.
#
# 3. **Unity of Opposites**: The translation illustrates that each contains the essence of its opposite, forming a unity of itself and its other.
#
# 4. **Existence as a Paradoxical Nature**: The text depicts existence as a paradox where each entity is both itself and its opposite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents existence, the unity of finite and infinite." .
#
# # Properties
# ex:referencedBy a owl:ObjectProperty ;
#     rdfs:label "referenced by" ;
#     rdfs:comment "Indicates that the finite is referenced by the infinite and vice versa." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:hasUnityWith a owl:ObjectProperty ;
#     rdfs:label "has unity with" ;
#     rdfs:comment "Indicates the unity between finite and infinite." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Existence .
#
# # Individuals
# ex:finite a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:existence1 a ex:Existence ;
#     rdfs:label "Existence" ;
#     rdfs:comment "An individual representing the unity of finite and infinite as existence." .
#
# # Relationships
# ex:finite ex:referencedBy ex:infinite ;
#     ex:hasUnityWith ex:existence1 .
#
# ex:infinite ex:referencedBy ex:finite ;
#     ex:hasUnityWith ex:existence1 .

# %% [markdown]
#     This alternating determination of self-negating
#     and of negating the negating is what passes
#     as the progress to infinity,
#     which is accepted in so many shapes and applications
#     as an unsurpassable ultimate at which thought,
#     having reached this “and so on to infinity,”
#     has usually achieved its end.

# %% [markdown]
# 1. **Self-Negating Cycle**: The transcreation focuses on the continuous cycle of self-negation and negating the negation as a pathway to infinity.
#
# 2. **Perception of Infinite Progression**: It highlights how this progression is often accepted as the ultimate endpoint in many intellectual contexts.
#
# 3. **Critique of Conventional Understanding**: The translation critiques the common perception that views this "and so on to infinity" as the final stage of thought.
#
# 4. **Limitation of Traditional View**: The text points out that this traditional understanding of infinity is limited and fails to capture the depth of the dialectical process.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:SelfNegating a owl:Class ;
#     rdfs:label "Self-Negating" ;
#     rdfs:comment "Represents the process of self-negating." .
#
# ex:NegatingNegating a owl:Class ;
#     rdfs:label "Negating the Negating" ;
#     rdfs:comment "Represents the process of negating the negating." .
#
# ex:AlternatingDetermination a owl:Class ;
#     rdfs:label "Alternating Determination" ;
#     rdfs:comment "Represents the alternating determination of self-negating and negating the negating." .
#
# ex:ProgressToInfinity a owl:Class ;
#     rdfs:label "Progress to Infinity" ;
#     rdfs:comment "Represents the concept of progress to infinity as the ultimate achievement in thought." .
#
# # Properties
# ex:contains a owl:ObjectProperty ;
#     rdfs:label "contains" ;
#     rdfs:comment "Indicates that alternating determination contains self-negating and negating the negating." ;
#     rdfs:domain ex:AlternatingDetermination ;
#     rdfs:range ex:SelfNegating, ex:NegatingNegating .
#
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that alternating determination leads to progress to infinity." ;
#     rdfs:domain ex:AlternatingDetermination ;
#     rdfs:range ex:ProgressToInfinity .
#
# # Individuals
# ex:selfNegating1 a ex:SelfNegating ;
#     rdfs:label "Self-Negating" ;
#     rdfs:comment "An individual representing the process of self-negating." .
#
# ex:negatingNegating1 a ex:NegatingNegating ;
#     rdfs:label "Negating the Negating" ;
#     rdfs:comment "An individual representing the process of negating the negating." .
#
# ex:alternatingDetermination1 a ex:AlternatingDetermination ;
#     rdfs:label "Alternating Determination" ;
#     rdfs:comment "An individual representing the alternating determination." ;
#     ex:contains ex:selfNegating1, ex:negatingNegating1 .
#
# ex:progressToInfinity1 a ex:ProgressToInfinity ;
#     rdfs:label "Progress to Infinity" ;
#     rdfs:comment "An individual representing progress to infinity." .
#
# # Relationships
# ex:alternatingDetermination1 ex:contains ex:selfNegating1, ex:negatingNegating1 ;
#     ex:leadsTo ex:progressToInfinity1 .

# %% [markdown]
#     This progress breaks out wherever relative determinations are
#     pressed to the point of opposition, so that,
#     though in inseparable unity,
#     each is nevertheless attributed an independent existence
#     over against the other.
#     This progress is therefore the contradiction
#     which is not resolved but is rather always
#     pronounced simply as present.

# %% [markdown]
# 1. **Opposition in Relative Determinations**: The transcreation emphasizes the emergence of opposition when conceptual opposites are pushed to extremes.
#
# 2. **Independent Existence of Opposites**: It highlights the perception of these opposites as independently existing in contrast to each other.
#
# 3. **Unresolved Contradiction in Progress**: The translation points out that this infinite progression embodies an unresolved contradiction that is continuously present.
#
# 4. **Continual Assertion of Conflict**: The text illustrates that this contradiction is not resolved but is consistently acknowledged and maintained.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:RelativeDetermination a owl:Class ;
#     rdfs:label "Relative Determination" ;
#     rdfs:comment "Represents a relative determination pressed to the point of opposition." .
#
# ex:Opposition a owl:Class ;
#     rdfs:label "Opposition" ;
#     rdfs:comment "Represents the state of opposition between relative determinations." .
#
# ex:IndependentExistence a owl:Class ;
#     rdfs:label "Independent Existence" ;
#     rdfs:comment "Represents the independent existence attributed to each relative determination." .
#
# ex:Contradiction a owl:Class ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "Represents the unresolved contradiction pronounced as present." .
#
# # Properties
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that relative determination leads to opposition." ;
#     rdfs:domain ex:RelativeDetermination ;
#     rdfs:range ex:Opposition .
#
# ex:hasIndependentExistence a owl:ObjectProperty ;
#     rdfs:label "has independent existence" ;
#     rdfs:comment "Indicates that each relative determination has independent existence." ;
#     rdfs:domain ex:RelativeDetermination ;
#     rdfs:range ex:IndependentExistence .
#
# ex:containsContradiction a owl:ObjectProperty ;
#     rdfs:label "contains contradiction" ;
#     rdfs:comment "Indicates that opposition contains an unresolved contradiction." ;
#     rdfs:domain ex:Opposition ;
#     rdfs:range ex:Contradiction .
#
# # Individuals
# ex:relativeDetermination1 a ex:RelativeDetermination ;
#     rdfs:label "Relative Determination" ;
#     rdfs:comment "An individual representing a relative determination pressed to the point of opposition." .
#
# ex:opposition1 a ex:Opposition ;
#     rdfs:label "Opposition" ;
#     rdfs:comment "An individual representing the state of opposition between relative determinations." ;
#     ex:containsContradiction ex:contradiction1 .
#
# ex:independentExistence1 a ex:IndependentExistence ;
#     rdfs:label "Independent Existence" ;
#     rdfs:comment "An individual representing the independent existence attributed to each relative determination." .
#
# ex:contradiction1 a ex:Contradiction ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "An individual representing the unresolved contradiction pronounced as present." .
#
# # Relationships
# ex:relativeDetermination1 ex:leadsTo ex:opposition1 ;
#     ex:hasIndependentExistence ex:independentExistence1 .
#
# ex:opposition1 ex:containsContradiction ex:contradiction1 .

# %% [markdown]
#     What we have before us is an abstract transcending
#     which remains incomplete because the transcending
#     itself has not been transcended.
#     Before us we have the infinite;
#     of course, this infinite is transcended,
#     for another limit is posited,
#     but just because of that only a return
#     is instead made back to the finite.

# %% [markdown]
# 1. **Incomplete Abstract Transcending**: The transcreation emphasizes that the process of transcending discussed by Hegel is incomplete, as it does not transcend itself.
#
# 2. **Cyclical Return to the Finite**: It highlights the cycle where each act of transcending is followed by the establishment of a new limit, leading back to the finite.
#
# 3. **Failure to Achieve True Infinity**: The translation points out that this process fails to reach a true state of infiniteness, as it is constantly bounded by new limits.
#
# 4. **Flaw in Abstract Concept of Transcendence**: The text illustrates the inherent flaw in this abstract notion of transcendence, which fails to escape the finite-infinite cycle.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:AbstractTranscending a owl:Class ;
#     rdfs:label "Abstract Transcending" ;
#     rdfs:comment "Represents the process of abstract transcending which remains incomplete." .
#
# ex:TranscendedInfinite a owl:Class ;
#     rdfs:label "Transcended Infinite" ;
#     rdfs:comment "Represents the infinite that has been transcended." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the new limit that is posited." .
#
# # Properties
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that the abstract transcending leads to the transcended infinite." ;
#     rdfs:domain ex:AbstractTranscending ;
#     rdfs:range ex:TranscendedInfinite .
#
# ex:returnsTo a owl:ObjectProperty ;
#     rdfs:label "returns to" ;
#     rdfs:comment "Indicates that the transcended infinite returns to the finite." ;
#     rdfs:domain ex:TranscendedInfinite ;
#     rdfs:range ex:Finite .
#
# ex:posits a owl:ObjectProperty ;
#     rdfs:label "posits" ;
#     rdfs:comment "Indicates that a new limit is posited within the infinite." ;
#     rdfs:domain ex:TranscendedInfinite ;
#     rdfs:range ex:Limit .
#
# # Individuals
# ex:abstractTranscending1 a ex:AbstractTranscending ;
#     rdfs:label "Abstract Transcending" ;
#     rdfs:comment "An individual representing the process of abstract transcending." .
#
# ex:transcendedInfinite1 a ex:TranscendedInfinite ;
#     rdfs:label "Transcended Infinite" ;
#     rdfs:comment "An individual representing the infinite that has been transcended." ;
#     ex:posits ex:limit1 ;
#     ex:returnsTo ex:finite1 .
#
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:limit1 a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the new limit that is posited." .
#
# # Relationships
# ex:abstractTranscending1 ex:leadsTo ex:transcendedInfinite1 .
#
# ex:transcendedInfinite1 ex:posits ex:limit1 ;
#     ex:returnsTo ex:finite1 .

# %% [markdown]
#     This bad infinite is in itself
#     the same as the perpetual ought;
#     it is indeed the negation of the finite,
#     but in truth it is unable to free itself from it;
#     the finite constantly resurfaces in it as its other,
#     since this infinite only is with reference to the finite,
#     which is its other.
#     The progress to infinity is
#     therefore only repetitious monotony,
#     the one and the same tedious
#     alternation of this finite and infinite.

# %% [markdown]
# 1. **'Bad Infinite' as Perpetual 'Ought'**: The transcreation underlines the notion of the 'bad infinite' as analogous to an unfulfilled 'ought.'
#
# 2. **Inability to Escape the Finite**: It emphasizes that this version of the infinite is intrinsically unable to free itself from the finite.
#
# 3. **Finite as the Constant 'Other'**: The translation highlights the persistent reappearance of the finite within the 'bad infinite.'
#
# 4. **Repetitive Monotony of Progress**: The text depicts the journey towards this infinite as a dull and repetitive cycle, lacking true progression.
#
# 5. **Tedious Alternation**: The aim is to present the 'bad infinite' as a tedious alternation between the finite and infinite, lacking depth and transcendence.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "Represents the bad infinite, which is unable to free itself from the finite." .
#
# ex:PerpetualOught a owl:Class ;
#     rdfs:label "Perpetual Ought" ;
#     rdfs:comment "Represents the perpetual ought, synonymous with the bad infinite." .
#
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:RepetitiousMonotony a owl:Class ;
#     rdfs:label "Repetitious Monotony" ;
#     rdfs:comment "Represents the repetitious monotony of the alternation between the finite and the bad infinite." .
#
# # Properties
# ex:negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that the bad infinite negates the finite." ;
#     rdfs:domain ex:BadInfinite ;
#     rdfs:range ex:Finite .
#
# ex:cannotFreeFrom a owl:ObjectProperty ;
#     rdfs:label "cannot free from" ;
#     rdfs:comment "Indicates that the bad infinite cannot free itself from the finite." ;
#     rdfs:domain ex:BadInfinite ;
#     rdfs:range ex:Finite .
#
# ex:resurfacesIn a owl:ObjectProperty ;
#     rdfs:label "resurfaces in" ;
#     rdfs:comment "Indicates that the finite constantly resurfaces in the bad infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:BadInfinite .
#
# ex:hasReferenceTo a owl:ObjectProperty ;
#     rdfs:label "has reference to" ;
#     rdfs:comment "Indicates that the bad infinite exists with reference to the finite." ;
#     rdfs:domain ex:BadInfinite ;
#     rdfs:range ex:Finite .
#
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that the perpetual ought leads to repetitious monotony." ;
#     rdfs:domain ex:PerpetualOught ;
#     rdfs:range ex:RepetitiousMonotony .
#
# # Individuals
# ex:badInfinite1 a ex:BadInfinite ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "An individual representing the bad infinite." ;
#     ex:negates ex:finite1 ;
#     ex:cannotFreeFrom ex:finite1 ;
#     ex:hasReferenceTo ex:finite1 .
#
# ex:perpetualOught1 a ex:PerpetualOught ;
#     rdfs:label "Perpetual Ought" ;
#     rdfs:comment "An individual representing the perpetual ought." ;
#     ex:leadsTo ex:repetitiousMonotony1 .
#
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." ;
#     ex:resurfacesIn ex:badInfinite1 .
#
# ex:repetitiousMonotony1 a ex:RepetitiousMonotony ;
#     rdfs:label "Repetitious Monotony" ;
#     rdfs:comment "An individual representing the repetitious monotony." .
#
# # Relationships
# ex:badInfinite1 ex:negates ex:finite1 ;
#     ex:cannotFreeFrom ex:finite1 ;
#     ex:hasReferenceTo ex:finite1 .
#
# ex:finite1 ex:resurfacesIn ex:badInfinite1 .
#
# ex:perpetualOught1 ex:leadsTo ex:repetitiousMonotony1 .

# %% [markdown]
#     The infinity of the infinite progress
#     remains burdened by the finite as such,
#     is thereby restricted, and is itself finite.
#     In fact, however, it is thereby posited as
#     the unity of the finite and the infinite.

# %% [markdown]
# 1. **Finite Burden on Infinite Progress**: The transcreation emphasizes that the infinite progress is limited by its ongoing relationship with the finite.
#
# 2. **Finite Nature of the Infinite**: It highlights the irony that the infinite, burdened by the finite, becomes finite itself.
#
# 3. **Unity of Finite and Infinite**: The translation underlines that this scenario actually represents the unity of the finite and the infinite.
#
# 4. **Synthesis in Infinite Progress**: The text suggests that infinite progress involves a synthesis of finitude and infinitude.

# %% [markdown]
# Let's continue developing the OWL ontology based on the provided text segment, focusing on the relationship between the finite and the infinite, and how they form a unity.
#
# ### OWL Ontology for the Unity of Finite and Infinite
#
# ```turtle
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:BurdenedInfinite a owl:Class ;
#     rdfs:label "Burdened Infinite" ;
#     rdfs:comment "Represents the infinite burdened by the finite." .
#
# ex:UnityOfFiniteAndInfinite a owl:Class ;
#     rdfs:label "Unity of Finite and Infinite" ;
#     rdfs:comment "Represents the unity of the finite and the infinite." .
#
# # Properties
# ex:burdenedBy a owl:ObjectProperty ;
#     rdfs:label "burdened by" ;
#     rdfs:comment "Indicates that the infinite progress is burdened by the finite." ;
#     rdfs:domain ex:BurdenedInfinite ;
#     rdfs:range ex:Finite .
#
# ex:isRestricted a owl:ObjectProperty ;
#     rdfs:label "is restricted" ;
#     rdfs:comment "Indicates that the infinite is restricted by the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:formsUnityWith a owl:ObjectProperty ;
#     rdfs:label "forms unity with" ;
#     rdfs:comment "Indicates that the infinite forms a unity with the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:UnityOfFiniteAndInfinite .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." ;
#     ex:isRestricted ex:finite1 ;
#     ex:formsUnityWith ex:unityOfFiniteAndInfinite1 .
#
# ex:burdenedInfinite1 a ex:BurdenedInfinite ;
#     rdfs:label "Burdened Infinite" ;
#     rdfs:comment "An individual representing the infinite burdened by the finite." ;
#     ex:burdenedBy ex:finite1 .
#
# ex:unityOfFiniteAndInfinite1 a ex:UnityOfFiniteAndInfinite ;
#     rdfs:label "Unity of Finite and Infinite" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." .
#
# # Relationships
# ex:burdenedInfinite1 ex:burdenedBy ex:finite1 .
#
# ex:infinite1 ex:isRestricted ex:finite1 ;
#     ex:formsUnityWith ex:unityOfFiniteAndInfinite1 .
# ```
#
# ### Explanation
#
# - **Classes**:
#   - **Finite**: Represents the finite aspect.
#   - **Infinite**: Represents the infinite aspect.
#   - **Burdened Infinite**: Represents the infinite burdened by the finite.
#   - **Unity of Finite and Infinite**: Represents the unity of the finite and the infinite.
#
# - **Properties**:
#   - **burdened by**: Indicates that the infinite progress is burdened by the finite.
#   - **is restricted**: Indicates that the infinite is restricted by the finite.
#   - **forms unity with**: Indicates that the infinite forms a unity with the finite.
#
# - **Individuals**:
#   - **finite1**: An instance of the class "Finite."
#   - **infinite1**: An instance of the class "Infinite."
#   - **burdenedInfinite1**: An instance of the class "Burdened Infinite."
#   - **unityOfFiniteAndInfinite1**: An instance of the class "Unity of Finite and Infinite."
#
# - **Relationships**:
#   - The burdened infinite is burdened by the finite.
#   - The infinite is restricted by the finite and forms a unity with the finite.
#
# This ontology captures the key concepts and relationships described in the provided text segment. Please provide the next segment or additional instructions for further refinement.

# %% [markdown]
#     Only, this unity is not reflected upon.
#     Yet it alone rouses the finite in the infinite,
#     and the infinite in the finite;
#     it is, so to speak, the impulse
#     driving the infinite progress.

# %% [markdown]
# 1. **Unreflected Unity**: The transcreation emphasizes the often overlooked but fundamental unity between the finite and the infinite.
#
# 2. **Mutual Animation of Finite and Infinite**: It highlights how this unity enlivens the finite within the infinite, and vice versa.
#
# 3. **Driving Force of Infinite Progress**: The translation portrays this unity as the impulse or driving force behind the notion of infinite progress.
#
# 4. **Core of Continuous Cycle**: The text suggests that this unity is at the heart of the continuous cycle toward infinity.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the unity of the finite and the infinite." .
#
# ex:DrivingImpulse a owl:Class ;
#     rdfs:label "Driving Impulse" ;
#     rdfs:comment "Represents the impulse driving the infinite progress." .
#
# # Properties
# ex:rouses a owl:ObjectProperty ;
#     rdfs:label "rouses" ;
#     rdfs:comment "Indicates that the unity rouses the finite in the infinite, and the infinite in the finite." ;
#     rdfs:domain ex:Unity ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:drives a owl:ObjectProperty ;
#     rdfs:label "drives" ;
#     rdfs:comment "Indicates that the unity drives the infinite progress." ;
#     rdfs:domain ex:Unity ;
#     rdfs:range ex:DrivingImpulse .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:unity1 a ex:Unity ;
#     rdfs:label "Unity" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." ;
#     ex:rouses ex:finite1, ex:infinite1 ;
#     ex:drives ex:drivingImpulse1 .
#
# ex:drivingImpulse1 a ex:DrivingImpulse ;
#     rdfs:label "Driving Impulse" ;
#     rdfs:comment "An individual representing the impulse driving the infinite progress." .
#
# # Relationships
# ex:unity1 ex:rouses ex:finite1, ex:infinite1 ;
#     ex:drives ex:drivingImpulse1 .

# %% [markdown]
#     This progress is the outside of this unity
#     at which representation remains fixated;
#     fixated at that perennial repetition
#     of one and the same alternation;
#     at the empty unrest of a progression
#     across the limit towards the infinite
#     which, in this infinity, finds a new limit
#     but is just as unable to halt at it
#     as it is at the infinite.

# %% [markdown]
# 1. **Fixation on External Progress**: The transcreation emphasizes the fixation on the external aspect of infinite progress, overlooking its deeper unity.
#
# 2. **Perennial Repetition**: It highlights the endless repetition and alternation between finite and infinite in this perception of progress.
#
# 3. **Empty Unrest of Progression**: The translation describes the restless and empty nature of this progression towards infinity, continually encountering new limits.
#
# 4. **Inability to Find an Endpoint**: The text points out that this type of progress is unable to find a true halt, neither at new limits nor in the infinite.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the unity of the finite and the infinite." .
#
# ex:Progress a owl:Class ;
#     rdfs:label "Progress" ;
#     rdfs:comment "Represents the progress towards the infinite." .
#
# ex:Fixation a owl:Class ;
#     rdfs:label "Fixation" ;
#     rdfs:comment "Represents the fixation on the repetitive alternation." .
#
# ex:Repetition a owl:Class ;
#     rdfs:label "Repetition" ;
#     rdfs:comment "Represents the perennial repetition of the same alternation." .
#
# ex:EmptyUnrest a owl:Class ;
#     rdfs:label "Empty Unrest" ;
#     rdfs:comment "Represents the empty unrest of the progression." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the limit encountered in the progression." .
#
# ex:Infinity a owl:Class ;
#     rdfs:label "Infinity" ;
#     rdfs:comment "Represents the infinite aspect encountered in the progression." .
#
# # Properties
# ex:hasFixationOn a owl:ObjectProperty ;
#     rdfs:label "has fixation on" ;
#     rdfs:comment "Indicates that progress has a fixation on repetition." ;
#     rdfs:domain ex:Progress ;
#     rdfs:range ex:Fixation .
#
# ex:resultsIn a owl:ObjectProperty ;
#     rdfs:label "results in" ;
#     rdfs:comment "Indicates that fixation results in repetition." ;
#     rdfs:domain ex:Fixation ;
#     rdfs:range ex:Repetition .
#
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that repetition leads to empty unrest." ;
#     rdfs:domain ex:Repetition ;
#     rdfs:range ex:EmptyUnrest .
#
# ex:encounters a owl:ObjectProperty ;
#     rdfs:label "encounters" ;
#     rdfs:comment "Indicates that progress encounters limits and infinity." ;
#     rdfs:domain ex:Progress ;
#     rdfs:range ex:Limit, ex:Infinity .
#
# # Individuals
# ex:unity1 a ex:Unity ;
#     rdfs:label "Unity" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." .
#
# ex:progress1 a ex:Progress ;
#     rdfs:label "Progress" ;
#     rdfs:comment "An individual representing the progress towards the infinite." ;
#     ex:hasFixationOn ex:fixation1 ;
#     ex:encounters ex:limit1, ex:infinity1 .
#
# ex:fixation1 a ex:Fixation ;
#     rdfs:label "Fixation" ;
#     rdfs:comment "An individual representing the fixation on repetition." ;
#     ex:resultsIn ex:repetition1 .
#
# ex:repetition1 a ex:Repetition ;
#     rdfs:label "Repetition" ;
#     rdfs:comment "An individual representing the perennial repetition of the same alternation." ;
#     ex:leadsTo ex:emptyUnrest1 .
#
# ex:emptyUnrest1 a ex:EmptyUnrest ;
#     rdfs:label "Empty Unrest" ;
#     rdfs:comment "An individual representing the empty unrest of the progression." .
#
# ex:limit1 a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the limit encountered in the progression." .
#
# ex:infinity1 a ex:Infinity ;
#     rdfs:label "Infinity" ;
#     rdfs:comment "An individual representing the infinite aspect encountered in the progression." .
#
# # Relationships
# ex:progress1 ex:hasFixationOn ex:fixation1 ;
#     ex:encounters ex:limit1, ex:infinity1 .
#
# ex:fixation1 ex:resultsIn ex:repetition1 .
#
# ex:repetition1 ex:leadsTo ex:emptyUnrest1 .

# %% [markdown]
#     This infinite has the rigid determination
#     of a beyond that cannot be attained,
#     for the very reason that it ought not be attained,
#     since the determinateness of the beyond,
#     of an existent negation, has not been let go.

# %% [markdown]
# 1. **Infinite as Unattainable 'Beyond'**: The transcreation emphasizes the concept of the infinite as a 'beyond' that is fundamentally unattainable.
#
# 2. **Reason for Unattainability**: It highlights that this unattainability is due to the inherent nature of the 'beyond' as an existent negation.
#
# 3. **Rigid Determination of the Infinite**: The translation points out the rigid determination of this infinite, defined by what it negates.
#
# 4. **Limitation in Understanding**: The text suggests that this perspective on the infinite reveals a limited understanding, viewing it as a static entity rather than a dynamic process.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the unity of the finite and the infinite." .
#
# ex:Progress a owl:Class ;
#     rdfs:label "Progress" ;
#     rdfs:comment "Represents the progress towards the infinite." .
#
# ex:Fixation a owl:Class ;
#     rdfs:label "Fixation" ;
#     rdfs:comment "Represents the fixation on the repetitive alternation." .
#
# ex:Repetition a owl:Class ;
#     rdfs:label "Repetition" ;
#     rdfs:comment "Represents the perennial repetition of the same alternation." .
#
# ex:EmptyUnrest a owl:Class ;
#     rdfs:label "Empty Unrest" ;
#     rdfs:comment "Represents the empty unrest of the progression." .
#
# ex:Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the limit encountered in the progression." .
#
# ex:Infinity a owl:Class ;
#     rdfs:label "Infinity" ;
#     rdfs:comment "Represents the infinite aspect encountered in the progression." .
#
# # Properties
# ex:hasFixationOn a owl:ObjectProperty ;
#     rdfs:label "has fixation on" ;
#     rdfs:comment "Indicates that progress has a fixation on repetition." ;
#     rdfs:domain ex:Progress ;
#     rdfs:range ex:Fixation .
#
# ex:resultsIn a owl:ObjectProperty ;
#     rdfs:label "results in" ;
#     rdfs:comment "Indicates that fixation results in repetition." ;
#     rdfs:domain ex:Fixation ;
#     rdfs:range ex:Repetition .
#
# ex:leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that repetition leads to empty unrest." ;
#     rdfs:domain ex:Repetition ;
#     rdfs:range ex:EmptyUnrest .
#
# ex:encounters a owl:ObjectProperty ;
#     rdfs:label "encounters" ;
#     rdfs:comment "Indicates that progress encounters limits and infinity." ;
#     rdfs:domain ex:Progress ;
#     rdfs:range ex:Limit, ex:Infinity .
#
# # Individuals
# ex:unity1 a ex:Unity ;
#     rdfs:label "Unity" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite." .
#
# ex:progress1 a ex:Progress ;
#     rdfs:label "Progress" ;
#     rdfs:comment "An individual representing the progress towards the infinite." ;
#     ex:hasFixationOn ex:fixation1 ;
#     ex:encounters ex:limit1, ex:infinity1 .
#
# ex:fixation1 a ex:Fixation ;
#     rdfs:label "Fixation" ;
#     rdfs:comment "An individual representing the fixation on repetition." ;
#     ex:resultsIn ex:repetition1 .
#
# ex:repetition1 a ex:Repetition ;
#     rdfs:label "Repetition" ;
#     rdfs:comment "An individual representing the perennial repetition of the same alternation." ;
#     ex:leadsTo ex:emptyUnrest1 .
#
# ex:emptyUnrest1 a ex:EmptyUnrest ;
#     rdfs:label "Empty Unrest" ;
#     rdfs:comment "An individual representing the empty unrest of the progression." .
#
# ex:limit1 a ex:Limit ;
#     rdfs:label "Limit" ;
#     rdfs:comment "An individual representing the limit encountered in the progression." .
#
# ex:infinity1 a ex:Infinity ;
#     rdfs:label "Infinity" ;
#     rdfs:comment "An individual representing the infinite aspect encountered in the progression." .
#
# # Relationships
# ex:progress1 ex:hasFixationOn ex:fixation1 ;
#     ex:encounters ex:limit1, ex:infinity1 .
#
# ex:fixation1 ex:resultsIn ex:repetition1 .
#
# ex:repetition1 ex:leadsTo ex:emptyUnrest1 .

# %% [markdown]
#     In this determination, the infinite has
#     the finite as a this-side over against it;
#     a finite that is likewise unable
#     to raise itself up to the infinite
#     just because it has this determination of an other,
#     that is, of an existence that perennially
#     regenerates itself in that beyond
#     precisely by being different from it.

# %% [markdown]
# 1. **Infinite with Finite as Opposing 'This-Side'**: The transcreation emphasizes the infinite having the finite as its contrasting 'this-side.'
#
# 2. **Finite's Inability to Transcend**: It highlights the finite's inherent inability to rise to the level of the infinite due to its nature as the 'other.'
#
# 3. **Perennial Regeneration of the Finite**: The translation points out the continuous self-regeneration of the finite in opposition to the infinite.
#
# 4. **Inherent Difference as Barrier**: The text illustrates that the finite's distinctness from the infinite acts as a barrier to their convergence.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:ThisSide a owl:Class ;
#     rdfs:label "This-Side" ;
#     rdfs:comment "Represents the finite as this-side over against the infinite." .
#
# ex:Other a owl:Class ;
#     rdfs:label "Other" ;
#     rdfs:comment "Represents the determination of an other, an existence different from the infinite." .
#
# # Properties
# ex:isOverAgainst a owl:ObjectProperty ;
#     rdfs:label "is over against" ;
#     rdfs:comment "Indicates that the finite is over against the infinite as a this-side." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:hasDeterminationOf a owl:ObjectProperty ;
#     rdfs:label "has determination of" ;
#     rdfs:comment "Indicates that the finite has the determination of an other." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Other .
#
# ex:regeneratesIn a owl:ObjectProperty ;
#     rdfs:label "regenerates in" ;
#     rdfs:comment "Indicates that the finite regenerates itself in the beyond by being different from it." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." ;
#     ex:isOverAgainst ex:infinite1 ;
#     ex:hasDeterminationOf ex:other1 ;
#     ex:regeneratesIn ex:infinite1 .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:thisSide1 a ex:ThisSide ;
#     rdfs:label "This-Side" ;
#     rdfs:comment "An individual representing the finite as this-side over against the infinite." .
#
# ex:other1 a ex:Other ;
#     rdfs:label "Other" ;
#     rdfs:comment "An individual representing the determination of an other, different from the infinite." .
#
# # Relationships
# ex:finite1 ex:isOverAgainst ex:infinite1 ;
#     ex:hasDeterminationOf ex:other1 ;
#     ex:regeneratesIn ex:infinite1 .

# %% [markdown]
# ## c. Affirmative infinity

# %% [markdown]
#     In this reciprocal determination of the finite and the infinite
#     alternating back and forth as just indicated,
#     the truth of these two is already implicitly present in itself,
#     and all that is needed is to take up what is there.
#     This back and forth movement constitutes the external realization
#     of the concept in which the content of the latter is posited,
#     but externally, as a falling out of the two;
#     all that is needed is the comparing of these two different moments
#     in which the unity is given which the concept itself gives.

# %% [markdown]
# 1. **Dynamic Relationship of Finite and Infinite**: The transcreation emphasizes the constant alternation and interplay between the finite and the infinite.
#
# 2. **External Manifestation of Conceptual Unity**: It highlights that this movement is the external realization of a deeper conceptual unity.
#
# 3. **Implicit Presence of Unity**: The translation points out that the truth of this unity is already implicitly present in the interaction of the finite and infinite.
#
# 4. **Task of Recognizing Unity**: The text suggests that understanding 'affirmative infinity' involves recognizing and drawing out this inherent unity.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:ReciprocalDetermination a owl:Class ;
#     rdfs:label "Reciprocal Determination" ;
#     rdfs:comment "Represents the reciprocal determination of the finite and the infinite." .
#
# ex:ExternalRealization a owl:Class ;
#     rdfs:label "External Realization" ;
#     rdfs:comment "Represents the external realization of the concept." .
#
# ex:Concept a owl:Class ;
#     rdfs:label "Concept" ;
#     rdfs:comment "Represents the concept which gives unity." .
#
# # Properties
# ex:alternatesWith a owl:ObjectProperty ;
#     rdfs:label "alternates with" ;
#     rdfs:comment "Indicates that the finite alternates with the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:containsTruthOf a owl:ObjectProperty ;
#     rdfs:label "contains truth of" ;
#     rdfs:comment "Indicates that the reciprocal determination contains the truth of the finite and the infinite." ;
#     rdfs:domain ex:ReciprocalDetermination ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:realizes a owl:ObjectProperty ;
#     rdfs:label "realizes" ;
#     rdfs:comment "Indicates that the external realization realizes the concept." ;
#     rdfs:domain ex:ExternalRealization ;
#     rdfs:range ex:Concept .
#
# ex:positsContentOf a owl:ObjectProperty ;
#     rdfs:label "posits content of" ;
#     rdfs:comment "Indicates that the external realization posits the content of the concept externally." ;
#     rdfs:domain ex:ExternalRealization ;
#     rdfs:range ex:Concept .
#
# ex:compares a owl:ObjectProperty ;
#     rdfs:label "compares" ;
#     rdfs:comment "Indicates that comparing different moments provides the unity given by the concept." ;
#     rdfs:domain ex:ExternalRealization ;
#     rdfs:range ex:Concept .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:reciprocalDetermination1 a ex:ReciprocalDetermination ;
#     rdfs:label "Reciprocal Determination" ;
#     rdfs:comment "An individual representing the reciprocal determination of the finite and the infinite." ;
#     ex:containsTruthOf ex:finite1, ex:infinite1 .
#
# ex:externalRealization1 a ex:ExternalRealization ;
#     rdfs:label "External Realization" ;
#     rdfs:comment "An individual representing the external realization of the concept." ;
#     ex:realizes ex:concept1 ;
#     ex:positsContentOf ex:concept1 ;
#     ex:compares ex:concept1 .
#
# ex:concept1 a ex:Concept ;
#     rdfs:label "Concept" ;
#     rdfs:comment "An individual representing the concept which gives unity." .
#
# # Relationships
# ex:finite1 ex:alternatesWith ex:infinite1 .
#
# ex:reciprocalDetermination1 ex:containsTruthOf ex:finite1, ex:infinite1 .
#
# ex:externalRealization1 ex:realizes ex:concept1 ;
#     ex:positsContentOf ex:concept1 ;
#     ex:compares ex:concept1 .

# %% [markdown]
#     “Unity of the finite and the infinite”
#     (as has often been already noted
#     but must especially be kept in mind at this juncture)
#     is the uneven expression for the unity as it is in truth;
#     but also the removal of this uneven determination must be
#     found in the externalization of the concept that lies ahead of us.

# %% [markdown]
# 1. **Critique of Simplistic Expression**: The transcreation emphasizes Hegel’s critique of the phrase "Unity of the finite and the infinite" as an inadequate representation of the true unity.
#
# 2. **Need for Deeper Understanding**: It highlights the necessity to transcend this uneven determination to grasp the actual nature of the unity.
#
# 3. **Externalization of the Concept**: The translation points out that a deeper understanding of this unity lies in exploring how the concept manifests externally.
#
# 4. **Beyond Simple Merging**: The text suggests that the true unity of the finite and infinite involves more than a straightforward combination of the two.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:UnityOfFiniteAndInfinite a owl:Class ;
#     rdfs:label "Unity of Finite and Infinite" ;
#     rdfs:comment "Represents the unity of the finite and the infinite as an uneven expression." .
#
# ex:TrueUnity a owl:Class ;
#     rdfs:label "True Unity" ;
#     rdfs:comment "Represents the true unity of the finite and the infinite." .
#
# ex:UnevenDetermination a owl:Class ;
#     rdfs:label "Uneven Determination" ;
#     rdfs:comment "Represents the uneven determination of the unity of finite and infinite." .
#
# ex:ExternalizationOfConcept a owl:Class ;
#     rdfs:label "Externalization of Concept" ;
#     rdfs:comment "Represents the externalization of the concept that removes uneven determination." .
#
# # Properties
# ex:contains a owl:ObjectProperty ;
#     rdfs:label "contains" ;
#     rdfs:comment "Indicates that the unity of finite and infinite contains an uneven determination." ;
#     rdfs:domain ex:UnityOfFiniteAndInfinite ;
#     rdfs:range ex:UnevenDetermination .
#
# ex:removes a owl:ObjectProperty ;
#     rdfs:label "removes" ;
#     rdfs:comment "Indicates that the externalization of the concept removes uneven determination." ;
#     rdfs:domain ex:ExternalizationOfConcept ;
#     rdfs:range ex:UnevenDetermination .
#
# ex:achieves a owl:ObjectProperty ;
#     rdfs:label "achieves" ;
#     rdfs:comment "Indicates that the externalization of the concept achieves true unity." ;
#     rdfs:domain ex:ExternalizationOfConcept ;
#     rdfs:range ex:TrueUnity .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." .
#
# ex:unityOfFiniteAndInfinite1 a ex:UnityOfFiniteAndInfinite ;
#     rdfs:label "Unity of Finite and Infinite" ;
#     rdfs:comment "An individual representing the unity of the finite and the infinite as an uneven expression." ;
#     ex:contains ex:unevenDetermination1 .
#
# ex:trueUnity1 a ex:TrueUnity ;
#     rdfs:label "True Unity" ;
#     rdfs:comment "An individual representing the true unity of the finite and the infinite." .
#
# ex:unevenDetermination1 a ex:UnevenDetermination ;
#     rdfs:label "Uneven Determination" ;
#     rdfs:comment "An individual representing the uneven determination of the unity of finite and infinite." .
#
# ex:externalizationOfConcept1 a ex:ExternalizationOfConcept ;
#     rdfs:label "Externalization of Concept" ;
#     rdfs:comment "An individual representing the externalization of the concept that removes uneven determination." ;
#     ex:removes ex:unevenDetermination1 ;
#     ex:achieves ex:trueUnity1 .
#
# # Relationships
# ex:unityOfFiniteAndInfinite1 ex:contains ex:unevenDetermination1 .
#
# ex:externalizationOfConcept1 ex:removes ex:unevenDetermination1 ;
#     ex:achieves ex:trueUnity1 .

# %% [markdown]
#     Taken in their first, only immediate determination,
#     the infinite is the transcending of the finite;
#     according to its determination, it is the negation of the finite;
#     the finite, for its part, is only that which must be transcended,
#     the negation in it of itself, and this is the infinite.

# %% [markdown]
# 1. **Infinite as Transcending Finite**: The transcreation emphasizes the initial definition of the infinite as the act of transcending the finite.
#
# 2. **Negation as Essence of Infinite**: It highlights that the infinite's fundamental characteristic is the negation of the finite.
#
# 3. **Finite as Necessitating Transcendence**: The translation points out that the finite's primary trait is being something that must be transcended, inherently pointing towards the infinite.
#
# 4. **Interconnected Definitions**: The text illustrates how these initial definitions of the finite and infinite reveal their interrelated nature.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:ImmediateDetermination a owl:Class ;
#     rdfs:label "Immediate Determination" ;
#     rdfs:comment "Represents the first, immediate determination." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the negation aspect." .
#
# ex:Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the act of transcending." .
#
# # Properties
# ex:isNegationOf a owl:ObjectProperty ;
#     rdfs:label "is negation of" ;
#     rdfs:comment "Indicates that the infinite is the negation of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:mustBeTranscended a owl:ObjectProperty ;
#     rdfs:label "must be transcended" ;
#     rdfs:comment "Indicates that the finite must be transcended." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:isTranscendenceOf a owl:ObjectProperty ;
#     rdfs:label "is transcendence of" ;
#     rdfs:comment "Indicates that the infinite is the transcendence of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that the finite contains the negation of itself." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Negation .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." ;
#     ex:mustBeTranscended ex:infinite1 ;
#     ex:containsNegation ex:negation1 .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." ;
#     ex:isNegationOf ex:finite1 ;
#     ex:isTranscendenceOf ex:finite1 .
#
# ex:immediateDetermination1 a ex:ImmediateDetermination ;
#     rdfs:label "Immediate Determination" ;
#     rdfs:comment "An individual representing the first, immediate determination." .
#
# ex:negation1 a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the negation aspect." .
#
# ex:transcendence1 a ex:Transcendence ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "An individual representing the act of transcending." .
#
# # Relationships
# ex:finite1 ex:mustBeTranscended ex:infinite1 ;
#     ex:containsNegation ex:negation1 .
#
# ex:infinite1 ex:isNegationOf ex:finite1 ;
#     ex:isTranscendenceOf ex:finite1 .

# %% [markdown]
#     In each, therefore, there is the determinateness of the other,
#     whereas, according to the viewpoint of the infinite progression,
#     the two should be mutually excluded
#     and would have to follow one another only alternately;
#     neither can be posited and grasped without the other,
#     the infinite without the finite, the finite without the infinite.

# %% [markdown]
# 1. **Mutual Determinateness**: The transcreation emphasizes that each of the concepts, the finite and the infinite, contains aspects of the other.
#
# 2. **Challenge to Infinite Progression Viewpoint**: It highlights how this observation contradicts the traditional viewpoint of infinite progression, where the finite and infinite are seen as mutually exclusive.
#
# 3. **Inseparability of Finite and Infinite**: The translation underscores the inseparability of the finite and infinite, each requiring the other for its full conceptualization.
#
# 4. **Integrated Relationship**: The text suggests a more integrated relationship between the finite and infinite than mere alternation.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:Determinateness a owl:Class ;
#     rdfs:label "Determinateness" ;
#     rdfs:comment "Represents the determinateness of an aspect." .
#
# ex:Interdependence a owl:Class ;
#     rdfs:label "Interdependence" ;
#     rdfs:comment "Represents the interdependence of the finite and the infinite." .
#
# # Properties
# ex:containsDeterminatenessOf a owl:ObjectProperty ;
#     rdfs:label "contains determinateness of" ;
#     rdfs:comment "Indicates that each aspect contains the determinateness of the other." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Determinateness .
#
# ex:mutuallyExcludes a owl:ObjectProperty ;
#     rdfs:label "mutually excludes" ;
#     rdfs:comment "Indicates that the finite and the infinite should be mutually exclusive according to the infinite progression viewpoint." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# ex:requires a owl:ObjectProperty ;
#     rdfs:label "requires" ;
#     rdfs:comment "Indicates that each aspect requires the other to be posited and grasped." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." ;
#     ex:containsDeterminatenessOf ex:determinateness1 ;
#     ex:requires ex:infinite1 .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." ;
#     ex:containsDeterminatenessOf ex:determinateness1 ;
#     ex:requires ex:finite1 .
#
# ex:determinateness1 a ex:Determinateness ;
#     rdfs:label "Determinateness" ;
#     rdfs:comment "An individual representing the determinateness of an aspect." .
#
# ex:interdependence1 a ex:Interdependence ;
#     rdfs:label "Interdependence" ;
#     rdfs:comment "An individual representing the interdependence of the finite and the infinite." .
#
# # Relationships
# ex:finite1 ex:containsDeterminatenessOf ex:determinateness1 ;
#     ex:requires ex:infinite1 .
#
# ex:infinite1 ex:containsDeterminatenessOf ex:determinateness1 ;
#     ex:requires ex:finite1 .

# %% [markdown]
#     In saying what the infinite is, namely the negation of the finite,
#     the finite itself is said also;
#     it cannot be avoided in the determination of the infinite.
#     One need only know what is being said in order to
#     find the determination of the finite in the infinite.

# %% [markdown]
# 1. **Infinite Defined Through Finite**: The transcreation emphasizes that the definition of the infinite inherently involves the finite.
#
# 2. **Inevitability of Finite in Infinite's Determination**: It highlights the impossibility of avoiding the finite when determining the infinite.
#
# 3. **Mutual Definition**: The translation underscores that understanding the infinite requires recognizing its interconnectedness with the finite.
#
# 4. **Integrated Conceptualization**: The text suggests a deep integration of the finite within the conceptualization of the infinite.

# %% [markdown]
# Let's extend the OWL ontology to capture the concept that the determination of the infinite inherently includes the finite, reflecting their inseparable relationship.
#
# ### OWL Ontology for the Determination of Infinite and Finite
#
# ```turtle
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite aspect." .
#
# ex:Determinateness a owl:Class ;
#     rdfs:label "Determinateness" ;
#     rdfs:comment "Represents the determinateness of an aspect." .
#
# ex:Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the negation aspect." .
#
# # Properties
# ex:containsDeterminatenessOf a owl:ObjectProperty ;
#     rdfs:label "contains determinateness of" ;
#     rdfs:comment "Indicates that the infinite contains the determinateness of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Determinateness .
#
# ex:includesNegationOf a owl:ObjectProperty ;
#     rdfs:label "includes negation of" ;
#     rdfs:comment "Indicates that the infinite includes the negation of the finite." ;
#     rdfs:domain ex:Infinite ;
#     rdfs:range ex:Finite .
#
# ex:isDeterminedBy a owl:ObjectProperty ;
#     rdfs:label "is determined by" ;
#     rdfs:comment "Indicates that the finite is determined by the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     rdfs:comment "An individual representing the finite." ;
#     ex:isDeterminedBy ex:infinite1 .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "An individual representing the infinite." ;
#     ex:containsDeterminatenessOf ex:finite1 ;
#     ex:includesNegationOf ex:finite1 .
#
# ex:determinateness1 a ex:Determinateness ;
#     rdfs:label "Determinateness" ;
#     rdfs:comment "An individual representing the determinateness of an aspect." .
#
# ex:negation1 a ex:Negation ;
#     rdfs:label "Negation" ;
#     rdfs:comment "An individual representing the negation aspect." .
#
# # Relationships
# ex:infinite1 ex:containsDeterminatenessOf ex:finite1 ;
#     ex:includesNegationOf ex:finite1 .
#
# ex:finite1 ex:isDeterminedBy ex:infinite1 .
# ```
#
# ### Explanation
#
# - **Classes**:
#   - **Finite**: Represents the finite aspect.
#   - **Infinite**: Represents the infinite aspect.
#   - **Determinateness**: Represents the determinateness of an aspect.
#   - **Negation**: Represents the negation aspect.
#
# - **Properties**:
#   - **contains determinateness of**: Indicates that the infinite contains the determinateness of the finite.
#   - **includes negation of**: Indicates that the infinite includes the negation of the finite.
#   - **is determined by**: Indicates that the finite is determined by the infinite.
#
# - **Individuals**:
#   - **finite1**: An instance of the class "Finite."
#   - **infinite1**: An instance of the class "Infinite."
#   - **determinateness1**: An instance of the class "Determinateness."
#   - **negation1**: An instance of the class "Negation."
#
# - **Relationships**:
#   - The infinite contains the determinateness and negation of the finite.
#   - The finite is determined by the infinite.
#
# This ontology captures the key concepts and relationships described in the provided text segment, emphasizing the interdependent determination and negation between the finite and the infinite. Please provide the next segment or additional instructions for further refinement.

# %% [markdown]
#     Regarding the finite, it is readily conceded that it is the null;
#     this very nothingness is however the infinite
#     from which it is inseparable.
#     Understood in this way, they may seem to be taken
#     according to the way each refers to its other.
#     Taken without this connecting reference,
#     and thus joined only through an “and,”
#     they subsist independently,
#     each only an existent over against the other.

# %% [markdown]
# 1. **Finite as Null**: The transcreation emphasizes the common conception of the finite as null or nothingness.
#
# 2. **Infinite as Nothingness of the Finite**: It highlights that the infinite is intrinsically connected to this notion of nothingness in the finite.
#
# 3. **Interconnected Understanding**: The translation underscores the interconnected nature of the finite and infinite when each is understood in reference to the other.
#
# 4. **Independent Existence in Separation**: The text illustrates that without this interconnected reference, the finite and infinite appear as independently existing entities.

# %% [markdown]
# ```turtle
# @prefix ex: <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# ex:Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite, which is considered the null." .
#
# ex:Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite, which is inseparable from the finite." .
#
# ex:Nothingness a owl:Class ;
#     rdfs:label "Nothingness" ;
#     rdfs:comment "Represents the nothingness of the finite." .
#
# ex:Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the independent existence of finite and infinite when taken without their connecting reference." .
#
# # Properties
# ex:isInseparableFrom a owl:ObjectProperty ;
#     rdfs:label "is inseparable from" ;
#     rdfs:comment "Indicates that the finite is inseparable from the infinite." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Infinite .
#
# ex:hasNothingness a owl:ObjectProperty ;
#     rdfs:label "has Nothingness" ;
#     rdfs:comment "Indicates that the finite has the quality of nothingness." ;
#     rdfs:domain ex:Finite ;
#     rdfs:range ex:Nothingness .
#
# ex:subsistsIndependently a owl:ObjectProperty ;
#     rdfs:label "subsists independently" ;
#     rdfs:comment "Indicates that finite and infinite subsist independently when joined only through an 'and'." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Existence .
#
# ex:refersTo a owl:ObjectProperty ;
#     rdfs:label "refers to" ;
#     rdfs:comment "Indicates that finite and infinite refer to each other." ;
#     rdfs:domain ex:Finite, ex:Infinite ;
#     rdfs:range ex:Finite, ex:Infinite .
#
# # Individuals
# ex:finite1 a ex:Finite ;
#     rdfs:label "Finite" ;
#     ex:hasNothingness ex:nothingness1 ;
#     ex:isInseparableFrom ex:infinite1 ;
#     ex:subsistsIndependently ex:existence1 ;
#     ex:refersTo ex:infinite1 .
#
# ex:infinite1 a ex:Infinite ;
#     rdfs:label "Infinite" ;
#     ex:subsistsIndependently ex:existence1 ;
#     ex:refersTo ex:finite1 .
#
# ex:nothingness1 a ex:Nothingness ;
#     rdfs:label "Nothingness" .
#
# ex:existence1 a ex:Existence ;
#     rdfs:label "Existence" .

# %% [markdown]
#     We have to examine how they would be constituted in this way.
#     The infinite, thus positioned, is one of the two;
#     but, as only one of them, it is itself finite,
#     it is not the whole but only one side;
#     it has its limit in that which stands over against it;
#     and so it is the finite infinite.
#     We have before us only two finites.

# %% [markdown]
# 1. **Infinite as Finite When Positioned Separately**: The transcreation emphasizes how the infinite, when considered as one of two separate entities, becomes finite itself.
#
# 2. **Finite Infinite Concept**: It highlights the emergence of the 'finite infinite' – an infinite that is limited by its opposition to the finite.
#
# 3. **Duality Leading to Two Finites**: The translation points out that in this scenario, we end up with two finite entities, rather than a true finite and infinite.
#
# 4. **Limitation of Separated View**: The text illustrates the inherent limitation in viewing the finite and infinite as separate and independent.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite, positioned as one of the two." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite aspect." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the limit that stands over against the infinite." .
#
# :FiniteInfinite a owl:Class ;
#     rdfs:label "Finite Infinite" ;
#     rdfs:comment "Represents the finite infinite, where the infinite is itself finite." .
#
# # Properties
# :isPositionedAs a owl:ObjectProperty ;
#     rdfs:label "is positioned as" ;
#     rdfs:comment "Indicates the positioning of the infinite as one of the two." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :FiniteInfinite .
#
# :hasLimit a owl:ObjectProperty ;
#     rdfs:label "has limit" ;
#     rdfs:comment "Indicates that the infinite has its limit in that which stands over against it." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Limit .
#
# :isFiniteInfinite a owl:ObjectProperty ;
#     rdfs:label "is finite infinite" ;
#     rdfs:comment "Indicates that the infinite is itself finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :FiniteInfinite .
#
# # Individuals
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isPositionedAs :finiteInfinite1 ;
#     :hasLimit :limit1 ;
#     :isFiniteInfinite :finiteInfinite1 .
#
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :finiteInfinite1 a :FiniteInfinite ;
#     rdfs:label "Finite Infinite" .

# %% [markdown]
#     The finitude of the infinite,
#     and therefore its unity with the finite,
#     lies in the very fact that it is separated from the finite
#     and placed, consequently, on one side.
#     The finite, for its part, removed from the infinite
#     and positioned for itself, is this self-reference
#     in which the relativity, its dependence and transitoriness, are removed;
#     it is the same self-subsistence and self-affirmation
#     which the infinite is presumed to be.

# %% [markdown]
# 1. **Finitude of the Infinite Through Separation**: The transcreation emphasizes that separating the infinite from the finite leads to its finitude.
#
# 2. **Unity of Finite and Infinite in Separation**: It highlights that this separation unites the finite and infinite in an unexpected way.
#
# 3. **Finite's Self-Reference and Self-Affirmation**: The translation points out that in its isolation, the finite assumes characteristics of self-subsistence and self-affirmation, akin to the infinite.
#
# 4. **Mutual Influence and Interdependence**: The text illustrates the mutual influence and interdependence of the finite and infinite when separated.

# %% [markdown]
#     The two pathways of consideration,
#     even though they seem at first to have
#     each a different determinateness for their point of departure;
#     the former inasmuch as it assumes it to be
#     only the reference of infinite and finite
#     to each other, of each to the other;
#     and the latter their complete separation from each other
#     yield one and the same result.

# %% [markdown]
# 1. **Two Paths of Consideration**: The transcreation highlights the two different approaches to understanding the finite and infinite – mutual reference and complete separation.
#
# 2. **Convergence to Same Result**: It emphasizes that despite their different starting points, both approaches lead to the same conclusion.
#
# 3. **Underlying Unity**: The translation underscores the underlying unity that emerges between the finite and infinite, regardless of the approach.
#
# 4. **Interconnectedness of Finite and Infinite**: The text illustrates the inherent interconnectedness that is revealed through both methods of consideration.

# %% [markdown]
#     The infinite and the finite, taken together
#     as referring to each other in a connection
#     which is presumed external but is in fact essential to them
#     (for without it, neither is what it is),
#     each contains its other in its own determination,
#     just as, when each is taken for itself,
#     when looked at on its terms,
#     each has the other present in it
#     as its own moment.

# %% [markdown]
# 1. **Essential Connection Between Finite and Infinite**: The transcreation underscores the essential, not merely external, connection between the finite and infinite.
#
# 2. **Mutual Containment in Each Other's Determination**: It highlights that each concept contains the essence of the other within its own determination.
#
# 3. **Presence of the Other in Isolation**: The translation points out that even when considered separately, each concept includes the other as a vital component.
#
# 4. **Internal Interweaving**: The text illustrates the internal interweaving of the finite and infinite within each other's conceptual framework.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the infinite, separated from the finite." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the finite, positioned for itself and self-referential." .
#
# :FinitudeOfInfinite a owl:Class ;
#     rdfs:label "Finitude of the Infinite" ;
#     rdfs:comment "Represents the finitude of the infinite and its unity with the finite." .
#
# :SelfReference a owl:Class ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "Represents the self-reference of the finite when positioned for itself." .
#
# :SelfSubsistence a owl:Class ;
#     rdfs:label "Self-Subsistence" ;
#     rdfs:comment "Represents the self-subsistence and self-affirmation of the finite." .
#
# # Properties
# :hasFinitude a owl:ObjectProperty ;
#     rdfs:label "has Finitude" ;
#     rdfs:comment "Indicates the finitude of the infinite and its unity with the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :FinitudeOfInfinite .
#
# :isSeparatedFrom a owl:ObjectProperty ;
#     rdfs:label "is separated from" ;
#     rdfs:comment "Indicates that the infinite is separated from the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Finite .
#
# :isPositionedForItself a owl:ObjectProperty ;
#     rdfs:label "is positioned for itself" ;
#     rdfs:comment "Indicates that the finite is positioned for itself and has self-reference." ;
#     rdfs:domain :Finite ;
#     rdfs:range :SelfReference .
#
# :hasSelfSubsistence a owl:ObjectProperty ;
#     rdfs:label "has Self-Subsistence" ;
#     rdfs:comment "Indicates that the finite has self-subsistence and self-affirmation." ;
#     rdfs:domain :Finite ;
#     rdfs:range :SelfSubsistence .
#
# # Individuals
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :hasFinitude :finitudeOfInfinite1 ;
#     :isSeparatedFrom :finite1 .
#
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isPositionedForItself :selfReference1 ;
#     :hasSelfSubsistence :selfSubsistence1 .
#
# :finitudeOfInfinite1 a :FinitudeOfInfinite ;
#     rdfs:label "Finitude of the Infinite" .
#
# :selfReference1 a :SelfReference ;
#     rdfs:label "Self-Reference" .
#
# :selfSubsistence1 a :SelfSubsistence ;
#     rdfs:label "Self-Subsistence" .

# %% [markdown]
#     This yields, then, the scandalous unity
#     of the finite and the infinite,
#     the unity which is itself the infinite
#     that embraces both itself and the finite,
#     the infinite, therefore, understood in a sense
#     other than when the finite is separated from it
#     and placed on the other side from it.

# %% [markdown]
# 1. **Paradoxical Unity**: The transcreation emphasizes the paradoxical and 'scandalous' nature of the unity between the finite and the infinite.
#
# 2. **Infinite as Encompassing Both**: It highlights that this unity involves the infinite encompassing both itself and the finite.
#
# 3. **Contrast with Traditional Notion**: The translation points out the contrast with traditional views that separate the finite and infinite.
#
# 4. **Different Understanding of the Infinite**: The text illustrates a different perspective on the infinite, one that is more integrated and encompassing.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :ScandalousUnity a owl:Class ;
#     rdfs:label "Scandalous Unity" ;
#     rdfs:comment "Represents the unity of the finite and the infinite that embraces both." .
#
# :EmbracingUnity a owl:Class ;
#     rdfs:label "Embracing Unity" ;
#     rdfs:comment "Represents the unity which is the infinite embracing both itself and the finite." .
#
# :SeparatedInfinite a owl:Class ;
#     rdfs:label "Separated Infinite" ;
#     rdfs:comment "Represents the infinite when the finite is separated from it and placed on the other side." .
#
# # Properties
# :hasScandalousUnity a owl:ObjectProperty ;
#     rdfs:label "has Scandalous Unity" ;
#     rdfs:comment "Indicates the unity of the finite and the infinite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :ScandalousUnity .
#
# :embraces a owl:ObjectProperty ;
#     rdfs:label "embraces" ;
#     rdfs:comment "Indicates that the infinite embraces both itself and the finite." ;
#     rdfs:domain :EmbracingUnity ;
#     rdfs:range :Infinite, :Finite .
#
# :understoodAs a owl:ObjectProperty ;
#     rdfs:label "understood as" ;
#     rdfs:comment "Indicates the sense in which the infinite is understood when not separated from the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :EmbracingUnity .
#
# :isSeparatedFrom a owl:ObjectProperty ;
#     rdfs:label "is separated from" ;
#     rdfs:comment "Indicates that the infinite is separated from the finite and placed on the other side." ;
#     rdfs:domain :SeparatedInfinite ;
#     rdfs:range :Finite .
#
# # Individuals
# :scandalousUnity1 a :ScandalousUnity ;
#     rdfs:label "Scandalous Unity" .
#
# :embracingUnity1 a :EmbracingUnity ;
#     rdfs:label "Embracing Unity" ;
#     :embraces :infinite1, :finite1 .
#
# :separatedInfinite1 a :SeparatedInfinite ;
#     rdfs:label "Separated Infinite" ;
#     :isSeparatedFrom :finite1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :hasScandalousUnity :scandalousUnity1 ;
#     :understoodAs :embracingUnity1 .
#
# :finite1 a :Finite ;
#     rdfs:label "Finite" .

# %% [markdown]
#     Since they must now also be distinguished,
#     each is within it, as just shown,
#     itself the unity of both;
#     there are thus two such unities.
#     The common element, the unity of both determinacies,
#     as such a unity, posits them at first as negated,
#     for each is to be what it is in being distinguished;
#     in their unity, therefore, they lose their qualitative nature;

# %% [markdown]
# 1. **Necessity of Distinction**: The transcreation emphasizes the need to distinguish between the finite and the infinite.
#
# 2. **Embodiment of Unity in Each**: It highlights that both the finite and the infinite inherently contain the unity of both.
#
# 3. **Two Unities**: The translation points out the existence of two unities, one represented in the finite and the other in the infinite.
#
# 4. **Negation in Common Element**: The text notes that the common element of their unity initially posits each as negated through distinction.
#
# 5. **Loss of Qualitative Nature in Unity**: The aim is to present Hegel's concept that in their unity, the finite and the infinite lose their distinct qualities.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :UnityOfBoth a owl:Class ;
#     rdfs:label "Unity of Both" ;
#     rdfs:comment "Represents the unity of both finite and infinite." .
#
# :TwoUnities a owl:Class ;
#     rdfs:label "Two Unities" ;
#     rdfs:comment "Represents the concept of two unities where each is the unity of both finite and infinite." .
#
# :CommonElement a owl:Class ;
#     rdfs:label "Common Element" ;
#     rdfs:comment "Represents the common element, the unity of both determinacies." .
#
# :Quality a owl:Class ;
#     rdfs:label "Quality" ;
#     rdfs:comment "Represents the qualitative nature involved in the unity of finite and infinite." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents the reality introduced by quality in the unity." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the negation introduced by quality in the unity." .
#
# # Properties
# :isDistinguishedBy a owl:ObjectProperty ;
#     rdfs:label "is distinguished by" ;
#     rdfs:comment "Indicates that each unity is distinguished by its own unity of both finite and infinite." ;
#     rdfs:domain :TwoUnities ;
#     rdfs:range :UnityOfBoth .
#
# :positsAsNegated a owl:ObjectProperty ;
#     rdfs:label "posits as negated" ;
#     rdfs:comment "Indicates that the common element posits the unities as negated." ;
#     rdfs:domain :CommonElement ;
#     rdfs:range :TwoUnities .
#
# :losesQualitativeNature a owl:ObjectProperty ;
#     rdfs:label "loses qualitative nature" ;
#     rdfs:comment "Indicates that in their unity, the finite and infinite lose their qualitative nature." ;
#     rdfs:domain :UnityOfBoth ;
#     rdfs:range :Quality .
#
# :hasQuality a owl:ObjectProperty ;
#     rdfs:label "has quality" ;
#     rdfs:comment "Indicates that the unity of finite and infinite has a qualitative nature." ;
#     rdfs:domain :UnityOfBoth ;
#     rdfs:range :Quality .
#
# :hasReality a owl:ObjectProperty ;
#     rdfs:label "has reality" ;
#     rdfs:comment "Indicates the reality aspect introduced by quality." ;
#     rdfs:domain :Quality ;
#     rdfs:range :Reality .
#
# :hasNegation a owl:ObjectProperty ;
#     rdfs:label "has negation" ;
#     rdfs:comment "Indicates the negation aspect introduced by quality." ;
#     rdfs:domain :Quality ;
#     rdfs:range :Negation .
#
# # Individuals
# :unityOfBoth1 a :UnityOfBoth ;
#     rdfs:label "Unity of Both" ;
#     :losesQualitativeNature :quality1 ;
#     :hasQuality :quality1 .
#
# :twoUnities1 a :TwoUnities ;
#     rdfs:label "Two Unities" ;
#     :isDistinguishedBy :unityOfBoth1 .
#
# :commonElement1 a :CommonElement ;
#     rdfs:label "Common Element" ;
#     :positsAsNegated :twoUnities1 .
#
# :quality1 a :Quality ;
#     rdfs:label "Quality" ;
#     :hasReality :reality1 ;
#     :hasNegation :negation1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .

# %% [markdown]
#     an important reflection for countering the incorrigible habit
#     of representing the infinite and the finite, in their unity,
#     as still holding on to the quality that
#     they would have when taken apart from each other;
#     of seeing in that unity, therefore, nothing except contradiction,
#     and not also the resolution of the contradiction by
#     the negation of the qualitative determinateness of each.
#     And so is the unity of the infinite and the finite,
#     at first simple and universal, falsified.

# %% [markdown]
# 1. **Misconception in Unity Representation**: The transcreation emphasizes the common error in representing the finite and infinite as retaining their separate qualities in unity.
#
# 2. **View of Unity as Contradiction**: It highlights how this leads to seeing their unity only as a contradiction, rather than also as a resolution.
#
# 3. **Negation of Qualitative Determinateness**: The translation points out the resolution through negating the individual qualities of the finite and infinite in their unity.
#
# 4. **Falsification of Simple Unity**: The text suggests that this misconception distorts the simple and universal nature of their unity.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Reflection a owl:Class ;
#     rdfs:label "Reflection" ;
#     rdfs:comment "Represents the reflection on the unity of finite and infinite." .
#
# :Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the unity of the infinite and the finite." .
#
# :QualitativeDeterminateness a owl:Class ;
#     rdfs:label "Qualitative Determinateness" ;
#     rdfs:comment "Represents the qualitative determinateness of the finite and infinite." .
#
# :Contradiction a owl:Class ;
#     rdfs:label "Contradiction" ;
#     rdfs:comment "Represents the contradiction seen in the unity of finite and infinite." .
#
# :Resolution a owl:Class ;
#     rdfs:label "Resolution" ;
#     rdfs:comment "Represents the resolution of the contradiction by negating qualitative determinateness." .
#
# # Properties
# :reflectsOn a owl:ObjectProperty ;
#     rdfs:label "reflects on" ;
#     rdfs:comment "Indicates the reflection on the unity of finite and infinite." ;
#     rdfs:domain :Reflection ;
#     rdfs:range :Unity .
#
# :hasQuality a owl:ObjectProperty ;
#     rdfs:label "has quality" ;
#     rdfs:comment "Indicates that the unity is falsely represented as holding on to the quality of finite and infinite when taken apart." ;
#     rdfs:domain :Unity ;
#     rdfs:range :QualitativeDeterminateness .
#
# :containsContradiction a owl:ObjectProperty ;
#     rdfs:label "contains contradiction" ;
#     rdfs:comment "Indicates the contradiction seen in the unity of finite and infinite." ;
#     rdfs:domain :Unity ;
#     rdfs:range :Contradiction .
#
# :resolvesContradiction a owl:ObjectProperty ;
#     rdfs:label "resolves contradiction" ;
#     rdfs:comment "Indicates the resolution of the contradiction by negating qualitative determinateness." ;
#     rdfs:domain :Unity ;
#     rdfs:range :Resolution .
#
# :isNegatedBy a owl:ObjectProperty ;
#     rdfs:label "is negated by" ;
#     rdfs:comment "Indicates that qualitative determinateness is negated in the resolution." ;
#     rdfs:domain :QualitativeDeterminateness ;
#     rdfs:range :Resolution .
#
# # Individuals
# :reflection1 a :Reflection ;
#     rdfs:label "Reflection" ;
#     :reflectsOn :unity1 .
#
# :unity1 a :Unity ;
#     rdfs:label "Unity" ;
#     :hasQuality :qualitativeDeterminateness1 ;
#     :containsContradiction :contradiction1 ;
#     :resolvesContradiction :resolution1 .
#
# :qualitativeDeterminateness1 a :QualitativeDeterminateness ;
#     rdfs:label "Qualitative Determinateness" ;
#     :isNegatedBy :resolution1 .
#
# :contradiction1 a :Contradiction ;
#     rdfs:label "Contradiction" .
#
# :resolution1 a :Resolution ;
#     rdfs:label "Resolution" .

# %% [markdown]
#     But further, since the two are now to be taken
#     also as distinguished, the unity of the infinite
#     which is itself both of these moments
#     is determined differently in each.
#     The infinite, determined as such, has in it
#     the finitude which is distinct from it;
#     in this unity, the infinite is the in-itself
#     while the finite is only determinateness,
#     the limit in the infinite.

# %% [markdown]
# 1. **Different Determinations in Unity**: The transcreation emphasizes that in the unity of the infinite and finite, each is determined differently.
#
# 2. **Infinite Including Finitude**: It highlights that the infinite, in its own determination, includes the concept of finitude within itself.
#
# 3. **Infinite as 'In-Itself'**: The translation illustrates that in this unity, the infinite is the underlying reality, the 'in-itself.'
#
# 4. **Finite as Limit in the Infinite**: The text points out that the finite is regarded as a determinateness or limit within the infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :DistinguishedUnity a owl:Class ;
#     rdfs:label "Distinguished Unity" ;
#     rdfs:comment "Represents the unity of the infinite, which is determined differently in each moment." .
#
# :InItself a owl:Class ;
#     rdfs:label "In-Itself" ;
#     rdfs:comment "Represents the infinite as the in-itself in the unity." .
#
# :Determinateness a owl:Class ;
#     rdfs:label "Determinateness" ;
#     rdfs:comment "Represents the finite as only determinateness, the limit in the infinite." .
#
# # Properties
# :hasDistinguishedUnity a owl:ObjectProperty ;
#     rdfs:label "has Distinguished Unity" ;
#     rdfs:comment "Indicates that the unity of the infinite is determined differently in each moment." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :DistinguishedUnity .
#
# :hasInItself a owl:ObjectProperty ;
#     rdfs:label "has In-Itself" ;
#     rdfs:comment "Indicates that the infinite, in this unity, is the in-itself." ;
#     rdfs:domain :DistinguishedUnity ;
#     rdfs:range :InItself .
#
# :hasDeterminateness a owl:ObjectProperty ;
#     rdfs:label "has Determinateness" ;
#     rdfs:comment "Indicates that the finite, in this unity, is only determinateness." ;
#     rdfs:domain :DistinguishedUnity ;
#     rdfs:range :Determinateness .
#
# # Individuals
# :distinguishedUnity1 a :DistinguishedUnity ;
#     rdfs:label "Distinguished Unity" ;
#     :hasInItself :inItself1 ;
#     :hasDeterminateness :determinateness1 .
#
# :inItself1 a :InItself ;
#     rdfs:label "In-Itself" .
#
# :determinateness1 a :Determinateness ;
#     rdfs:label "Determinateness" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :hasDistinguishedUnity :distinguishedUnity1 .

# %% [markdown]
#     But such a limit is the absolute
#     other of the infinite, its opposite.
#     The infinite's determination, which is the in-itself as such,
#     is corrupted by being saddled with a quality of this sort;
#     the infinite is thus a finitized infinite.

# %% [markdown]
# 1. **Limit as Opposite of the Infinite**: The transcreation emphasizes Hegel's critique of viewing the limit as the absolute other of the infinite.
#
# 2. **Corruption of Infinite's Determination**: It highlights how the association of the infinite with a finite quality corrupts its true nature.
#
# 3. **Infinite as 'Finitized'**: The translation underscores that this approach leads to the infinite becoming a 'finitized' version of itself.
#
# 4. **Contradiction in Infinite's Nature**: The text illustrates the contradiction introduced by associating the infinite with finitude.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Opposite a owl:Class ;
#     rdfs:label "Opposite" ;
#     rdfs:comment "Represents the absolute other of the infinite, its opposite." .
#
# :FinitizedInfinite a owl:Class ;
#     rdfs:label "Finitized Infinite" ;
#     rdfs:comment "Represents the infinite corrupted by being saddled with a quality, making it a finitized infinite." .
#
# # Properties
# :hasOpposite a owl:ObjectProperty ;
#     rdfs:label "has Opposite" ;
#     rdfs:comment "Indicates that the limit is the absolute other of the infinite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Opposite .
#
# :isCorruptedBy a owl:ObjectProperty ;
#     rdfs:label "is corrupted by" ;
#     rdfs:comment "Indicates that the infinite is corrupted by being saddled with a quality." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Quality .
#
# :isFinitizedInfinite a owl:ObjectProperty ;
#     rdfs:label "is finitized infinite" ;
#     rdfs:comment "Indicates that the infinite is thus a finitized infinite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :FinitizedInfinite .
#
# # Individuals
# :opposite1 a :Opposite ;
#     rdfs:label "Opposite" .
#
# :finitizedInfinite1 a :FinitizedInfinite ;
#     rdfs:label "Finitized Infinite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :hasOpposite :opposite1 ;
#     :isCorruptedBy :quality1 ;
#     :isFinitizedInfinite :finitizedInfinite1 .
#
# :quality1 a :Quality ;
#     rdfs:label "Quality" .

# %% [markdown]
#     Likewise, since the finite is as such only the non-in-itself
#     but equally has its opposite in it by virtue
#     of the said unity,
#     it is elevated above its worth
#     and, so to speak, infinitely elevated;
#     it is posited as the infinitized finite.

# %% [markdown]
# 1. **Finite as 'Non-in-Itself'**: The transcreation emphasizes that the finite is fundamentally lacking in inherent essence.
#
# 2. **Elevation of the Finite**: It highlights how the finite is 'infinitely elevated' due to its unity with the infinite.
#
# 3. **Concept of 'Infinitized Finite'**: The translation points out the transformation of the finite into the 'infinitized finite.'
#
# 4. **Transcendence of Finite Limitations**: The text illustrates that through this elevation, the finite transcends its inherent limitations.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :NonInItself a owl:Class ;
#     rdfs:label "Non-In-Itself" ;
#     rdfs:comment "Represents the finite as the non-in-itself." .
#
# :InfinitizedFinite a owl:Class ;
#     rdfs:label "Infinitized Finite" ;
#     rdfs:comment "Represents the finite infinitely elevated and posited as the infinitized finite." .
#
# # Properties
# :hasNonInItself a owl:ObjectProperty ;
#     rdfs:label "has Non-In-Itself" ;
#     rdfs:comment "Indicates that the finite is the non-in-itself." ;
#     rdfs:domain :Finite ;
#     rdfs:range :NonInItself .
#
# :hasOpposite a owl:ObjectProperty ;
#     rdfs:label "has Opposite" ;
#     rdfs:comment "Indicates that the finite has its opposite in it by virtue of the unity." ;
#     rdfs:domain :Finite ;
#     rdfs:range :Opposite .
#
# :isInfinitelyElevated a owl:ObjectProperty ;
#     rdfs:label "is Infinitely Elevated" ;
#     rdfs:comment "Indicates that the finite is elevated above its worth and infinitely elevated." ;
#     rdfs:domain :Finite ;
#     rdfs:range :InfinitizedFinite .
#
# # Individuals
# :nonInItself1 a :NonInItself ;
#     rdfs:label "Non-In-Itself" .
#
# :infinitizedFinite1 a :InfinitizedFinite ;
#     rdfs:label "Infinitized Finite" .
#
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :hasNonInItself :nonInItself1 ;
#     :hasOpposite :opposite1 ;
#     :isInfinitelyElevated :infinitizedFinite1 .
#
# :opposite1 a :Opposite ;
#     rdfs:label "Opposite" .

# %% [markdown]
#     Likewise, just as the simple unity of infinite and finite was
#     falsified before by the understanding, so too is the double unity.
#     Here also this happens because the infinite is taken
#     in one of the two unities not as negated but,
#     rather, as the in-itself in which, therefore,
#     determinateness and restriction should not be posited,
#     for they would debase and corrupt it.

# %% [markdown]
# 1. **Misrepresentation by the Understanding**: The transcreation emphasizes the misunderstanding of the finite and infinite's unity by the understanding.
#
# 2. **Distortion of Double Unity**: It highlights how this misinterpretation extends to the double unity, where the finite and infinite are unified yet distinct.
#
# 3. **Infinite as Pure 'In-Itself'**: The translation critiques the flawed perception of the infinite as an untainted 'in-itself' without negation.
#
# 4. **Flaw in Excluding Determinateness**: The text points out the error in believing that determinateness or restriction corrupts the infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :DoubleUnity a owl:Class ;
#     rdfs:label "Double Unity" ;
#     rdfs:comment "Represents the double unity of the infinite and finite." .
#
# :Understanding a owl:Class ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "Represents the understanding that falsifies the unity of infinite and finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in the unity of infinite and finite." .
#
# # Properties
# :falsifies a owl:ObjectProperty ;
#     rdfs:label "falsifies" ;
#     rdfs:comment "Indicates that the understanding falsifies the unity of infinite and finite." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :DoubleUnity .
#
# :isNotNegated a owl:ObjectProperty ;
#     rdfs:label "is not negated" ;
#     rdfs:comment "Indicates that the infinite is taken as not negated in one of the unities." ;
#     rdfs:domain :DoubleUnity ;
#     rdfs:range :Infinite .
#
# :hasInItself a owl:ObjectProperty ;
#     rdfs:label "has In-Itself" ;
#     rdfs:comment "Indicates that the infinite is taken as the in-itself in the unity." ;
#     rdfs:domain :DoubleUnity ;
#     rdfs:range :InItself .
#
# :excludesDeterminateness a owl:ObjectProperty ;
#     rdfs:label "excludes Determinateness" ;
#     rdfs:comment "Indicates that determinateness and restriction are excluded from the in-itself." ;
#     rdfs:domain :InItself ;
#     rdfs:range :Determinateness .
#
# # Individuals
# :doubleUnity1 a :DoubleUnity ;
#     rdfs:label "Double Unity" ;
#     :isNotNegated :infinite1 ;
#     :hasInItself :inItself1 .
#
# :understanding1 a :Understanding ;
#     rdfs:label "Understanding" ;
#     :falsifies :doubleUnity1 .
#
# :inItself1 a :InItself ;
#     rdfs:label "In-Itself" ;
#     :excludesDeterminateness :determinateness1 .
#
# :determinateness1 a :Determinateness ;
#     rdfs:label "Determinateness" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .

# %% [markdown]
#     Conversely, the finite is equally held fixed
#     as not negated, although null in itself;
#     so that, in combination with the infinite,
#     it is elevated to what it is not
#     and is thereby infinitized notwithstanding its determination
#     that has not vanished but is rather perpetuated.

# %% [markdown]
# 1. **Finite Held as Non-Negated**: The transcreation emphasizes the perception of the finite as something that is not negated, despite its inherent nullity.
#
# 2. **Paradoxical Elevation of the Finite**: It highlights the paradoxical elevation of the finite in its combination with the infinite, becoming 'infinitized.'
#
# 3. **Persistence of Finite Determination**: The translation points out that this elevation occurs even though the finite's inherent nature has not vanished.
#
# 4. **Contradiction in Infinitized State**: The text illustrates the contradiction of the finite being recognized for its nullity while being raised to an 'infinitized' status.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :FixedFinite a owl:Class ;
#     rdfs:label "Fixed Finite" ;
#     rdfs:comment "Represents the finite held fixed as not negated." .
#
# :InfinitizedState a owl:Class ;
#     rdfs:label "Infinitized State" ;
#     rdfs:comment "Represents the finite elevated to an infinitized state in combination with the infinite." .
#
# :NullInItself a owl:Class ;
#     rdfs:label "Null In-Itself" ;
#     rdfs:comment "Represents the finite as null in itself." .
#
# :PerpetuatedDetermination a owl:Class ;
#     rdfs:label "Perpetuated Determination" ;
#     rdfs:comment "Represents the determination of the finite that has not vanished but is perpetuated." .
#
# # Properties
# :heldFixedAsNotNegated a owl:ObjectProperty ;
#     rdfs:label "held fixed as not negated" ;
#     rdfs:comment "Indicates that the finite is held fixed as not negated." ;
#     rdfs:domain :Finite ;
#     rdfs:range :FixedFinite .
#
# :isNullInItself a owl:ObjectProperty ;
#     rdfs:label "is null in itself" ;
#     rdfs:comment "Indicates that the finite is null in itself." ;
#     rdfs:domain :FixedFinite ;
#     rdfs:range :NullInItself .
#
# :isInfinitizedInCombinationWith a owl:ObjectProperty ;
#     rdfs:label "is infinitized in combination with" ;
#     rdfs:comment "Indicates that the finite is elevated to an infinitized state in combination with the infinite." ;
#     rdfs:domain :Finite ;
#     rdfs:range :InfinitizedState .
#
# :hasPerpetuatedDetermination a owl:ObjectProperty ;
#     rdfs:label "has perpetuated determination" ;
#     rdfs:comment "Indicates that the determination of the finite has not vanished but is perpetuated." ;
#     rdfs:domain :InfinitizedState ;
#     rdfs:range :PerpetuatedDetermination .
#
# # Individuals
# :fixedFinite1 a :FixedFinite ;
#     rdfs:label "Fixed Finite" ;
#     :isNullInItself :nullInItself1 .
#
# :infinitizedState1 a :InfinitizedState ;
#     rdfs:label "Infinitized State" ;
#     :hasPerpetuatedDetermination :perpetuatedDetermination1 .
#
# :nullInItself1 a :NullInItself ;
#     rdfs:label "Null In-Itself" .
#
# :perpetuatedDetermination1 a :PerpetuatedDetermination ;
#     rdfs:label "Perpetuated Determination" .
#
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :heldFixedAsNotNegated :fixedFinite1 ;
#     :isInfinitizedInCombinationWith :infinitizedState1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .

# %% [markdown]
#     The falsification that the understanding perpetrates
#     with respect to the finite and the infinite,
#     of holding their reciprocal reference fixed
#     as qualitative differentiation,
#     of maintaining that their determination is separate,
#     indeed, absolutely separate, comes from forgetting
#     what for the understanding itself is the concept of these moments.

# %% [markdown]
# 1. **Understanding's Falsification**: The transcreation emphasizes the understanding's incorrect interpretation of the finite and infinite as qualitatively different and separate.
#
# 2. **Fixation on Separateness**: It highlights the understanding's insistence on treating their determinations as completely distinct.
#
# 3. **Forgetting Conceptual Essence**: The translation points out that this error arises from forgetting the inherent conceptual nature of the finite and infinite within the understanding's own framework.
#
# 4. **Neglect of Deeper Interplay**: The text suggests that this misinterpretation overlooks the true interconnectedness and unity of the finite and infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Falsification a owl:Class ;
#     rdfs:label "Falsification" ;
#     rdfs:comment "Represents the falsification that the understanding perpetrates with respect to the finite and the infinite." .
#
# :ReciprocalReference a owl:Class ;
#     rdfs:label "Reciprocal Reference" ;
#     rdfs:comment "Represents the reciprocal reference between the finite and the infinite." .
#
# :QualitativeDifferentiation a owl:Class ;
#     rdfs:label "Qualitative Differentiation" ;
#     rdfs:comment "Represents the qualitative differentiation held fixed by the understanding." .
#
# :SeparateDetermination a owl:Class ;
#     rdfs:label "Separate Determination" ;
#     rdfs:comment "Represents the separate determination maintained by the understanding." .
#
# :ConceptOfMoments a owl:Class ;
#     rdfs:label "Concept of Moments" ;
#     rdfs:comment "Represents the concept of the moments of the finite and the infinite for the understanding." .
#
# # Properties
# :perpetratesFalsification a owl:ObjectProperty ;
#     rdfs:label "perpetrates falsification" ;
#     rdfs:comment "Indicates that the understanding perpetrates falsification with respect to the finite and the infinite." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :Falsification .
#
# :holdsFixed a owl:ObjectProperty ;
#     rdfs:label "holds fixed" ;
#     rdfs:comment "Indicates that the understanding holds the reciprocal reference fixed as qualitative differentiation." ;
#     rdfs:domain :Falsification ;
#     rdfs:range :QualitativeDifferentiation .
#
# :maintainsSeparation a owl:ObjectProperty ;
#     rdfs:label "maintains separation" ;
#     rdfs:comment "Indicates that the understanding maintains the determination of the finite and infinite as separate." ;
#     rdfs:domain :Falsification ;
#     rdfs:range :SeparateDetermination .
#
# :forgetsConcept a owl:ObjectProperty ;
#     rdfs:label "forgets concept" ;
#     rdfs:comment "Indicates that the understanding forgets the concept of the moments of the finite and the infinite." ;
#     rdfs:domain :Falsification ;
#     rdfs:range :ConceptOfMoments .
#
# # Individuals
# :falsification1 a :Falsification ;
#     rdfs:label "Falsification" ;
#     :holdsFixed :qualitativeDifferentiation1 ;
#     :maintainsSeparation :separateDetermination1 ;
#     :forgetsConcept :conceptOfMoments1 .
#
# :reciprocalReference1 a :ReciprocalReference ;
#     rdfs:label "Reciprocal Reference" .
#
# :qualitativeDifferentiation1 a :QualitativeDifferentiation ;
#     rdfs:label "Qualitative Differentiation" .
#
# :separateDetermination1 a :SeparateDetermination ;
#     rdfs:label "Separate Determination" .
#
# :conceptOfMoments1 a :ConceptOfMoments ;
#     rdfs:label "Concept of Moments" .
#
# :understanding1 a :Understanding ;
#     rdfs:label "Understanding" ;
#     :perpetratesFalsification :falsification1 .

# %% [markdown]
#     According to this concept, the unity of the finite and the infinite
#     is not an external bringing together of them,
#     nor an incongruous combination that goes against their nature,
#     one in which inherently separate and opposed terms
#     that exist independently and are consequently incompatible,
#     would be knotted together.

# %% [markdown]
# 1. **Unity Beyond External Amalgamation**: The transcreation emphasizes that the unity of the finite and infinite is not an external merging.
#
# 2. **Rejection of Incongruous Combination**: It highlights Hegel's view that their unity is not a forced combination of incompatible entities.
#
# 3. **Inherent Interconnectedness**: The translation points out the intrinsic, harmonious nature of the unity between the finite and infinite.
#
# 4. **Contrast with Forced Knotting**: The text contrasts Hegel’s perspective with the idea of forcibly ‘knotting together’ separate entities.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :ExternalCombination a owl:Class ;
#     rdfs:label "External Combination" ;
#     rdfs:comment "Represents an external bringing together of finite and infinite." .
#
# :IncongruousCombination a owl:Class ;
#     rdfs:label "Incongruous Combination" ;
#     rdfs:comment "Represents an incongruous combination that goes against the nature of the finite and infinite." .
#
# # Properties
# :unitesInternally a owl:ObjectProperty ;
#     rdfs:label "unites internally" ;
#     rdfs:comment "Indicates that the unity of finite and infinite is internal and respects their nature." ;
#     rdfs:domain :AffirmativeInfinity ;
#     rdfs:range :Finite, :Infinite .
#
# :avoidsExternalCombination a owl:ObjectProperty ;
#     rdfs:label "avoids external combination" ;
#     rdfs:comment "Indicates that the unity of finite and infinite is not an external combination." ;
#     rdfs:domain :AffirmativeInfinity ;
#     rdfs:range :ExternalCombination .
#
# :avoidsIncongruousCombination a owl:ObjectProperty ;
#     rdfs:label "avoids incongruous combination" ;
#     rdfs:comment "Indicates that the unity of finite and infinite is not an incongruous combination." ;
#     rdfs:domain :AffirmativeInfinity ;
#     rdfs:range :IncongruousCombination .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" ;
#     :unitesInternally :finite1, :infinite1 ;
#     :avoidsExternalCombination :externalCombination1 ;
#     :avoidsIncongruousCombination :incongruousCombination1 .
#
# :externalCombination1 a :ExternalCombination ;
#     rdfs:label "External Combination" .
#
# :incongruousCombination1 a :IncongruousCombination ;
#     rdfs:label "Incongruous Combination" .

# %% [markdown]
#     Rather, each is itself this unity,
#     and this only as a sublating of itself
#     in which neither would have an advantage over the other
#     in in-itselfness and affirmative existence.
#     As has earlier been shown,
#     finitude is only as a transcending of itself;
#     it is therefore within it that the infinite,
#     the other of itself, is contained.

# %% [markdown]
# 1. **Unity in Both Finite and Infinite**: The transcreation emphasizes that the finite and the infinite both embody the same unity.
#
# 2. **Sublation as Self-Transcendence**: It highlights the process of sublation as a mutual self-transcendence, where neither has an advantage.
#
# 3. **Finitude’s Transcendence**: The translation underscores that finitude's nature is to transcend itself, thereby containing the infinite.
#
# 4. **Infinite Contained in Finite**: The text illustrates that within the finite lies the infinite, challenging traditional notions of their separation.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "Represents the process of sublation (Aufhebung) in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# # Properties
# :unitesInternally a owl:ObjectProperty ;
#     rdfs:label "unites internally" ;
#     rdfs:comment "Indicates that the unity of finite and infinite is internal and respects their nature." ;
#     rdfs:domain :AffirmativeInfinity ;
#     rdfs:range :Finite, :Infinite .
#
# :isContainedWithin a owl:ObjectProperty ;
#     rdfs:label "is contained within" ;
#     rdfs:comment "Indicates that the infinite is contained within the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Finite .
#
# :sublatesItself a owl:ObjectProperty ;
#     rdfs:label "sublates itself" ;
#     rdfs:comment "Indicates that an entity sublates (negates and preserves) itself." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Sublation .
#
# :transcendsItself a owl:ObjectProperty ;
#     rdfs:label "transcends itself" ;
#     rdfs:comment "Indicates that finitude transcends itself." ;
#     rdfs:domain :Finite ;
#     rdfs:range :Transcendence .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" ;
#     :unitesInternally :finite1, :infinite1 ;
#     :isContainedWithin :finite1 ;
#     :sublatesItself :sublation1 ;
#     :transcendsItself :transcendence1 .
#
# :sublation1 a :Sublation ;
#     rdfs:label "Sublation" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .

# %% [markdown]
#     Similarly, the infinite is only as the transcending of the finite;
#     it therefore contains its other essentially,
#     and it is thus within it that it is the other of itself.
#     The finite is not sublated by the infinite
#     as by a power present outside it;
#     its infinity consists rather in sublating itself.

# %% [markdown]
# 1. **Infinite as Transcendence of Finite**: The transcreation underscores that the infinite is characterized by its transcendence over the finite.
#
# 2. **Infinite Contains the Finite**: It highlights that the infinite inherently embodies the finite within itself.
#
# 3. **Finite as 'Other' Within Infinite**: The translation points out that the finite becomes the 'other' of the infinite, integral to its nature.
#
# 4. **Self-Transcendence of the Finite**: The text illustrates that the infinity of the finite lies in its own act of self-transcendence.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "Represents the process of sublation (Aufhebung) in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# # Properties
# :containsEssentially a owl:ObjectProperty ;
#     rdfs:label "contains essentially" ;
#     rdfs:comment "Indicates that the infinite essentially contains the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Finite .
#
# :isOtherOfItself a owl:ObjectProperty ;
#     rdfs:label "is other of itself" ;
#     rdfs:comment "Indicates that the infinite is the other of itself through containing the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Infinite .
#
# :isContainedWithin a owl:ObjectProperty ;
#     rdfs:label "is contained within" ;
#     rdfs:comment "Indicates that the infinite is contained within the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Finite .
#
# :sublatesItself a owl:ObjectProperty ;
#     rdfs:label "sublates itself" ;
#     rdfs:comment "Indicates that an entity sublates (negates and preserves) itself." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Sublation .
#
# :transcendsItself a owl:ObjectProperty ;
#     rdfs:label "transcends itself" ;
#     rdfs:comment "Indicates that finitude transcends itself." ;
#     rdfs:domain :Finite ;
#     rdfs:range :Transcendence .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :sublatesItself :sublation1 ;
#     :transcendsItself :transcendence1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :containsEssentially :finite1 ;
#     :isOtherOfItself :infinite1 ;
#     :sublatesItself :sublation1 ;
#     :transcendsItself :transcendence1 .
#
# :sublation1 a :Sublation ;
#     rdfs:label "Sublation" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .

# %% [markdown]
#     This sublating is not, consequently,
#     alteration or otherness in general,
#     not the sublating of something.
#     That into which the finite is sublated is
#     the infinite as the negating of finitude.
#     But the latter has long since been only existence,
#     determined as a non-being.

# %% [markdown]
# 1. **Sublation Beyond Simple Alteration**: The transcreation emphasizes that sublation is more than just change or general negation.
#
# 2. **Transformation to the Infinite**: It highlights the transformation of the finite into the infinite as a fundamental aspect of sublation.
#
# 3. **Infinite as Negation of Finitude**: The translation illustrates that the infinite represents the negation of the finite's 'non-being' state.
#
# 4. **Redefinition of Finitude**: The text points out that finitude has been redefined as a form of existence determined as non-being.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "Represents the process of sublation (Aufhebung) in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# # Properties
# :sublatesInto a owl:ObjectProperty ;
#     rdfs:label "sublates into" ;
#     rdfs:comment "Indicates that the finite sublates into the infinite." ;
#     rdfs:domain :Finite ;
#     rdfs:range :Infinite .
#
# :negatesFinitude a owl:ObjectProperty ;
#     rdfs:label "negates finitude" ;
#     rdfs:comment "Indicates that the infinite negates finitude." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Negation .
#
# :isDeterminedAsNonBeing a owl:ObjectProperty ;
#     rdfs:label "is determined as non-being" ;
#     rdfs:comment "Indicates that the finite is determined as non-being." ;
#     rdfs:domain :Finite ;
#     rdfs:range :Negation .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :sublatesInto :infinite1 ;
#     :isDeterminedAsNonBeing :negation1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :negatesFinitude :negation1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :sublation1 a :Sublation ;
#     rdfs:label "Sublation" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .

# %% [markdown]
#     It is only the negation, therefore,
#     that in the negation sublates itself.
#     Thus infinity is determined on its side
#     as the negative of the finite
#     and thereby of determinateness in general,
#     as an empty beyond;
#     its sublating of itself into the finite is
#     a return from an empty flight,
#     the negation of the beyond
#     which is inherently a negative.

# %% [markdown]
# 1. **Negation Negating Itself**: The transcreation emphasizes the process where negation itself is negated.
#
# 2. **Infinity as Negation of Finite**: It highlights that infinity is defined as the negation of both the finite and determinateness.
#
# 3. **Empty Beyond Concept**: The translation points out the portrayal of infinity as an 'empty beyond,' contrasting with the finite.
#
# 4. **Return from Empty Flight**: The text illustrates the concept of infinity's return from an abstract negation as a key aspect of its nature.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "Represents the process of sublation (Aufhebung) in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :EmptyBeyond a owl:Class ;
#     rdfs:label "Empty Beyond" ;
#     rdfs:comment "Represents the concept of the infinite as an empty beyond." .
#
# # Properties
# :sublatesItselfInNegation a owl:ObjectProperty ;
#     rdfs:label "sublates itself in negation" ;
#     rdfs:comment "Indicates that negation sublates itself in the process of infinity." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Sublation .
#
# :isDeterminedAsEmptyBeyond a owl:ObjectProperty ;
#     rdfs:label "is determined as empty beyond" ;
#     rdfs:comment "Indicates that the infinite is determined as an empty beyond." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :EmptyBeyond .
#
# :returnsFromEmptyBeyond a owl:ObjectProperty ;
#     rdfs:label "returns from empty beyond" ;
#     rdfs:comment "Indicates that the infinite returns from an empty beyond by sublating itself into the finite." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Finite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isDeterminedAsEmptyBeyond :emptyBeyond1 ;
#     :returnsFromEmptyBeyond :finite1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :sublation1 a :Sublation ;
#     rdfs:label "Sublation" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" ;
#     :sublatesItselfInNegation :sublation1 .
#
# :emptyBeyond1 a :EmptyBeyond ;
#     rdfs:label "Empty Beyond" .

# %% [markdown]
#     Present in both, therefore, is the same negation of negation.
#     But this negation of negation is in itself self-reference,
#     affirmation but as turning back to itself, that is
#     through the mediation that the negation of negation is.

# %% [markdown]
# 1. **Common Negation of Negation**: The transcreation highlights that both the finite and infinite undergo the process of negation of negation.
#
# 2. **Self-Reference and Affirmation**: It emphasizes that this negation of negation leads to self-reference and, subsequently, to affirmation.
#
# 3. **Mediated Transformation**: The translation illustrates that this affirmation is achieved through a mediated process, not a straightforward reversal.
#
# 4. **Dialectical Process of Self-Realization**: The text points out the dialectical nature of this process, indicating a deeper level of self-realization and identity.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "Represents the process of sublation (Aufhebung) in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :NegationOfNegation a owl:Class ;
#     rdfs:label "Negation of Negation" ;
#     rdfs:comment "Represents the concept of negation of negation in Hegelian philosophy." .
#
# :SelfReference a owl:Class ;
#     rdfs:label "Self-Reference" ;
#     rdfs:comment "Represents the concept of self-reference in Hegelian philosophy." .
#
# :Mediation a owl:Class ;
#     rdfs:label "Mediation" ;
#     rdfs:comment "Represents the concept of mediation in Hegelian philosophy." .
#
# # Properties
# :containsNegationOfNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation of negation" ;
#     rdfs:comment "Indicates that an entity contains the negation of negation." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :NegationOfNegation .
#
# :isSelfReferentialThrough a owl:ObjectProperty ;
#     rdfs:label "is self-referential through" ;
#     rdfs:comment "Indicates that the negation of negation is self-referential through mediation." ;
#     rdfs:domain :NegationOfNegation ;
#     rdfs:range :SelfReference .
#
# :isMediatedBy a owl:ObjectProperty ;
#     rdfs:label "is mediated by" ;
#     rdfs:comment "Indicates that the self-reference is mediated by negation of negation." ;
#     rdfs:domain :SelfReference ;
#     rdfs:range :Mediation .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :containsNegationOfNegation :negationOfNegation1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :containsNegationOfNegation :negationOfNegation1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :sublation1 a :Sublation ;
#     rdfs:label "Sublation" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :negationOfNegation1 a :NegationOfNegation ;
#     rdfs:label "Negation of Negation" ;
#     :isSelfReferentialThrough :selfReference1 .
#
# :selfReference1 a :SelfReference ;
#     rdfs:label "Self-Reference" ;
#     :isMediatedBy :mediation1 .
#
# :mediation1 a :Mediation ;
#     rdfs:label "Mediation" .

# %% [markdown]
#     These are the determinations that it is essential to bring to view;
#     the second point, however, is that in the infinite progression
#     they are also posited, and how they are posited therein,
#     namely, not in their ultimate truth.

# %% [markdown]
# 1. **Essential Determinations**: The transcreation emphasizes the need to recognize key determinations to understand infinite progression.
#
# 2. **Representation in Infinite Progression**: It highlights that these determinations are included in the concept of infinite progression but not in their fullest truth.
#
# 3. **Distorted or Incomplete Positing**: The translation points out that the representation of these determinations in infinite progression is somewhat distorted or incomplete.
#
# 4. **Limitation in Conceptual Framework**: The text suggests a limitation in the infinite progression's ability to fully capture the true essence of these determinations.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :EssentialDetermination a owl:Class ;
#     rdfs:label "Essential Determination" ;
#     rdfs:comment "Represents the essential determinations in Hegelian philosophy." .
#
# :InfiniteProgression a owl:Class ;
#     rdfs:label "Infinite Progression" ;
#     rdfs:comment "Represents the infinite progression in Hegelian philosophy." .
#
# :IntermediateStage a owl:Class ;
#     rdfs:label "Intermediate Stage" ;
#     rdfs:comment "Represents the intermediate stage in the dialectical process." .
#
# # Properties
# :containsEssentialDetermination a owl:ObjectProperty ;
#     rdfs:label "contains essential determination" ;
#     rdfs:comment "Indicates that an entity contains essential determinations." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :EssentialDetermination .
#
# :isPositedIn a owl:ObjectProperty ;
#     rdfs:label "is posited in" ;
#     rdfs:comment "Indicates that essential determinations are posited in the infinite progression." ;
#     rdfs:domain :EssentialDetermination ;
#     rdfs:range :InfiniteProgression .
#
# :isNotUltimateTruth a owl:ObjectProperty ;
#     rdfs:label "is not ultimate truth" ;
#     rdfs:comment "Indicates that the determinations are not the ultimate truth." ;
#     rdfs:domain :EssentialDetermination ;
#     rdfs:range :IntermediateStage .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :essentialDetermination1 a :EssentialDetermination ;
#     rdfs:label "Essential Determination" ;
#     :isPositedIn :infiniteProgression1 ;
#     :isNotUltimateTruth :intermediateStage1 .
#
# :infiniteProgression1 a :InfiniteProgression ;
#     rdfs:label "Infinite Progression" ;
#     :containsEssentialDetermination :essentialDetermination1 .
#
# :intermediateStage1 a :IntermediateStage ;
#     rdfs:label "Intermediate Stage" .

# %% [markdown]
#     First, both are negated in that progression,
#     the infinite as well as the finite;
#     both are equally transcended.
#     Second, they are also posited as distinct,
#     one after the other, each positive for itself.

# %% [markdown]
# 1. **Negation of Finite and Infinite**: The transcreation highlights the initial negation or transcendence of both the finite and the infinite in the infinite progression.
#
# 2. **Positing as Distinct Entities**: It emphasizes that, following this negation, they are also posited as distinct and positively defined entities.
#
# 3. **Simultaneous Transcendence and Affirmation**: The translation illustrates the dual aspect of transcending and simultaneously affirming the finite and infinite.
#
# 4. **Sequential Representation**: The text notes the sequential and linear representation of the finite and infinite in the progression.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# :DistinctPositing a owl:Class ;
#     rdfs:label "Distinct Positing" ;
#     rdfs:comment "Represents the concept of positing entities as distinct." .
#
# # Properties
# :isNegatedInProgression a owl:ObjectProperty ;
#     rdfs:label "is negated in progression" ;
#     rdfs:comment "Indicates that an entity is negated in the infinite progression." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :isTranscendedInProgression a owl:ObjectProperty ;
#     rdfs:label "is transcended in progression" ;
#     rdfs:comment "Indicates that an entity is transcended in the infinite progression." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Transcendence .
#
# :isPositedAsDistinct a owl:ObjectProperty ;
#     rdfs:label "is posited as distinct" ;
#     rdfs:comment "Indicates that an entity is posited as distinct." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :DistinctPositing .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isNegatedInProgression :negation1 ;
#     :isTranscendedInProgression :transcendence1 ;
#     :isPositedAsDistinct :distinctPositing1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isNegatedInProgression :negation1 ;
#     :isTranscendedInProgression :transcendence1 ;
#     :isPositedAsDistinct :distinctPositing1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .
#
# :distinctPositing1 a :DistinctPositing ;
#     rdfs:label "Distinct Positing" .

# %% [markdown]
#     We sort out these two determinations while comparing them,
#     just as in the comparison (in an external comparing)
#     we have separated the two ways of considering them:
#     the finite and the infinite as referring to one another,
#     and each taken for itself.

# %% [markdown]
# 1. **Comparative Analysis of Determinations**: The transcreation emphasizes Hegel's approach of sorting out and comparing the finite and infinite's determinations.
#
# 2. **Relational vs. Individual Consideration**: It highlights the two ways of considering them: in mutual reference and individually.
#
# 3. **Methodical Approach for Understanding**: The translation illustrates the methodical approach of separating and then exploring these concepts in different contexts.
#
# 4. **External Comparing**: The text points out that this analysis is done through 'external comparing,' a process that aids in understanding the distinct nature of each concept.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Comparison a owl:Class ;
#     rdfs:label "Comparison" ;
#     rdfs:comment "Represents the process of comparing finite and infinite." .
#
# :ExternalComparison a owl:Class ;
#     rdfs:label "External Comparison" ;
#     rdfs:comment "Represents the external comparison of finite and infinite." .
#
# :ReferringToOneAnother a owl:Class ;
#     rdfs:label "Referring to One Another" ;
#     rdfs:comment "Represents the concept of finite and infinite referring to one another." .
#
# :TakenForItself a owl:Class ;
#     rdfs:label "Taken for Itself" ;
#     rdfs:comment "Represents the concept of considering finite and infinite independently." .
#
# # Properties
# :sortsOutDeterminations a owl:ObjectProperty ;
#     rdfs:label "sorts out determinations" ;
#     rdfs:comment "Indicates that an entity sorts out determinations in the comparison." ;
#     rdfs:domain :Comparison ;
#     rdfs:range :Finite, :Infinite .
#
# :comparesExternally a owl:ObjectProperty ;
#     rdfs:label "compares externally" ;
#     rdfs:comment "Indicates that an entity compares finite and infinite externally." ;
#     rdfs:domain :Comparison ;
#     rdfs:range :ExternalComparison .
#
# :considersAsReferringToOneAnother a owl:ObjectProperty ;
#     rdfs:label "considers as referring to one another" ;
#     rdfs:comment "Indicates that an entity considers finite and infinite as referring to one another." ;
#     rdfs:domain :Comparison ;
#     rdfs:range :ReferringToOneAnother .
#
# :considersAsTakenForItself a owl:ObjectProperty ;
#     rdfs:label "considers as taken for itself" ;
#     rdfs:comment "Indicates that an entity considers finite and infinite independently." ;
#     rdfs:domain :Comparison ;
#     rdfs:range :TakenForItself .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :comparison1 a :Comparison ;
#     rdfs:label "Comparison" ;
#     :sortsOutDeterminations :finite1, :infinite1 ;
#     :comparesExternally :externalComparison1 ;
#     :considersAsReferringToOneAnother :referringToOneAnother1 ;
#     :considersAsTakenForItself :takenForItself1 .
#
# :externalComparison1 a :ExternalComparison ;
#     rdfs:label "External Comparison" .
#
# :referringToOneAnother1 a :ReferringToOneAnother ;
#     rdfs:label "Referring to One Another" .
#
# :takenForItself1 a :TakenForItself ;
#     rdfs:label "Taken for Itself" .

# %% [markdown]
#     The infinite progression, however, says more than this.
#     Also posited in it, though at first still only as
#     transition and alternation,
#     is the connectedness of the terms being distinguished.
#     We now only need to see, in one simple reflection,
#     what is in fact present in it.

# %% [markdown]
# 1. **More Than Separation**: The transcreation emphasizes that infinite progression involves more than the separate consideration of the finite and infinite.
#
# 2. **Connectedness of Terms**: It highlights that infinite progression also posits the interconnectedness of the finite and infinite, initially as transition and alternation.
#
# 3. **Insightful Reflection**: The translation suggests that a deeper understanding of infinite progression comes from recognizing this interconnectedness.
#
# 4. **Dynamic Interplay**: The text illustrates the dynamic interplay and influence between the finite and infinite within the progression.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :InfiniteProgression a owl:Class ;
#     rdfs:label "Infinite Progression" ;
#     rdfs:comment "Represents the infinite progression in Hegelian philosophy." .
#
# :Transition a owl:Class ;
#     rdfs:label "Transition" ;
#     rdfs:comment "Represents the concept of transition in Hegelian philosophy." .
#
# :Alternation a owl:Class ;
#     rdfs:label "Alternation" ;
#     rdfs:comment "Represents the concept of alternation in Hegelian philosophy." .
#
# :Connectedness a owl:Class ;
#     rdfs:label "Connectedness" ;
#     rdfs:comment "Represents the intrinsic connectedness of finite and infinite." .
#
# # Properties
# :includesTransition a owl:ObjectProperty ;
#     rdfs:label "includes transition" ;
#     rdfs:comment "Indicates that the infinite progression includes transition." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :Transition .
#
# :includesAlternation a owl:ObjectProperty ;
#     rdfs:label "includes alternation" ;
#     rdfs:comment "Indicates that the infinite progression includes alternation." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :Alternation .
#
# :includesConnectedness a owl:ObjectProperty ;
#     rdfs:label "includes connectedness" ;
#     rdfs:comment "Indicates that the infinite progression includes the connectedness of finite and infinite." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :Connectedness .
#
# :reflectsOnConnectedness a owl:ObjectProperty ;
#     rdfs:label "reflects on connectedness" ;
#     rdfs:comment "Indicates that reflection is needed to understand the connectedness present in the infinite progression." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :Connectedness .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :infiniteProgression1 a :InfiniteProgression ;
#     rdfs:label "Infinite Progression" ;
#     :includesTransition :transition1 ;
#     :includesAlternation :alternation1 ;
#     :includesConnectedness :connectedness1 ;
#     :reflectsOnConnectedness :connectedness1 .
#
# :transition1 a :Transition ;
#     rdfs:label "Transition" .
#
# :alternation1 a :Alternation ;
#     rdfs:label "Alternation" .
#
# :connectedness1 a :Connectedness ;
#     rdfs:label "Connectedness" .

# %% [markdown]
#     In the first place,
#     the negation of the finite and the infinite
#     which is posited in the infinite progression
#     can be taken as simple,
#     and hence as mutual externality,
#     only a following of one upon the other.

# %% [markdown]
# 1. **Negation as Simple Process**: The transcreation emphasizes that the negation of the finite and infinite is initially seen as a simple process.
#
# 2. **Mutual Externality**: It highlights the view of the finite and infinite as externally following one another without deeper interconnection.
#
# 3. **Linear Succession**: The translation points out the perception of the finite and infinite as existing in a linear sequence, one after the other.
#
# 4. **Surface-Level Interpretation**: The text suggests that this view represents a surface-level understanding of the relationship between the finite and infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :InfiniteProgression a owl:Class ;
#     rdfs:label "Infinite Progression" ;
#     rdfs:comment "Represents the infinite progression in Hegelian philosophy." .
#
# :MutualExternality a owl:Class ;
#     rdfs:label "Mutual Externality" ;
#     rdfs:comment "Represents the concept of mutual externality in the infinite progression." .
#
# :SequentialRelation a owl:Class ;
#     rdfs:label "Sequential Relation" ;
#     rdfs:comment "Represents the sequential relation of finite and infinite." .
#
# # Properties
# :isNegatedIn a owl:ObjectProperty ;
#     rdfs:label "is negated in" ;
#     rdfs:comment "Indicates that an entity is negated in the infinite progression." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :hasSimpleNegation a owl:ObjectProperty ;
#     rdfs:label "has simple negation" ;
#     rdfs:comment "Indicates that the negation in the infinite progression is simple." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :Negation .
#
# :hasMutualExternality a owl:ObjectProperty ;
#     rdfs:label "has mutual externality" ;
#     rdfs:comment "Indicates that the infinite progression includes mutual externality." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :MutualExternality .
#
# :hasSequentialRelation a owl:ObjectProperty ;
#     rdfs:label "has sequential relation" ;
#     rdfs:comment "Indicates that the infinite progression includes a sequential relation of finite and infinite." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :SequentialRelation .
#
# :follows a owl:ObjectProperty ;
#     rdfs:label "follows" ;
#     rdfs:comment "Indicates that one entity follows another in sequence." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Finite, :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isNegatedIn :negation1 ;
#     :follows :infinite1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isNegatedIn :negation1 ;
#     :follows :finite1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :infiniteProgression1 a :InfiniteProgression ;
#     rdfs:label "Infinite Progression" ;
#     :hasSimpleNegation :negation1 ;
#     :hasMutualExternality :mutualExternality1 ;
#     :hasSequentialRelation :sequentialRelation1 .
#
# :mutualExternality1 a :MutualExternality ;
#     rdfs:label "Mutual Externality" .
#
# :sequentialRelation1 a :SequentialRelation ;
#     rdfs:label "Sequential Relation" .

# %% [markdown]
#     Starting from the finite,
#     the limit is thus transcended, the finite negated.
#     We now have its beyond, the infinite,
#     but in this the limit rises up again;
#     so we have the transcending of the infinite.

# %% [markdown]
# 1. **Transcendence from Finite to Infinite**: The transcreation emphasizes the initial transcendence from the finite, negating its limit.
#
# 2. **Re-emergence of Limit in Infinite**: It highlights the paradoxical return of the limit within the infinite, challenging its boundlessness.
#
# 3. **Need for Transcending the Infinite**: The translation points out the subsequent need to transcend the infinite due to the re-emergence of the limit.
#
# 4. **Dialectical Movement**: The text illustrates the dialectical nature of this process, moving from finite to infinite and beyond.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of a limit in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# # Properties
# :transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that an entity transcends its limits." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Limit .
#
# :isNegated a owl:ObjectProperty ;
#     rdfs:label "is negated" ;
#     rdfs:comment "Indicates that an entity is negated." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :re-emergesIn a owl:ObjectProperty ;
#     rdfs:label "re-emerges in" ;
#     rdfs:comment "Indicates that a limit re-emerges in the infinite." ;
#     rdfs:domain :Limit ;
#     rdfs:range :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :transcends :limit1 ;
#     :isNegated :negation1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :transcends :limit1 ;
#     :isNegated :negation1 ;
#     :re-emergesIn :limit1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .

# %% [markdown]
#     This twofold sublation is nonetheless
#     partly only an external event
#     and an alternating of moments in general,
#     and partly still not posited as one unity;
#     each of these moves beyond is an independent starting point,
#     a fresh act, so that the two fall apart.

# %% [markdown]
# 1. **Sublation as External Event**: The transcreation emphasizes Hegel's critique of the twofold sublation being seen as an external alternation of moments.
#
# 2. **Lack of Perceived Unity**: It highlights the absence of a unified view of the process, with each transition treated as a separate act.
#
# 3. **Independent Starting Points**: The translation points out that each move from finite to infinite is seen as an independent, fresh act, leading to a conceptual disconnection.
#
# 4. **Fragmentation of Process**: The text illustrates the fragmentation in the conceptualization of this process, failing to see it as a cohesive whole.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of a limit in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# :ExternalEvent a owl:Class ;
#     rdfs:label "External Event" ;
#     rdfs:comment "Represents the concept of an external event in the sublation process." .
#
# :AlternatingMoments a owl:Class ;
#     rdfs:label "Alternating Moments" ;
#     rdfs:comment "Represents the alternating moments in the sublation process." .
#
# :IndependentStartingPoint a owl:Class ;
#     rdfs:label "Independent Starting Point" ;
#     rdfs:comment "Represents the concept of an independent starting point in the sublation process." .
#
# :Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the concept of unity in the sublation process." .
#
# # Properties
# :hasExternalEvent a owl:ObjectProperty ;
#     rdfs:label "has external event" ;
#     rdfs:comment "Indicates that the sublation process includes an external event." ;
#     rdfs:domain :Transcendence ;
#     rdfs:range :ExternalEvent .
#
# :hasAlternatingMoments a owl:ObjectProperty ;
#     rdfs:label "has alternating moments" ;
#     rdfs:comment "Indicates that the sublation process includes alternating moments." ;
#     rdfs:domain :Transcendence ;
#     rdfs:range :AlternatingMoments .
#
# :isNotPositedAsUnity a owl:ObjectProperty ;
#     rdfs:label "is not posited as unity" ;
#     rdfs:comment "Indicates that the sublation process is not posited as a single unity." ;
#     rdfs:domain :Transc

# %% [markdown]
#     But, in addition, their connection is
#     also present in the infinite progression.
#     The finite comes first;
#     then there is the transcending of it,
#     and this negative, or this beyond of the finite,
#     is the infinite;
#     third, this negation is transcended in turn,
#     a new limit comes up, a finite again.

# %% [markdown]
# 1. **Sequence of Transcendence**: The transcreation highlights the sequence in infinite progression, starting with the finite, moving to the infinite, and returning to the finite.
#
# 2. **Negation and Beyond**: It emphasizes the process of transcending the finite to reach the infinite, which is seen as a negation or a 'beyond.'
#
# 3. **Cycle of Finite and Infinite**: The translation illustrates the cyclical nature of this process, where the negation of the infinite leads to a new finite.
#
# 4. **Interconnectedness in Progression**: The text underscores the interconnectedness of the finite and infinite within this conceptual framework.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of a limit in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# :ExternalEvent a owl:Class ;
#     rdfs:label "External Event" ;
#     rdfs:comment "Represents the concept of an external event in the sublation process." .
#
# :AlternatingMoments a owl:Class ;
#     rdfs:label "Alternating Moments" ;
#     rdfs:comment "Represents the alternating moments in the sublation process." .
#
# :IndependentStartingPoint a owl:Class ;
#     rdfs:label "Independent Starting Point" ;
#     rdfs:comment "Represents the concept of an independent starting point in the sublation process." .
#
# :Unity a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the concept of unity in the sublation process." .
#
# # Properties
# :hasExternalEvent a owl:ObjectProperty ;
#     rdfs:label "has external event" ;
#     rdfs:comment "Indicates that the sublation process includes an external event." ;
#     rdfs:domain :Transcendence ;
#     rdfs:range :ExternalEvent .
#
# :hasAlternatingMoments a owl:ObjectProperty ;
#     rdfs:label "has alternating moments" ;
#     rdfs:comment "Indicates that the sublation process includes alternating moments." ;
#     rdfs:domain :Transcendence ;
#     rdfs:range :AlternatingMoments .
#
# :isNotPositedAsUnity a owl:ObjectProperty ;
#     rdfs:label "is not posited as unity" ;
#     rdfs:comment "Indicates that the sublation process is not posited as a single unity." ;
#     rdfs:domain :Transcendence ;
#     rdfs:range :Unity .
#
# :hasIndependentStartingPoint a owl:ObjectProperty ;
#     rdfs:label "has independent starting point" ;
#     rdfs:comment "Indicates that each move in the sublation process is an independent starting point." ;
#     rdfs:domain :Transcendence ;
#     rdfs:range :IndependentStartingPoint .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" ;
#     :hasExternalEvent :externalEvent1 ;
#     :hasAlternatingMoments :alternatingMoments1 ;
#     :isNotPositedAsUnity :unity1 ;
#     :hasIndependentStartingPoint :independentStartingPoint1 .
#
# :externalEvent1 a :ExternalEvent ;
#     rdfs:label "External Event" .
#
# :alternatingMoments1 a :AlternatingMoments ;
#     rdfs:label "Alternating Moments" .
#
# :unity1 a :Unity ;
#     rdfs:label "Unity" .
#
# :independentStartingPoint1 a :IndependentStartingPoint ;
#     rdfs:label "Independent Starting Point" .

# %% [markdown]
#     This is the complete, self-closing movement
#     that has arrived at that which made the beginning;
#     what emerges is the same as that
#     from which the departure was made,
#     that is, the finite is restored;
#     the latter has therefore rejoined itself,
#     in its beyond has only found itself again.

# %% [markdown]
# 1. **Self-Closing Cyclical Movement**: The transcreation emphasizes the cyclical nature of the movement from the finite to the infinite and back to the finite.
#
# 2. **Return to the Origin**: It highlights that the process culminates in the return to the point of origin, restoring the finite.
#
# 3. **Rejoining of the Finite**: The translation points out that the finite, after encountering the infinite, rejoins and rediscovers itself.
#
# 4. **Rediscovery in the Beyond**: The text illustrates the concept that the finite's journey into the infinite is ultimately a rediscovery of its own essence.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Cycle a owl:Class ;
#     rdfs:label "Cycle" ;
#     rdfs:comment "Represents the cyclical process of negation and transcendence." .
#
# # Properties
# :transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that an entity transcends its limits." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Transcendence .
#
# :becomes a owl:ObjectProperty ;
#     rdfs:label "becomes" ;
#     rdfs:comment "Indicates that an entity becomes another entity through negation and transcendence." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that an entity negates its previous state." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :partOfCycle a owl:ObjectProperty ;
#     rdfs:label "part of cycle" ;
#     rdfs:comment "Indicates that an entity is part of a cyclical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Cycle .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :transcends :limit1 ;
#     :becomes :infinite1 ;
#     :negates :negation1 ;
#     :partOfCycle :cycle1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :transcends :limit1 ;
#     :becomes :finite1 ;
#     :negates :negation1 ;
#     :partOfCycle :cycle1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :cycle1 a :Cycle ;
#     rdfs:label "Cycle" .

# %% [markdown]
#     The same is the case regarding the infinite.
#     In the infinite, in the beyond of the limit,
#     only a new limit arises which has the same fate, namely,
#     that as finite it must be negated.

# %% [markdown]
# 1. **Encounter with New Limits**: The transcreation emphasizes that within the infinite, new limits continually arise.
#
# 2. **Fate of the New Limits**: It highlights that these new limits, although encountered in the infinite, are finite and must be negated.
#
# 3. **Infinite as Dynamic Process**: The translation points out that the infinite is characterized by the ongoing process of transcending finite limits.
#
# 4. **Paradoxical Aspect of Infinite**: The text illustrates the paradox that the infinite involves consistently transcending the finite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of a limit in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Cycle a owl:Class ;
#     rdfs:label "Cycle" ;
#     rdfs:comment "Represents the cyclical process of negation and transcendence." .
#
# # Properties
# :transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that an entity transcends its limits." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Transcendence .
#
# :becomes a owl:ObjectProperty ;
#     rdfs:label "becomes" ;
#     rdfs:comment "Indicates that an entity becomes another entity through negation and transcendence." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that an entity negates its previous state." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :re-emergesIn a owl:ObjectProperty ;
#     rdfs:label "re-emerges in" ;
#     rdfs:comment "Indicates that a new limit re-emerges in the infinite." ;
#     rdfs:domain :Limit ;
#     rdfs:range :Infinite .
#
# :partOfCycle a owl:ObjectProperty ;
#     rdfs:label "part of cycle" ;
#     rdfs:comment "Indicates that an entity is part of a cyclical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Cycle .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :transcends :limit1 ;
#     :becomes :infinite1 ;
#     :negates :negation1 ;
#     :partOfCycle :cycle1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :transcends :limit1 ;
#     :becomes :finite1 ;
#     :negates :negation1 ;
#     :partOfCycle :cycle1 ;
#     :re-emergesIn :limit1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :cycle1 a :Cycle ;
#     rdfs:label "Cycle" .

# %% [markdown]
#     Thus what is again at hand is the same infinite
#     that just now disappeared in the new limit;
#     by being sublated, by traversing the new limit,
#     the infinite has not therefore advanced one jot further:
#     it has distanced itself neither from the finite
#     (for the finite is just this,
#     to pass over into the infinite),
#     nor from itself, for it has arrived at itself.

# %% [markdown]
# 1. **Recurring Nature of the Infinite**: The transcreation emphasizes the repetitive emergence of the infinite as it transcends new limits.
#
# 2. **Lack of Advancement**: It highlights that this process does not represent a progression or distancing from its essence.
#
# 3. **Finite’s Transition to Infinite**: The translation points out that the finite inherently transitions into the infinite, reinforcing the infinite's return to itself.
#
# 4. **Perpetual Self-Arrival**: The text illustrates the concept of the infinite constantly rediscovering its infinitude in this cycle.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of a limit in Hegelian philosophy." .
#
# :Transcendence a owl:Class ;
#     rdfs:label "Transcendence" ;
#     rdfs:comment "Represents the concept of transcending limits in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Cycle a owl:Class ;
#     rdfs:label "Cycle" ;
#     rdfs:comment "Represents the cyclical process of negation and transcendence." .
#
# # Properties
# :transcends a owl:ObjectProperty ;
#     rdfs:label "transcends" ;
#     rdfs:comment "Indicates that an entity transcends its limits." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Transcendence .
#
# :becomes a owl:ObjectProperty ;
#     rdfs:label "becomes" ;
#     rdfs:comment "Indicates that an entity becomes another entity through negation and transcendence." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that an entity negates its previous state." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :re-emergesIn a owl:ObjectProperty ;
#     rdfs:label "re-emerges in" ;
#     rdfs:comment "Indicates that a new limit re-emerges in the infinite." ;
#     rdfs:domain :Limit ;
#     rdfs:range :Infinite .
#
# :partOfCycle a owl:ObjectProperty ;
#     rdfs:label "part of cycle" ;
#     rdfs:comment "Indicates that an entity is part of a cyclical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Cycle .
#
# :arrivesAtItself a owl:ObjectProperty ;
#     rdfs:label "arrives at itself" ;
#     rdfs:comment "Indicates that the infinite arrives back at itself." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :transcends :limit1 ;
#     :becomes :infinite1 ;
#     :negates :negation1 ;
#     :partOfCycle :cycle1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :transcends :limit1 ;
#     :becomes :finite1 ;
#     :negates :negation1 ;
#     :partOfCycle :cycle1 ;
#     :re-emergesIn :limit1 ;
#     :arrivesAtItself :infinite1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :transcendence1 a :Transcendence ;
#     rdfs:label "Transcendence" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :cycle1 a :Cycle ;
#     rdfs:label "Cycle" .

# %% [markdown]
#     Thus the finite and the infinite are both
#     this movement of each returning
#     to itself through its negation;
#     they are only as implicit mediation,
#     and the affirmative of each
#     contains the negative of each,
#     and is the negation of the negation.

# %% [markdown]
# 1. **Movement of Self-Return Through Negation**: The transcreation emphasizes the movement in which both the finite and the infinite return to themselves through negation.
#
# 2. **Implicit Mediation**: It highlights that this movement is an implicit mediation, not a direct or isolated process.
#
# 3. **Affirmative Contains the Negative**: The translation points out that the affirmative aspect of each contains its own negation, leading to the negation of the negation.
#
# 4. **Dynamic and Interconnected Nature**: The text illustrates the dynamic and interconnected nature of the finite and the infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :NegationOfNegation a owl:Class ;
#     rdfs:label "Negation of Negation" ;
#     rdfs:comment "Represents the concept of negation of the negation in Hegelian philosophy." .
#
# :Mediation a owl:Class ;
#     rdfs:label "Mediation" ;
#     rdfs:comment "Represents the concept of implicit mediation in Hegelian philosophy." .
#
# # Properties
# :returnsToSelfThroughNegation a owl:ObjectProperty ;
#     rdfs:label "returns to self through negation" ;
#     rdfs:comment "Indicates that an entity returns to itself through its negation." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :containsNegativeOfEach a owl:ObjectProperty ;
#     rdfs:label "contains negative of each" ;
#     rdfs:comment "Indicates that the affirmative of each contains the negative of each." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Negation .
#
# :isNegationOfNegation a owl:ObjectProperty ;
#     rdfs:label "is negation of negation" ;
#     rdfs:comment "Indicates that an entity is the negation of the negation." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :NegationOfNegation .
#
# :existsAsImplicitMediation a owl:ObjectProperty ;
#     rdfs:label "exists as implicit mediation" ;
#     rdfs:comment "Indicates that an entity exists as implicit mediation." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Mediation .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :returnsToSelfThroughNegation :negation1 ;
#     :containsNegativeOfEach :negation1 ;
#     :isNegationOfNegation :negationOfNegation1 ;
#     :existsAsImplicitMediation :mediation1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :returnsToSelfThroughNegation :negation1 ;
#     :containsNegativeOfEach :negation1 ;
#     :isNegationOfNegation :negationOfNegation1 ;
#     :existsAsImplicitMediation :mediation1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :negationOfNegation1 a :NegationOfNegation ;
#     rdfs:label "Negation of Negation" .
#
# :mediation1 a :Mediation ;
#     rdfs:label "Mediation" .

# %% [markdown]
#     They are thus a result
#     and, as such, not in the determination
#     that they had at the beginning:
#     neither is the finite an existence on its side
#     nor the infinite an existence
#     or a being-in-itself beyond that existence,
#     that is, beyond existence in
#     the determination of finitude.

# %% [markdown]
# 1. **Transcendence of Initial Determinations**: The transcreation emphasizes that the finite and infinite transcend their initial, separate existences.
#
# 2. **Finite and Infinite as Evolved Results**: It highlights that both concepts evolve beyond their original definitions as a result of their dialectical process.
#
# 3. **Departure from Original Conceptualization**: The translation points out the departure from the original conceptualization of the finite and infinite as distinct entities.
#
# 4. **Dynamic Process of Transformation**: The text illustrates the dynamic transformation that redefines the essence of both concepts.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Result a owl:Class ;
#     rdfs:label "Result" ;
#     rdfs:comment "Represents the outcome of the dialectical process." .
#
# :Transformation a owl:Class ;
#     rdfs:label "Transformation" ;
#     rdfs:comment "Represents the concept of transformation through the dialectical process." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence in Hegelian philosophy." .
#
# # Properties
# :undergoesTransformation a owl:ObjectProperty ;
#     rdfs:label "undergoes transformation" ;
#     rdfs:comment "Indicates that an entity undergoes transformation through the dialectical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Transformation .
#
# :isResultOf a owl:ObjectProperty ;
#     rdfs:label "is result of" ;
#     rdfs:comment "Indicates that an entity is the result of the dialectical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Result .
#
# :isInterrelatedWith a owl:ObjectProperty ;
#     rdfs:label "is interrelated with" ;
#     rdfs:comment "Indicates that the finite and the infinite are interrelated through their dialectical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Finite, :Infinite .
#
# :noLongerInitialDetermination a owl:ObjectProperty ;
#     rdfs:label "no longer initial determination" ;
#     rdfs:comment "Indicates that an entity no longer holds its initial determination after the dialectical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Transformation .
#
# :existsAsInterrelated a owl:ObjectProperty ;
#     rdfs:label "exists as interrelated" ;
#     rdfs:comment "Indicates that the finite and the infinite exist in an interrelated manner." ;
#     rdfs:domain :Existence ;
#     rdfs:range :Finite, :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :undergoesTransformation :transformation1 ;
#     :isResultOf :result1 ;
#     :isInterrelatedWith :infinite1 ;
#     :noLongerInitialDetermination :transformation1 ;
#     :existsAsInterrelated :existence1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :undergoesTransformation :transformation1 ;
#     :isResultOf :result1 ;
#     :isInterrelatedWith :finite1 ;
#     :noLongerInitialDetermination :transformation1 ;
#     :existsAsInterrelated :existence1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :result1 a :Result ;
#     rdfs:label "Result" .
#
# :transformation1 a :Transformation ;
#     rdfs:label "Transformation" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" .

# %% [markdown]
#     The understanding strongly resists
#     the unity of the finite and the infinite
#     only because it presupposes restriction
#     and finitude to remain,
#     like being-in-itself, constants.

# %% [markdown]
# 1. **Understanding's Resistance to Unity**: The transcreation emphasizes the understanding’s resistance to accepting the unity of the finite and the infinite.
#
# 2. **Presupposition of Constants**: It highlights that this resistance is due to the presupposition of restriction and finitude as constants, like being-in-itself.
#
# 3. **Rigid Categorization**: The translation points out the understanding’s rigid categorization of the finite and infinite as fundamentally separate and unchanging.
#
# 4. **Limitation in Cognitive Processing**: The text suggests that this rigid perspective limits the understanding’s ability to perceive the dynamic nature of reality.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Restriction a owl:Class ;
#     rdfs:label "Restriction" ;
#     rdfs:comment "Represents the concept of restriction in Hegelian philosophy." .
#
# :Finitude a owl:Class ;
#     rdfs:label "Finitude" ;
#     rdfs:comment "Represents the concept of finitude in Hegelian philosophy." .
#
# :BeingInItself a owl:Class ;
#     rdfs:label "Being-in-itself" ;
#     rdfs:comment "Represents the concept of being-in-itself in Hegelian philosophy." .
#
# :Understanding a owl:Class ;
#     rdfs:label "Understanding" ;
#     rdfs:comment "Represents the faculty of understanding in Hegelian philosophy." .
#
# # Properties
# :resistsUnityOf a owl:ObjectProperty ;
#     rdfs:label "resists unity of" ;
#     rdfs:comment "Indicates that the understanding resists the unity of the finite and the infinite." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :Finite, :Infinite .
#
# :presupposes a owl:ObjectProperty ;
#     rdfs:label "presupposes" ;
#     rdfs:comment "Indicates that the understanding presupposes certain concepts as constants." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :Restriction, :Finitude .
#
# :viewsAsConstant a owl:ObjectProperty ;
#     rdfs:label "views as constant" ;
#     rdfs:comment "Indicates that the understanding views certain concepts as constants." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :Restriction, :Finitude, :BeingInItself .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :restriction1 a :Restriction ;
#     rdfs:label "Restriction" .
#
# :finitude1 a :Finitude ;
#     rdfs:label "Finitude" .
#
# :beingInItself1 a :BeingInItself ;
#     rdfs:label "Being-in-itself" .
#
# :understanding1 a :Understanding ;
#     rdfs:label "Understanding" ;
#     :resistsUnityOf :finite1, :infinite1 ;
#     :presupposes :restriction1, :finitude1 ;
#     :viewsAsConstant :restriction1, :finitude1, :beingInItself1 .

# %% [markdown]
#     It thereby overlooks the negation of both
#     which is in fact present in the infinite progression,
#     just as it equally overlooks that the two occur in this
#     progression only as moments of a whole,
#     that each emerges only through the mediation of its opposite
#     but, essentially, equally by means of the sublation of its opposite.

# %% [markdown]
# 1. **Oversight of Negation**: The transcreation emphasizes the understanding's failure to recognize the negation of both the finite and the infinite in the infinite progression.
#
# 2. **Interconnectedness as Moments of a Whole**: It highlights the idea that the finite and infinite occur as interconnected moments within a larger whole.
#
# 3. **Mediation and Sublation**: The translation points out that each arises through the mediation and sublation of its opposite, not independently.
#
# 4. **Limitation of the Understanding**: The text suggests that the understanding overlooks the complex, dialectical nature of the finite and infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Mediation a owl:Class ;
#     rdfs:label "Mediation" ;
#     rdfs:comment "Represents the concept of mediation in Hegelian philosophy." .
#
# :Sublation a owl:Class ;
#     rdfs:label "Sublation" ;
#     rdfs:comment "Represents the concept of sublation (Aufhebung) in Hegelian philosophy." .
#
# :Whole a owl:Class ;
#     rdfs:label "Whole" ;
#     rdfs:comment "Represents the unified whole in Hegelian philosophy." .
#
# # Properties
# :overlooksNegationOf a owl:ObjectProperty ;
#     rdfs:label "overlooks negation of" ;
#     rdfs:comment "Indicates that the understanding overlooks the negation present in both the finite and the infinite." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :Negation .
#
# :occursAsMomentOf a owl:ObjectProperty ;
#     rdfs:label "occurs as moment of" ;
#     rdfs:comment "Indicates that the finite and the infinite occur as moments of a whole." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Whole .
#
# :emergesThroughMediationOf a owl:ObjectProperty ;
#     rdfs:label "emerges through mediation of" ;
#     rdfs:comment "Indicates that each entity emerges through the mediation of its opposite." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Mediation .
#
# :emergesThroughSublationOf a owl:ObjectProperty ;
#     rdfs:label "emerges through sublation of" ;
#     rdfs:comment "Indicates that each entity emerges through the sublation of its opposite." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Sublation .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :occursAsMomentOf :whole1 ;
#     :emergesThroughMediationOf :mediation1 ;
#     :emergesThroughSublationOf :sublation1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :occursAsMomentOf :whole1 ;
#     :emergesThroughMediationOf :mediation1 ;
#     :emergesThroughSublationOf :sublation1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :mediation1 a :Mediation ;
#     rdfs:label "Mediation" .
#
# :sublation1 a :Sublation ;
#     rdfs:label "Sublation" .
#
# :whole1 a :Whole ;
#     rdfs:label "Whole" .

# %% [markdown]
#     If this immanent turning back has for the moment been reckoned
#     to be just as much the turning back of the finite to itself
#     and of the infinite to itself,
#     noticeable in this very result is an error connected
#     with the one-sidedness just criticized:
#     the finite and then the infinite is
#     each taken as the starting point,
#     and only in this way two results ensue.

# %% [markdown]
# 1. **Error in Separate Starting Points**: The transcreation emphasizes the error of considering the finite and infinite separately as starting points for their turning back.
#
# 2. **One-Sidedness Critique**: It highlights Hegel's critique of the one-sided approach that leads to two distinct results.
#
# 3. **Lack of Interconnectedness**: The translation points out that this approach fails to capture the interconnectedness between the finite and infinite.
#
# 4. **Misunderstanding of Immanent Turning Back**: The text suggests that the finite and infinite's turning back is misunderstood as independent processes.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :Mediation a owl:Class ;
#     rdfs:label "Mediation" ;
#     rdfs:comment "Represents the concept of mediation in Hegelian philosophy." .
#
# :Result a owl:Class ;
#     rdfs:label "Result" ;
#     rdfs:comment "Represents the outcome of the dialectical process." .
#
# # Properties
# :returnsToSelf a owl:ObjectProperty ;
#     rdfs:label "returns to self" ;
#     rdfs:comment "Indicates that an entity returns to itself through its dialectical process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Finite, :Infinite .
#
# :isStartingPointFor a owl:ObjectProperty ;
#     rdfs:label "is starting point for" ;
#     rdfs:comment "Indicates that an entity is taken as the starting point for a process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Result .
#
# :leadsTo a owl:ObjectProperty ;
#     rdfs:label "leads to" ;
#     rdfs:comment "Indicates that an entity leads to a certain result." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Result .
#
# :overlooks a owl:ObjectProperty ;
#     rdfs:label "overlooks" ;
#     rdfs:comment "Indicates that an approach overlooks a key aspect." ;
#     rdfs:domain :Understanding ;
#     rdfs:range :Negation, :Mediation .
#
# :mutualMediation a owl:ObjectProperty ;
#     rdfs:label "mutual mediation" ;
#     rdfs:comment "Indicates the mutual mediation between entities." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Mediation .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :returnsToSelf :finite1 ;
#     :isStartingPointFor :result1 ;
#     :leadsTo :result1 ;
#     :mutualMediation :mediation1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :returnsToSelf :infinite1 ;
#     :isStartingPointFor :result2 ;
#     :leadsTo :result2 ;
#     :mutualMediation :mediation1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" .
#
# :mediation1 a :Mediation ;
#     rdfs:label "Mediation" .
#
# :result1 a :Result ;
#     rdfs:label "Result 1" .
#
# :result2 a :Result ;
#     rdfs:label "Result 2" .

# %% [markdown]
#     But it is a matter of total indifference
#     which is taken as the starting point
#     and, with this, the distinction caused
#     by the duality of results dissolves of itself.

# %% [markdown]
# 1. **Indifference of Starting Point**: The transcreation emphasizes Hegel's view that the choice of starting with the finite or the infinite is ultimately indifferent.
#
# 2. **Dissolution of Duality**: It highlights that the distinction created by different starting points dissolves in the broader understanding of their relationship.
#
# 3. **Transcendence Beyond Initial Choice**: The translation suggests that the deeper understanding of the finite and infinite transcends the initial dichotomy of starting points.
#
# 4. **Irrelevance in Deeper Exploration**: The text illustrates that in the more profound philosophical exploration, the choice of starting point becomes irrelevant.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :Indifference a owl:Class ;
#     rdfs:label "Indifference" ;
#     rdfs:comment "Represents the indifference of the starting point between finite and infinite." .
#
# :Duality a owl:Class ;
#     rdfs:label "Duality" ;
#     rdfs:comment "Represents the duality of results that dissolves in the understanding of their unity." .
#
# # Properties
# :isIndifferentTo a owl:ObjectProperty ;
#     rdfs:label "is indifferent to" ;
#     rdfs:comment "Indicates that an entity is indifferent to the choice of starting point." ;
#     rdfs:domain :Indifference ;
#     rdfs:range :Finite, :Infinite .
#
# :dissolves a owl:ObjectProperty ;
#     rdfs:label "dissolves" ;
#     rdfs:comment "Indicates that the duality dissolves in the understanding of unity." ;
#     rdfs:domain :Duality ;
#     rdfs:range :Unity .
#
# :unifies a owl:ObjectProperty ;
#     rdfs:label "unifies" ;
#     rdfs:comment "Indicates that an entity unifies two concepts." ;
#     rdfs:domain :Unity ;
#     rdfs:range :Finite, :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isIndifferentTo :indifference1 ;
#     :unifies :unity1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isIndifferentTo :indifference1 ;
#     :unifies :unity1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :indifference1 a :Indifference ;
#     rdfs:label "Indifference" .
#
# :duality1 a :Duality ;
#     rdfs:label "Duality" ;
#     :dissolves :unity1 .
#
# :unity1 a owl:Class ;
#     rdfs:label "Unity" ;
#     rdfs:comment "Represents the dialectical unity of finite and infinite." .

# %% [markdown]
#     This is likewise posited in the line
#     of the infinite progression,
#     open-ended on both sides,
#     wherein each of the moments
#     recurs in equal alternation,
#     and it is totally extraneous
#     at which position the progression is
#     arrested and taken as beginning.

# %% [markdown]
# 1. **Open-Ended Infinite Progression**: The transcreation emphasizes the concept of the infinite progression as an open-ended line where moments recur in alternation.
#
# 2. **Indifference to Starting Point**: It highlights the idea that the position at which the progression is commenced is irrelevant to its nature.
#
# 3. **Equal Alternation of Moments**: The translation points out the equal importance of each moment, finite or infinite, in the progression.
#
# 4. **Arbitrary Beginning**: The text suggests that the choice of where to begin analyzing the infinite progression is arbitrary.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :InfiniteProgression a owl:Class ;
#     rdfs:label "Infinite Progression" ;
#     rdfs:comment "Represents the infinite progression that is open-ended and cyclic." .
#
# :CyclicalNature a owl:Class ;
#     rdfs:label "Cyclical Nature" ;
#     rdfs:comment "Represents the cyclical and self-replicating process of the infinite progression." .
#
# # Properties
# :openEndedOnBothSides a owl:ObjectProperty ;
#     rdfs:label "open-ended on both sides" ;
#     rdfs:comment "Indicates that the infinite progression is open-ended on both sides." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :CyclicalNature .
#
# :recursInAlternation a owl:ObjectProperty ;
#     rdfs:label "recurs in alternation" ;
#     rdfs:comment "Indicates that each moment in the progression recurs in equal alternation." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :CyclicalNature .
#
# :isExtraneous a owl:ObjectProperty ;
#     rdfs:label "is extraneous" ;
#     rdfs:comment "Indicates that the starting point of the progression is extraneous." ;
#     rdfs:domain :InfiniteProgression ;
#     rdfs:range :StartingPoint .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :infiniteProgression1 a :InfiniteProgression ;
#     rdfs:label "Infinite Progression" ;
#     :openEndedOnBothSides :cyclicalNature1 ;
#     :recursInAlternation :cyclicalNature1 ;
#     :isExtraneous :startingPoint1 .
#
# :cyclicalNature1 a :CyclicalNature ;
#     rdfs:label "Cyclical Nature" .
#
# :startingPoint1 a owl:Class ;
#     rdfs:label "Starting Point" ;
#     rdfs:comment "Represents the concept of the starting point in the infinite progression." .

# %% [markdown]
#     The moments are distinguished in the progression
#     but each is equally only moment of the other.
#     Since both, the finite and the infinite,
#     are themselves moments of the progress,
#     they are jointly the finite,
#     and, since they are equally jointly
#     negated in it and in the result,
#     this result as the negation
#     of their joint finitude is
#     called with truth the infinite.

# %% [markdown]
# 1. **Interdependent Moments**: The transcreation highlights the interdependence of the finite and infinite, each being a moment of the other within the progression.
#
# 2. **Joint Constitution of the Finite**: It emphasizes that together, the finite and infinite form what is collectively understood as the finite.
#
# 3. **Negation and Transcendence**: The translation points out that the negation of their joint finitude within the progression leads to the emergence of the true infinite.
#
# 4. **Emergence of the Infinite**: The text illustrates that the infinite is a concept that transcends the finite, emerging from their mutual negation.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :JointFinitude a owl:Class ;
#     rdfs:label "Joint Finitude" ;
#     rdfs:comment "Represents the collective finitude of the finite and the infinite." .
#
# # Properties
# :isMomentOf a owl:ObjectProperty ;
#     rdfs:label "is moment of" ;
#     rdfs:comment "Indicates that an entity is a moment of another in the progression." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# :isCollectively a owl:ObjectProperty ;
#     rdfs:label "is collectively" ;
#     rdfs:comment "Indicates that entities are collectively forming a concept." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :JointFinitude .
#
# :isNegatedIn a owl:ObjectProperty ;
#     rdfs:label "is negated in" ;
#     rdfs:comment "Indicates that an entity is negated in a certain process." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :AffirmativeInfinity .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isMomentOf :infinite1 ;
#     :isCollectively :jointFinitude1 ;
#     :isNegatedIn :affirmativeInfinity1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isMomentOf :finite1 ;
#     :isCollectively :jointFinitude1 ;
#     :isNegatedIn :affirmativeInfinity1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :jointFinitude1 a :JointFinitude ;
#     rdfs:label "Joint Finitude" .

# %% [markdown]
#     Their distinction is thus the
#     double meaning which they both have.
#     The finite has the double meaning,
#     first, of being the finite over against the infinite
#     which stands over against it,
#     and, second, of being at the same time
#     the finite and the infinite over against the infinite.

# %% [markdown]
# 1. **Dual Meaning of the Finite**: The transcreation emphasizes the dual meaning of the finite in relation to the infinite.
#
# 2. **Finite as Opposite to Infinite**: It highlights the first aspect of the finite as being distinctly opposite and separate from the infinite.
#
# 3. **Finite as Both Finite and Infinite**: The translation points out the second, more complex aspect where the finite embodies both finitude and a dimension of the infinite.
#
# 4. **Blurring of Separation**: The text illustrates how this dual meaning challenges the strict separation between the finite and infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :DoubleMeaning a owl:Class ;
#     rdfs:label "Double Meaning" ;
#     rdfs:comment "Represents the double meaning of the finite in relation to the infinite." .
#
# # Properties
# :isDefinedBy a owl:ObjectProperty ;
#     rdfs:label "is defined by" ;
#     rdfs:comment "Indicates that an entity is defined by another entity." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# :embodies a owl:ObjectProperty ;
#     rdfs:label "embodies" ;
#     rdfs:comment "Indicates that an entity embodies both finitude and infinity." ;
#     rdfs:domain :Finite ;
#     rdfs:range :DoubleMeaning .
#
# :overAgainst a owl:ObjectProperty ;
#     rdfs:label "over against" ;
#     rdfs:comment "Indicates that an entity stands over against another entity." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isDefinedBy :infinite1 ;
#     :embodies :doubleMeaning1 ;
#     :overAgainst :infinite1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isDefinedBy :finite1 ;
#     :overAgainst :finite1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :doubleMeaning1 a :DoubleMeaning ;
#     rdfs:label "Double Meaning" .

# %% [markdown]
#     Also the infinite has the double meaning
#     of being one of the two moments
#     (it is then the bad infinite)
#     and of being the infinite in which the two moments,
#     itself and its other, are only moments.

# %% [markdown]
# 1. **Dual Meaning of the Infinite**: The transcreation emphasizes the dual meaning of the infinite in relation to the finite.
#
# 2. **Infinite as 'Bad Infinite'**: It highlights the first meaning where the infinite is seen as an opposing moment to the finite, termed the 'bad infinite.'
#
# 3. **Infinite as Inclusive Entity**: The translation points out the second, more profound meaning where the infinite includes both itself and the finite as integral moments.
#
# 4. **Beyond Simple Negation**: The text illustrates that this broader perspective of the infinite goes beyond being a mere negation of the finite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :DoubleMeaning a owl:Class ;
#     rdfs:label "Double Meaning" ;
#     rdfs:comment "Represents the double meaning of the finite and infinite in relation to each other." .
#
# :BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "Represents the limited understanding of infinity, which stands in opposition to the finite." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite that integrates both the finite and the infinite as moments." .
#
# # Properties
# :isMomentOf a owl:ObjectProperty ;
#     rdfs:label "is moment of" ;
#     rdfs:comment "Indicates that an entity is a moment of another in the progression." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Infinite, :Finite .
#
# :hasDoubleMeaning a owl:ObjectProperty ;
#     rdfs:label "has double meaning" ;
#     rdfs:comment "Indicates that an entity has a double meaning in its relation to another." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :DoubleMeaning .
#
# :standsOverAgainst a owl:ObjectProperty ;
#     rdfs:label "stands over against" ;
#     rdfs:comment "Indicates that an entity stands over against another entity." ;
#     rdfs:domain :BadInfinite ;
#     rdfs:range :Finite .
#
# :integrates a owl:ObjectProperty ;
#     rdfs:label "integrates" ;
#     rdfs:comment "Indicates that an entity integrates both itself and its other as moments." ;
#     rdfs:domain :TrueInfinite ;
#     rdfs:range :Finite, :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :isMomentOf :infinite1 ;
#     :hasDoubleMeaning :doubleMeaning1 ;
#     :standsOverAgainst :badInfinite1 ;
#     :integrates :trueInfinite1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :isMomentOf :finite1 ;
#     :hasDoubleMeaning :doubleMeaning1 ;
#     :standsOverAgainst :badInfinite1 ;
#     :integrates :trueInfinite1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :doubleMeaning1 a :DoubleMeaning ;
#     rdfs:label "Double Meaning" .
#
# :badInfinite1 a :BadInfinite ;
#     rdfs:label "Bad Infinite" .
#
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .

# %% [markdown]
#     Therefore, as in fact we now have it,
#     the nature of the infinite is
#     that it is the process in which it lowers itself
#     to be only one of its determinations over against the finite
#     and therefore itself only one of the finites,
#     and elevates this distinction of itself
#     and itself to be self-affirmation
#     and, through this mediation, the true infinite.

# %% [markdown]
# 1. **Infinite as Dynamic Process**: The transcreation emphasizes the nature of the infinite as a dynamic, self-transformative process.
#
# 2. **Lowering and Self-Transformation**: It highlights how the infinite initially lowers itself to a finite level, only to transform this limitation.
#
# 3. **Self-Affirmation of the Infinite**: The translation illustrates the infinite's movement from self-negation to self-affirmation.
#
# 4. **True Infinite Through Mediation**: The text points out that this process of confronting and transcending finitude realizes the true infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :SelfDifferentiation a owl:Class ;
#     rdfs:label "Self-Differentiation" ;
#     rdfs:comment "Represents the process by which the infinite lowers itself to become one of the finites." .
#
# :SelfAffirmation a owl:Class ;
#     rdfs:label "Self-Affirmation" ;
#     rdfs:comment "Represents the process by which the infinite reaffirms itself through mediation." .
#
# # Properties
# :lowersItselfTo a owl:ObjectProperty ;
#     rdfs:label "lowers itself to" ;
#     rdfs:comment "Indicates that the infinite lowers itself to become one of its determinations." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :SelfDifferentiation .
#
# :becomesOneOf a owl:ObjectProperty ;
#     rdfs:label "becomes one of" ;
#     rdfs:comment "Indicates that an entity becomes one of the finites." ;
#     rdfs:domain :SelfDifferentiation ;
#     rdfs:range :Finite .
#
# :reaffirmsItself a owl:ObjectProperty ;
#     rdfs:label "reaffirms itself" ;
#     rdfs:comment "Indicates that the infinite reaffirms itself through mediation." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :SelfAffirmation .
#
# :achieves a owl:ObjectProperty ;
#     rdfs:label "achieves" ;
#     rdfs:comment "Indicates that an entity achieves its true form through a process." ;
#     rdfs:domain :SelfAffirmation ;
#     rdfs:range :AffirmativeInfinity .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :lowersItselfTo :selfDifferentiation1 ;
#     :reaffirmsItself :selfAffirmation1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" .
#
# :selfDifferentiation1 a :SelfDifferentiation ;
#     rdfs:label "Self-Differentiation" ;
#     :becomesOneOf :finite1 .
#
# :selfAffirmation1 a :SelfAffirmation ;
#     rdfs:label "Self-Affirmation" ;
#     :achieves :affirmativeInfinity1 .

# %% [markdown]
#     This determination of the true infinite
#     cannot be captured in the already criticized formula
#     of a unity of the finite and the infinite;
#     unity is abstract, motionless self-sameness,
#     and the moments are likewise unmoved beings.
#     But, like both its moments, the infinite is
#     rather essentially only as becoming,
#     though a becoming now further determined in its moments.

# %% [markdown]
# 1. **Dynamic Nature of the True Infinite**: The transcreation emphasizes Hegel's view of the true infinite as a process of becoming, rather than a static unity.
#
# 2. **Critique of Abstract Unity**: It highlights Hegel's criticism of the concept of unity as too abstract and unmoving.
#
# 3. **Continuous Evolution and Movement**: The translation illustrates the infinite as continuously evolving and redefining itself through its relationship with the finite.
#
# 4. **Contrast with Static Conceptualization**: The text points out the contrast between Hegel’s dynamic understanding of the infinite and the static notion of unity.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :AffirmativeInfinity a owl:Class ;
#     rdfs:label "Affirmative Infinity" ;
#     rdfs:comment "Represents the true infinity that transcends and unites the finite." .
#
# :AbstractUnity a owl:Class ;
#     rdfs:label "Abstract Unity" ;
#     rdfs:comment "Represents the static, motionless concept of unity." .
#
# :DynamicBecoming a owl:Class ;
#     rdfs:label "Dynamic Becoming" ;
#     rdfs:comment "Represents the dynamic process of becoming in the true infinite." .
#
# # Properties
# :criticizes a owl:ObjectProperty ;
#     rdfs:label "criticizes" ;
#     rdfs:comment "Indicates that an entity criticizes another concept." ;
#     rdfs:domain :Infinite ;
#     rdfs:range :AbstractUnity .
#
# :characterizedBy a owl:ObjectProperty ;
#     rdfs:label "characterized by" ;
#     rdfs:comment "Indicates that an entity is characterized by a particular quality." ;
#     rdfs:domain :AffirmativeInfinity ;
#     rdfs:range :DynamicBecoming .
#
# :isFurtherDeterminedIn a owl:ObjectProperty ;
#     rdfs:label "is further determined in" ;
#     rdfs:comment "Indicates that an entity is further determined in another entity." ;
#     rdfs:domain :DynamicBecoming ;
#     rdfs:range :Finite, :Infinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :criticizes :abstractUnity1 .
#
# :affirmativeInfinity1 a :AffirmativeInfinity ;
#     rdfs:label "Affirmative Infinity" ;
#     :characterizedBy :dynamicBecoming1 .
#
# :abstractUnity1 a :AbstractUnity ;
#     rdfs:label "Abstract Unity" .
#
# :dynamicBecoming1 a :DynamicBecoming ;
#     rdfs:label "Dynamic Becoming" ;
#     :isFurtherDeterminedIn :finite1, :infinite1 .

# %% [markdown]
#     Becoming has for its determinations,
#     first, abstract being and nothing;
#     as alteration, it has existence, something and other;
#     now as infinite, it has finite and infinite,
#     these two themselves as in becoming.

# %% [markdown]
# 1. **Stages of Becoming**: The transcreation highlights the evolving stages of becoming as outlined by Hegel, from abstract to more concrete forms.
#
# 2. **Initial Determinations**: It emphasizes the initial determinations of becoming as 'being' and 'nothing.'
#
# 3. **Alteration Phase**: The translation points out the alteration phase of becoming, involving 'existence,' 'something,' and 'other.'
#
# 4. **Incorporation of Finite and Infinite**: The text illustrates the most developed stage of becoming, which includes the interplay of the finite and the infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :AbstractBeing a owl:Class ;
#     rdfs:label "Abstract Being" ;
#     rdfs:comment "Represents the abstract concept of being." .
#
# :Nothing a owl:Class ;
#     rdfs:label "Nothing" ;
#     rdfs:comment "Represents the abstract concept of nothing." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence in the alteration stage." .
#
# :Something a owl:Class ;
#     rdfs:label "Something" ;
#     rdfs:comment "Represents the concept of something in the alteration stage." .
#
# :Other a owl:Class ;
#     rdfs:label "Other" ;
#     rdfs:comment "Represents the concept of other in the alteration stage." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite." .
#
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite." .
#
# :Becoming a owl:Class ;
#     rdfs:label "Becoming" ;
#     rdfs:comment "Represents the dynamic process of becoming in Hegelian philosophy." .
#
# # Properties
# :hasDetermination a owl:ObjectProperty ;
#     rdfs:label "has determination" ;
#     rdfs:comment "Indicates that an entity has a specific determination." ;
#     rdfs:domain :Becoming ;
#     rdfs:range :AbstractBeing, :Nothing, :Existence, :Something, :Other, :Finite, :Infinite .
#
# :inStateOf a owl:ObjectProperty ;
#     rdfs:label "in state of" ;
#     rdfs:comment "Indicates that an entity is in a state of becoming." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :Becoming .
#
# # Individuals
# :abstractBeing1 a :AbstractBeing ;
#     rdfs:label "Abstract Being" .
#
# :nothing1 a :Nothing ;
#     rdfs:label "Nothing" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" .
#
# :something1 a :Something ;
#     rdfs:label "Something" .
#
# :other1 a :Other ;
#     rdfs:label "Other" .
#
# :finite1 a :Finite ;
#     rdfs:label "Finite" ;
#     :inStateOf :becoming1 .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" ;
#     :inStateOf :becoming1 .
#
# :becoming1 a :Becoming ;
#     rdfs:label "Becoming" ;
#     :hasDetermination :abstractBeing1, :nothing1, :existence1, :something1, :other1, :finite1, :infinite1 .

# %% [markdown]
#     This infinite, as being-turned-back-unto-itself,
#     as reference of itself to itself, is being;
#     but not indeterminate, abstract being,
#     for it is posited as negating the negation;
#     consequently, it is also existence or “thereness,”
#     for it contains negation in general
#     and consequently determinateness.

# %% [markdown]
# 1. **Infinite as Self-Referential**: The transcreation emphasizes Hegel's idea of the infinite as a process of turning back onto itself, a self-reference.
#
# 2. **Beyond Indeterminate Being**: It highlights that this form of the infinite is more than indeterminate or abstract being.
#
# 3. **Negation of Negation**: The translation points out that this specific form of being arises from the negation of negation, leading to existence or "thereness."
#
# 4. **Incorporation of Negation and Determinateness**: The text illustrates how this concept of the infinite includes negation and thus achieves determinateness.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Being a owl:Class ;
#     rdfs:label "Being" ;
#     rdfs:comment "Represents the being-turned-back-unto-itself, as reference of itself to itself." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# # Properties
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Infinite, :Finite ;
#     rdfs:range :Finite, :Infinite .
#
# :isPartOf a owl:ObjectProperty ;
#     rdfs:label "is part of" ;
#     rdfs:comment "Indicates that a concept is part of another." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :TrueInfinite .
#
# :containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that a concept contains negation." ;
#     rdfs:domain :Existence ;
#     rdfs:range :Negation .
#
# :determines a owl:ObjectProperty ;
#     rdfs:label "determines" ;
#     rdfs:comment "Indicates that a concept determines another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Determination .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" ;
#     :negates :finite1 ;
#     :negates :infinite1 .
#
# :being1 a :Being ;
#     rdfs:label "Being" ;
#     :isPartOf :trueInfinite1 .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :containsNegation :negation1 ;
#     :determines :determination1 .
#
# # Relationships
# :finite1 :isPartOf :trueInfinite1 .
# :infinite1 :isPartOf :trueInfinite1 .

# %% [markdown]
#     It is, and is there, present, before us.
#     Only the bad infinite is the beyond,
#     since it is only the negation of
#     the finite posited as real
#     and, as such, it is abstract first negation;
#     thus determined only as negative,
#     it does not have the affirmation of existence in it;
#     held fast only as something negative,
#     it ought not to be there, it ought to be unattainable.

# %% [markdown]
# 1. **True Infinite as Present and Concrete**: The transcreation emphasizes that the true infinite is tangible and present in reality, not merely abstract.
#
# 2. **'Bad' Infinite as Abstract Beyond**: It highlights the characterization of the 'bad' infinite as an unreachable beyond, defined by negation.
#
# 3. **Lack of Affirmative Existence in 'Bad' Infinite**: The translation points out that the 'bad' infinite lacks the affirmation of existence, being only a negative entity.
#
# 4. **Distinction in Conceptualization**: The text illustrates Hegel's distinction between the true and 'bad' infinite in terms of their existence and tangibility.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Being a owl:Class ;
#     rdfs:label "Being" ;
#     rdfs:comment "Represents the being-turned-back-unto-itself, as reference of itself to itself." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "Represents the abstract, unattainable infinite that is only the negation of the finite." .
#
# # Properties
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Infinite, :Finite ;
#     rdfs:range :Finite, :Infinite .
#
# :isPartOf a owl:ObjectProperty ;
#     rdfs:label "is part of" ;
#     rdfs:comment "Indicates that a concept is part of another." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :TrueInfinite .
#
# :containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that a concept contains negation." ;
#     rdfs:domain :Existence ;
#     rdfs:range :Negation .
#
# :determines a owl:ObjectProperty ;
#     rdfs:label "determines" ;
#     rdfs:comment "Indicates that a concept determines another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Determination .
#
# :positsAsReal a owl:ObjectProperty ;
#     rdfs:label "posits as real" ;
#     rdfs:comment "Indicates that a concept posits another as real." ;
#     rdfs:domain :Finite ;
#     rdfs:range :BadInfinite .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" ;
#     :negates :finite1 ;
#     :negates :infinite1 .
#
# :being1 a :Being ;
#     rdfs:label "Being" ;
#     :isPartOf :trueInfinite1 .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :containsNegation :negation1 ;
#     :determines :determination1 .
#
# :badInfinite1 a :BadInfinite ;
#     rdfs:label "Bad Infinite" ;
#     :negates :finite1 ;
#     :positsAsReal :finite1 .
#
# # Relationships
# :finite1 :isPartOf :trueInfinite1 .
# :infinite1 :isPartOf :trueInfinite1 .

# %% [markdown]
#     However, to be thus unattainable is
#     not its grandeur but rather its defect,
#     which is at bottom the result of holding fast
#     to the finite as such, as existent.
#     It is the untrue which is the unattainable,
#     and what must be recognized is that
#     such an infinite is the untrue.

# %% [markdown]
# 1. **Critique of 'Bad' Infinite's Unattainability**: The transcreation emphasizes Hegel's critique of the perceived grandeur in the unattainability of the 'bad' infinite.
#
# 2. **Defectiveness of the 'Bad' Infinite**: It highlights that this unattainability is actually a defect stemming from an overemphasis on the finite.
#
# 3. **Untrue Nature of 'Bad' Infinite**: The translation points out Hegel's assertion that the 'bad' infinite's unattainability is due to its untrue nature.
#
# 4. **Misconception of Finite and Infinite**: The text illustrates the misconception leading to the 'bad' infinite, where the finite is overly prioritized as existent.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Being a owl:Class ;
#     rdfs:label "Being" ;
#     rdfs:comment "Represents the being-turned-back-unto-itself, as reference of itself to itself." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "Represents the abstract, unattainable infinite that is only the negation of the finite." .
#
# :Untrue a owl:Class ;
#     rdfs:label "Untrue" ;
#     rdfs:comment "Represents the concept of the unattainable, abstract infinite which is untrue." .
#
# # Properties
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Infinite, :Finite ;
#     rdfs:range :Finite, :Infinite .
#
# :isPartOf a owl:ObjectProperty ;
#     rdfs:label "is part of" ;
#     rdfs:comment "Indicates that a concept is part of another." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :TrueInfinite .
#
# :containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that a concept contains negation." ;
#     rdfs:domain :Existence ;
#     rdfs:range :Negation .
#
# :determines a owl:ObjectProperty ;
#     rdfs:label "determines" ;
#     rdfs:comment "Indicates that a concept determines another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Determination .
#
# :positsAsReal a owl:ObjectProperty ;
#     rdfs:label "posits as real" ;
#     rdfs:comment "Indicates that a concept posits another as real." ;
#     rdfs:domain :Finite ;
#     rdfs:range :BadInfinite .
#
# :unattainable a owl:ObjectProperty ;
#     rdfs:label "unattainable" ;
#     rdfs:comment "Indicates that a concept is unattainable." ;
#     rdfs:domain :BadInfinite ;
#     rdfs:range :Untrue .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" ;
#     :negates :finite1 ;
#     :negates :infinite1 .
#
# :being1 a :Being ;
#     rdfs:label "Being" ;
#     :isPartOf :trueInfinite1 .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :containsNegation :negation1 ;
#     :determines :determination1 .
#
# :badInfinite1 a :BadInfinite ;
#     rdfs:label "Bad Infinite" ;
#     :negates :finite1 ;
#     :positsAsReal :finite1 ;
#     :unattainable :untrue1 .
#
# :untrue1 a :Untrue ;
#     rdfs:label "Untrue" .
#
# # Relationships
# :finite1 :isPartOf :trueInfinite1 .
# :infinite1 :isPartOf :trueInfinite1 .

# %% [markdown]
#     The image of the progression in infinity is the straight line;
#     the infinite is only at the two limits of this line,
#     and always only is where the latter
#     (which is existence)
#     is not but transcends itself,
#     in its non-existence, that is, in the indeterminate.

# %% [markdown]
# 1. **Straight Line as Infinity Metaphor**: The transcreation emphasizes the use of a straight line as a metaphor for the progression towards infinity.
#
# 2. **Infinite at the Extremities**: It highlights that the infinite is conceptualized at the extremities of the line, beyond tangible points.
#
# 3. **Transcendence Beyond Existence**: The translation points out that the infinite lies where the line transcends itself, moving into non-existence or the indeterminate.
#
# 4. **Beyond Finite Existence**: The text illustrates that the infinite is always beyond the finite existence represented by the line.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Being a owl:Class ;
#     rdfs:label "Being" ;
#     rdfs:comment "Represents the being-turned-back-unto-itself, as reference of itself to itself." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "Represents the abstract, unattainable infinite that is only the negation of the finite." .
#
# :Untrue a owl:Class ;
#     rdfs:label "Untrue" ;
#     rdfs:comment "Represents the concept of the unattainable, abstract infinite which is untrue." .
#
# :StraightLine a owl:Class ;
#     rdfs:label "Straight Line" ;
#     rdfs:comment "Represents the image of progression in infinity as a straight line." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of limits at the ends of a straight line, indicating points of infinity." .
#
# # Properties
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Infinite, :Finite ;
#     rdfs:range :Finite, :Infinite .
#
# :isPartOf a owl:ObjectProperty ;
#     rdfs:label "is part of" ;
#     rdfs:comment "Indicates that a concept is part of another." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :TrueInfinite .
#
# :containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that a concept contains negation." ;
#     rdfs:domain :Existence ;
#     rdfs:range :Negation .
#
# :determines a owl:ObjectProperty ;
#     rdfs:label "determines" ;
#     rdfs:comment "Indicates that a concept determines another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Determination .
#
# :positsAsReal a owl:ObjectProperty ;
#     rdfs:label "posits as real" ;
#     rdfs:comment "Indicates that a concept posits another as real." ;
#     rdfs:domain :Finite ;
#     rdfs:range :BadInfinite .
#
# :unattainable a owl:ObjectProperty ;
#     rdfs:label "unattainable" ;
#     rdfs:comment "Indicates that a concept is unattainable." ;
#     rdfs:domain :BadInfinite ;
#     rdfs:range :Untrue .
#
# :hasLimit a owl:ObjectProperty ;
#     rdfs:label "has limit" ;
#     rdfs:comment "Indicates that a straight line has limits indicating points of infinity." ;
#     rdfs:domain :StraightLine ;
#     rdfs:range :Limit .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" ;
#     :negates :finite1 ;
#     :negates :infinite1 .
#
# :being1 a :Being ;
#     rdfs:label "Being" ;
#     :isPartOf :trueInfinite1 .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :containsNegation :negation1 ;
#     :determines :determination1 .
#
# :badInfinite1 a :BadInfinite ;
#     rdfs:label "Bad Infinite" ;
#     :negates :finite1 ;
#     :positsAsReal :finite1 ;
#     :unattainable :untrue1 .
#
# :untrue1 a :Untrue ;
#     rdfs:label "Untrue" .
#
# :straightLine1 a :StraightLine ;
#     rdfs:label "Straight Line" ;
#     :hasLimit :limit1 ;
#     :hasLimit :limit2 .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :limit2 a :Limit ;
#     rdfs:label "Limit" .
#
# # Relationships
# :finite1 :isPartOf :trueInfinite1 .
# :infinite1 :isPartOf :trueInfinite1 .

# %% [markdown]
#     As true infinite, bent back upon itself,
#     its image becomes the circle,
#     the line that has reached itself,
#     closed and wholly present,
#     without beginning and end.

# %% [markdown]
# 1. **Circle as Symbol of True Infinite**: The transcreation emphasizes the circle as a symbol representing the true infinite in Hegel's philosophy.
#
# 2. **Self-Contained and Complete**: It highlights the circle's nature as a self-contained form, signifying completeness and totality.
#
# 3. **Continuous Loop Without End**: The translation illustrates the continuous, unbroken nature of the circle, without a beginning or an end.
#
# 4. **Contrast with Linear Extension**: The text contrasts the circle with the straight line, which represents an indefinite outward extension.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Being a owl:Class ;
#     rdfs:label "Being" ;
#     rdfs:comment "Represents the being-turned-back-unto-itself, as reference of itself to itself." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :BadInfinite a owl:Class ;
#     rdfs:label "Bad Infinite" ;
#     rdfs:comment "Represents the abstract, unattainable infinite that is only the negation of the finite." .
#
# :Untrue a owl:Class ;
#     rdfs:label "Untrue" ;
#     rdfs:comment "Represents the concept of the unattainable, abstract infinite which is untrue." .
#
# :StraightLine a owl:Class ;
#     rdfs:label "Straight Line" ;
#     rdfs:comment "Represents the image of progression in infinity as a straight line." .
#
# :Limit a owl:Class ;
#     rdfs:label "Limit" ;
#     rdfs:comment "Represents the concept of limits at the ends of a straight line, indicating points of infinity." .
#
# # Properties
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Infinite, :Finite ;
#     rdfs:range :Finite, :Infinite .
#
# :isPartOf a owl:ObjectProperty ;
#     rdfs:label "is part of" ;
#     rdfs:comment "Indicates that a concept is part of another." ;
#     rdfs:domain :Finite, :Infinite ;
#     rdfs:range :TrueInfinite .
#
# :containsNegation a owl:ObjectProperty ;
#     rdfs:label "contains negation" ;
#     rdfs:comment "Indicates that a concept contains negation." ;
#     rdfs:domain :Existence ;
#     rdfs:range :Negation .
#
# :determines a owl:ObjectProperty ;
#     rdfs:label "determines" ;
#     rdfs:comment "Indicates that a concept determines another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Determination .
#
# :positsAsReal a owl:ObjectProperty ;
#     rdfs:label "posits as real" ;
#     rdfs:comment "Indicates that a concept posits another as real." ;
#     rdfs:domain :Finite ;
#     rdfs:range :BadInfinite .
#
# :unattainable a owl:ObjectProperty ;
#     rdfs:label "unattainable" ;
#     rdfs:comment "Indicates that a concept is unattainable." ;
#     rdfs:domain :BadInfinite ;
#     rdfs:range :Untrue .
#
# :hasLimit a owl:ObjectProperty ;
#     rdfs:label "has limit" ;
#     rdfs:comment "Indicates that a straight line has limits indicating points of infinity." ;
#     rdfs:domain :StraightLine ;
#     rdfs:range :Limit .
#
# # Individuals
# :finite1 a :Finite ;
#     rdfs:label "Finite" .
#
# :infinite1 a :Infinite ;
#     rdfs:label "Infinite" .
#
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" ;
#     :negates :finite1 ;
#     :negates :infinite1 .
#
# :being1 a :Being ;
#     rdfs:label "Being" ;
#     :isPartOf :trueInfinite1 .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :containsNegation :negation1 ;
#     :determines :determination1 .
#
# :badInfinite1 a :BadInfinite ;
#     rdfs:label "Bad Infinite" ;
#     :negates :finite1 ;
#     :positsAsReal :finite1 ;
#     :unattainable :untrue1 .
#
# :untrue1 a :Untrue ;
#     rdfs:label "Untrue" .
#
# :straightLine1 a :StraightLine ;
#     rdfs:label "Straight Line" ;
#     :hasLimit :limit1 ;
#     :hasLimit :limit2 .
#
# :limit1 a :Limit ;
#     rdfs:label "Limit" .
#
# :limit2 a :Limit ;
#     rdfs:label "Limit" .
#
# # Relationships
# :finite1 :isPartOf :trueInfinite1 .
# :infinite1 :isPartOf :trueInfinite1 .

# %% [markdown]
#     True infinity, thus taken in general as existence posited
#     as affirmative in contrast to abstract negation,
#     is reality in a higher sense than it was earlier
#     as simply determined; it has now obtained a concrete content.
#     It is not the finite which is the real, but rather the infinite.
#     Thus reality is further determined
#     as essence, concept, idea, and so forth.

# %% [markdown]
# 1. **True Infinity as Affirmative Existence**: The transcreation emphasizes Hegel's definition of true infinity as existence posited affirmatively against abstract negation.
#
# 2. **Elevation of Reality**: It highlights the elevation of the infinite as a higher form of reality compared to finite existence.
#
# 3. **Concrete Content of Infinity**: The translation points out the transformation of the infinite from an abstract concept to one with concrete content.
#
# 4. **Reality Beyond Finitude**: The text illustrates that true reality, according to Hegel, is found in the infinite rather than the finite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents reality as determined by true infinity in Hegelian philosophy." .
#
# :Essence a owl:Class ;
#     rdfs:label "Essence" ;
#     rdfs:comment "Represents the essence of reality as further determined by true infinity." .
#
# :Concept a owl:Class ;
#     rdfs:label "Concept" ;
#     rdfs:comment "Represents the concept as further determined by true infinity." .
#
# :Idea a owl:Class ;
#     rdfs:label "Idea" ;
#     rdfs:comment "Represents the idea as further determined by true infinity." .
#
# # Properties
# :isDeterminedAs a owl:ObjectProperty ;
#     rdfs:label "is determined as" ;
#     rdfs:comment "Indicates that reality is determined as essence, concept, and idea." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Essence, :Concept, :Idea .
#
# # Individuals
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :isPartOf :trueInfinite1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" ;
#     :isDeterminedAs :essence1, :concept1, :idea1 .
#
# :essence1 a :Essence ;
#     rdfs:label "Essence" .
#
# :concept1 a :Concept ;
#     rdfs:label "Concept" .
#
# :idea1 a :Idea ;
#     rdfs:label "Idea" .
#
# # Relationships
# :reality1 :isDeterminedAs :essence1, :concept1, :idea1 .

# %% [markdown]
#     In connection with the more concrete,
#     it is however superfluous to repeat such earlier
#     and more abstract categories as reality,
#     and to use them for determinations more
#     concrete than they are by themselves.
#     Such a repetition, as when it is said that essence,
#     or that the concept, is real, has its origin in the fact
#     that to uneducated thought the most abstract categories
#     such as being, existence, reality, finitude, are the most familiar.

# %% [markdown]
# 1. **Critique of Redundant Repetition**: The transcreation emphasizes Hegel's critique of the unnecessary repetition of abstract categories in discussing more concrete concepts.
#
# 2. **Intellectual Habit of Familiarity**: It highlights the tendency to rely on familiar abstract categories due to their familiarity in uneducated thought.
#
# 3. **Limitation in Conceptual Understanding**: The translation points out that this practice limits the understanding of more complex concepts.
#
# 4. **Need for Deeper Engagement**: The text suggests that Hegel advocates for a deeper engagement with philosophical concepts beyond familiar abstractions.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Being a owl:Class ;
#     rdfs:label "Being" ;
#     rdfs:comment "Represents the concept of being in Hegelian philosophy." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents reality as determined by true infinity in Hegelian philosophy." .
#
# :Essence a owl:Class ;
#     rdfs:label "Essence" ;
#     rdfs:comment "Represents the essence of reality as further determined by true infinity." .
#
# :Concept a owl:Class ;
#     rdfs:label "Concept" ;
#     rdfs:comment "Represents the concept as further determined by true infinity." .
#
# :Idea a owl:Class ;
#     rdfs:label "Idea" ;
#     rdfs:comment "Represents the idea as further determined by true infinity." .
#
# # Properties
# :isDeterminedAs a owl:ObjectProperty ;
#     rdfs:label "is determined as" ;
#     rdfs:comment "Indicates that reality is determined as essence, concept, and idea." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Essence, :Concept, :Idea .
#
# # Individuals
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :isPartOf :trueInfinite1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" ;
#     :isDeterminedAs :essence1, :concept1, :idea1 .
#
# :essence1 a :Essence ;
#     rdfs:label "Essence" .
#
# :concept1 a :Concept ;
#     rdfs:label "Concept" .
#
# :idea1 a :Idea ;
#     rdfs:label "Idea" .
#
# # Relationships
# :reality1 :isDeterminedAs :essence1, :concept1, :idea1 .

# %% [markdown]
#     The more immediate occasion, however,
#     for recalling here the categories of reality
#     is that the negation, against which reality is the affirmative,
#     is here the negation of negation,
#     and consequently itself posited over against
#     that reality which finite existence is.

# %% [markdown]
# 1. **Context for Recalling Categories of Reality**: The transcreation emphasizes Hegel's immediate occasion for revisiting the categories of reality.
#
# 2. **Negation of Negation**: It highlights the complex form of negation – the negation of negation – against which reality is positioned as affirmative.
#
# 3. **Contrast with Finite Existence**: The translation points out that this negation of negation is posited against the reality of finite existence.
#
# 4. **Need for Conceptual Clarity**: The text illustrates the necessity of recalling these categories to understand the complex relationship between these concepts.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents reality as determined by true infinity in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :NegationOfNegation a owl:Class ;
#     rdfs:label "Negation of Negation" ;
#     rdfs:comment "Represents the concept of the negation of negation in Hegelian philosophy." .
#
# # Properties
# :isDeterminedAs a owl:ObjectProperty ;
#     rdfs:label "is determined as" ;
#     rdfs:comment "Indicates that reality is determined as essence, concept, and idea." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Essence, :Concept, :Idea .
#
# :isNegatedBy a owl:ObjectProperty ;
#     rdfs:label "is negated by" ;
#     rdfs:comment "Indicates that a concept is negated by another." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Negation .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Reality .
#
# :negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that a concept is the negation of negation." ;
#     rdfs:domain :NegationOfNegation ;
#     rdfs:range :Negation .
#
# # Individuals
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :isPartOf :trueInfinite1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" ;
#     :isDeterminedAs :essence1, :concept1, :idea1 ;
#     :isNegatedBy :negation1 .
#
# :essence1 a :Essence ;
#     rdfs:label "Essence" .
#
# :concept1 a :Concept ;
#     rdfs:label "Concept" .
#
# :idea1 a :Idea ;
#     rdfs:label "Idea" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" ;
#     :negates :reality1 .
#
# :negationOfNegation1 a :NegationOfNegation ;
#     rdfs:label "Negation of Negation" ;
#     :negationOfNegation :negation1 .
#
# # Relationships
# :reality1 :isDeterminedAs :essence1, :concept1, :idea1 .
# :reality1 :isNegatedBy :negation1 .
# :negation1 :negates :reality1 .
# :negationOfNegation1 :negationOfNegation :negation1 .

# %% [markdown]
#     Negation is thus determined as ideality;
#     the idealized is the finite as it is in the true infinite
#     (as a determination, a content, a distinct
#     but not a subsistent existent, a moment rather.
#     Ideality has this more concrete signification
#     which is not fully expressed through
#     the negation of finite existence.)

# %% [markdown]
# 1. **Negation as Ideality**: The transcreation emphasizes Hegel's definition of negation in terms of ideality.
#
# 2. **Finite within the True Infinite**: It highlights the conceptualization of the finite as a distinct yet non-subsistent element within the true infinite.
#
# 3. **Ideality's Concrete Signification**: The translation points out that ideality represents a more concrete meaning than just the negation of finite existence.
#
# 4. **Transformation of the Finite**: The text illustrates the transformation and new dimension of the finite within the scope of the infinite.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents reality as determined by true infinity in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :NegationOfNegation a owl:Class ;
#     rdfs:label "Negation of Negation" ;
#     rdfs:comment "Represents the concept of the negation of negation in Hegelian philosophy." .
#
# :Ideality a owl:Class ;
#     rdfs:label "Ideality" ;
#     rdfs:comment "Represents the concept of ideality, where the finite exists as a determination within the true infinite." .
#
# # Properties
# :isDeterminedAs a owl:ObjectProperty ;
#     rdfs:label "is determined as" ;
#     rdfs:comment "Indicates that reality is determined as essence, concept, and idea." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Essence, :Concept, :Idea .
#
# :isNegatedBy a owl:ObjectProperty ;
#     rdfs:label "is negated by" ;
#     rdfs:comment "Indicates that a concept is negated by another." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Negation .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Reality .
#
# :negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that a concept is the negation of negation." ;
#     rdfs:domain :NegationOfNegation ;
#     rdfs:range :Negation .
#
# :idealizes a owl:ObjectProperty ;
#     rdfs:label "idealizes" ;
#     rdfs:comment "Indicates that a concept is idealized within another." ;
#     rdfs:domain :Ideality ;
#     rdfs:range :Finite .
#
# # Individuals
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :isPartOf :trueInfinite1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" ;
#     :isDeterminedAs :essence1, :concept1, :idea1 ;
#     :isNegatedBy :negation1 .
#
# :essence1 a :Essence ;
#     rdfs:label "Essence" .
#
# :concept1 a :Concept ;
#     rdfs:label "Concept" .
#
# :idea1 a :Idea ;
#     rdfs:label "Idea" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" ;
#     :negates :reality1 .
#
# :negationOfNegation1 a :NegationOfNegation ;
#     rdfs:label "Negation of Negation" ;
#     :negationOfNegation :negation1 .
#
# :ideality1 a :Ideality ;
#     rdfs:label "Ideality" ;
#     :idealizes :finite1 .
#
# # Relationships
# :reality1 :isDeterminedAs :essence1, :concept1, :idea1 .
# :reality1 :isNegatedBy :negation1 .
# :negation1 :negates :reality1 .
# :negationOfNegation1 :negationOfNegation :negation1 .
# :ideality1 :idealizes :finite1 .

# %% [markdown]
#     As regards reality and ideality,
#     the opposition of finite and infinite is, however,
#     so grasped that the finite assumes the value of “the real,”
#     whereas the infinite that of “the idealized”;
#     in the same way, further on, also the concept is
#     regarded as an idealization, that is, as a mere idealization,
#     in contrast to existence in general, which is regarded as “the real.”

# %% [markdown]
# 1. **Finite as 'The Real'**: The transcreation emphasizes that the finite is often viewed as embodying 'the real' in opposition to the infinite.
#
# 2. **Infinite as 'The Idealized'**: It highlights that the infinite is seen as 'the idealized,' existing more in thought than reality.
#
# 3. **Concept as Idealization**: The translation points out Hegel's observation that the concept itself is often treated as an idealization in contrast to tangible existence.
#
# 4. **Contrast Between Existence and Concept**: The text illustrates the contrast set up between the concrete reality of existence and the ideality of concepts.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents reality as determined by true infinity in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :NegationOfNegation a owl:Class ;
#     rdfs:label "Negation of Negation" ;
#     rdfs:comment "Represents the concept of the negation of negation in Hegelian philosophy." .
#
# :Ideality a owl:Class ;
#     rdfs:label "Ideality" ;
#     rdfs:comment "Represents the concept of ideality, where the finite exists as a determination within the true infinite." .
#
# :Concept a owl:Class ;
#     rdfs:label "Concept" ;
#     rdfs:comment "Represents the concept as further determined by true infinity." .
#
# # Properties
# :isDeterminedAs a owl:ObjectProperty ;
#     rdfs:label "is determined as" ;
#     rdfs:comment "Indicates that reality is determined as essence, concept, and idea." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Essence, :Concept, :Idea .
#
# :isNegatedBy a owl:ObjectProperty ;
#     rdfs:label "is negated by" ;
#     rdfs:comment "Indicates that a concept is negated by another." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Negation .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Reality .
#
# :negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that a concept is the negation of negation." ;
#     rdfs:domain :NegationOfNegation ;
#     rdfs:range :Negation .
#
# :idealizes a owl:ObjectProperty ;
#     rdfs:label "idealizes" ;
#     rdfs:comment "Indicates that a concept is idealized within another." ;
#     rdfs:domain :Ideality ;
#     rdfs:range :Finite .
#
# :regardedAs a owl:ObjectProperty ;
#     rdfs:label "regarded as" ;
#     rdfs:comment "Indicates that a concept is regarded as another concept." ;
#     rdfs:domain :Finite, :Infinite, :Concept, :Existence ;
#     rdfs:range :Reality, :Ideality .
#
# # Individuals
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :isPartOf :trueInfinite1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" ;
#     :isDeterminedAs :essence1, :concept1, :idea1 ;
#     :isNegatedBy :negation1 .
#
# :essence1 a :Essence ;
#     rdfs:label "Essence" .
#
# :concept1 a :Concept ;
#     rdfs:label "Concept" ;
#     :regardedAs :ideality1 .
#
# :idea1 a :Idea ;
#     rdfs:label "Idea" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" ;
#     :negates :reality1 .
#
# :negationOfNegation1 a :NegationOfNegation ;
#     rdfs:label "Negation of Negation" ;
#     :negationOfNegation :negation1 .
#
# :ideality1 a :Ideality ;
#     rdfs:label "Ideality" ;
#     :idealizes :finite1 .
#
# # Relationships
# :reality1 :isDeterminedAs :essence1, :concept1, :idea1 .
# :reality1 :isNegatedBy :negation1 .
# :negation1 :negates :reality1 .
# :negationOfNegation1 :negationOfNegation :negation1 .
# :ideality1 :idealizes :finite1 .
# :finite1 :regardedAs :reality1 .
# :infinite1 :regardedAs :ideality1 .
# :concept1 :regardedAs :ideality1 .
# :existence1 :regardedAs :reality1 .

# %% [markdown]
#     When contrasted in this way, it is of course of no use to have
#     reserved for the said concrete determination of negation
#     the distinctive expression of “idealization”;
#     in that opposition of finite and infinite,
#     we are back to the one-sidedness of
#     the abstract negative characteristic of the bad infinite
#     and still fixed in the affirmative existence of the finite.

# %% [markdown]
# 1. **Critique of Simplistic Contrast**: The transcreation emphasizes Hegel's critique of the traditional, simplistic contrast between the finite and infinite.
#
# 2. **Misuse of 'Idealization'**: It highlights the problem with using 'idealization' in this limited context, where its deeper meaning is lost.
#
# 3. **Return to One-Sided Perspective**: The translation points out that this approach leads back to the one-sided view of the infinite as the 'bad infinite' and the finite as the only real existence.
#
# 4. **Need for Comprehensive Understanding**: The text suggests that Hegel calls for a broader understanding that captures the complex dynamics between these concepts.

# %% [markdown]
# ```turtle
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# # Classes
# :Infinite a owl:Class ;
#     rdfs:label "Infinite" ;
#     rdfs:comment "Represents the concept of the infinite in Hegelian philosophy." .
#
# :Finite a owl:Class ;
#     rdfs:label "Finite" ;
#     rdfs:comment "Represents the concept of the finite in Hegelian philosophy." .
#
# :TrueInfinite a owl:Class ;
#     rdfs:label "True Infinite" ;
#     rdfs:comment "Represents the true infinite, achieved through the self-sublation of the finite and the infinite." .
#
# :Existence a owl:Class ;
#     rdfs:label "Existence" ;
#     rdfs:comment "Represents the concept of existence or 'thereness' in Hegelian philosophy." .
#
# :Reality a owl:Class ;
#     rdfs:label "Reality" ;
#     rdfs:comment "Represents reality as determined by true infinity in Hegelian philosophy." .
#
# :Negation a owl:Class ;
#     rdfs:label "Negation" ;
#     rdfs:comment "Represents the concept of negation in Hegelian philosophy." .
#
# :NegationOfNegation a owl:Class ;
#     rdfs:label "Negation of Negation" ;
#     rdfs:comment "Represents the concept of the negation of negation in Hegelian philosophy." .
#
# :Ideality a owl:Class ;
#     rdfs:label "Ideality" ;
#     rdfs:comment "Represents the concept of ideality, where the finite exists as a determination within the true infinite." .
#
# :Concept a owl:Class ;
#     rdfs:label "Concept" ;
#     rdfs:comment "Represents the concept as further determined by true infinity." .
#
# # Properties
# :isDeterminedAs a owl:ObjectProperty ;
#     rdfs:label "is determined as" ;
#     rdfs:comment "Indicates that reality is determined as essence, concept, and idea." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Essence, :Concept, :Idea .
#
# :isNegatedBy a owl:ObjectProperty ;
#     rdfs:label "is negated by" ;
#     rdfs:comment "Indicates that a concept is negated by another." ;
#     rdfs:domain :Reality ;
#     rdfs:range :Negation .
#
# :negates a owl:ObjectProperty ;
#     rdfs:label "negates" ;
#     rdfs:comment "Indicates that one concept negates another." ;
#     rdfs:domain :Negation ;
#     rdfs:range :Reality .
#
# :negationOfNegation a owl:ObjectProperty ;
#     rdfs:label "negation of negation" ;
#     rdfs:comment "Indicates that a concept is the negation of negation." ;
#     rdfs:domain :NegationOfNegation ;
#     rdfs:range :Negation .
#
# :idealizes a owl:ObjectProperty ;
#     rdfs:label "idealizes" ;
#     rdfs:comment "Indicates that a concept is idealized within another." ;
#     rdfs:domain :Ideality ;
#     rdfs:range :Finite .
#
# :regardedAs a owl:ObjectProperty ;
#     rdfs:label "regarded as" ;
#     rdfs:comment "Indicates that a concept is regarded as another concept." ;
#     rdfs:domain :Finite, :Infinite, :Concept, :Existence ;
#     rdfs:range :Reality, :Ideality .
#
# # Individuals
# :trueInfinite1 a :TrueInfinite ;
#     rdfs:label "True Infinite" .
#
# :existence1 a :Existence ;
#     rdfs:label "Existence" ;
#     :isPartOf :trueInfinite1 .
#
# :reality1 a :Reality ;
#     rdfs:label "Reality" ;
#     :isDeterminedAs :essence1, :concept1, :idea1 ;
#     :isNegatedBy :negation1 .
#
# :essence1 a :Essence ;
#     rdfs:label "Essence" .
#
# :concept1 a :Concept ;
#     rdfs:label "Concept" ;
#     :regardedAs :ideality1 .
#
# :idea1 a :Idea ;
#     rdfs:label "Idea" .
#
# :negation1 a :Negation ;
#     rdfs:label "Negation" ;
#     :negates :reality1 .
#
# :negationOfNegation1 a :NegationOfNegation ;
#     rdfs:label "Negation of Negation" ;
#     :negationOfNegation :negation1 .
#
# :ideality1 a :Ideality ;
#     rdfs:label "Ideality" ;
#     :idealizes :finite1 .
#
# # Relationships
# :reality1 :isDeterminedAs :essence1, :concept1, :idea1 .
# :reality1 :isNegatedBy :negation1 .
# :negation1 :negates :reality1 .
# :negationOfNegation1 :negationOfNegation :negation1 .
# :ideality1 :idealizes :finite1 .
# :finite1 :regardedAs :reality1 .
# :infinite1 :regardedAs :ideality1 .
# :concept1 :regardedAs :ideality1 .
# :existence1 :regardedAs :reality1 .
